# %% [markdown]
# ### 사용할 라이브러리

# %%
### 기본 라이브러리
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

### 형태소 분석
from konlpy.tag import Okt

### 단어 분할
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

### 정규표현식(Regular Expression; regex) 
import re

# %% [markdown]
# ### 데이터셋 읽어들이기

# %%
### ratins_train and ratings_test 파일의 데이터셋 읽어들이기
# - 변수명 : train_data, test_data
# - read_tabel() 함수 사용
train_data = pd.read_table("./files/ratings_train.txt")
test_data = pd.read_table("./files/ratings_test.txt")

# %%
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        50000 non-null  int64
#  1   document  49997 non-null  object
#  2   label     50000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 종속변수로 사용할 label의 고유한 범주 확인하기

# %%
### label 데이터의 범주별 갯수 확인하기
print(train_data["label"].value_counts())
print(test_data["label"].value_counts())

### 훈련 및 테스트 데이터의 범주는 0과 1로,
#   - 범주별 데이터 건수는 고르게 분포되어 있음
# Out:
# label
# 0    75173
# 1    74827
# Name: count, dtype: int64
# label
# 1    25173
# 0    24827
# Name: count, dtype: int64

# %% [markdown]
# ### 독립변수로 사용할 document 데이터 전처리하기

# %%
train_data["document"]
# Out:
# 0                                       아 더빙.. 진짜 짜증나네요 목소리
# 1                         흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                             교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
#                                 ...
# 149995                                  인간이 문제지.. 소는 뭔죄인가..
# 149996                                        평점이 너무 낮아서...
# 149997                      이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?
# 149998                          청춘 영화의 최고봉.방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 150000, dtype: object

# %%
### 정규표현식을 이용하여 영어/숫자/특수문자 모두 제거하기
# - 한글과 공백을 제외한 모든것 제거하기
# - 정규표현식 : 문장 내에 특정 문자의 패턴을 이용하여 필터링하는 기법
# - 사용함수 : replace("정규표현식", "바꿀값", regex=True)
#            : regex=True -> 정규표현식을 이용하여 필터링 하겠다는 정의
# [^ㄱ-ㅎㅏ-ㅣ가-힣 ] : 한글과 공백이 아닌(^) 모든[] 것을 의미함
train_data["document"] = train_data["document"].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
test_data["document"]  = test_data["document"].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)

# %%
train_data.head(1)
# Out:
#         id           document  label
# 0  9976970  아 더빙 진짜 짜증나네요 목소리      0

# %%
test_data.head(1)
# Out:
#         id document  label
# 0  6270596      굳 ㅋ      1

# %% [markdown]
# ### 독립변수(document) 내에 공백(white space)만 있는 경우 제거하기

# %%
### 데이터 내에 공백(white space)은 문자로 인식하기 때문에 
# - 공백을 ""로 치환하면 Nan이 됨
# - Nan 처리 후 기존의 결측치 제거 방식을 사용함

### 공백을 ""로 치환하기 : 정규표현식 사용
# - ^ + : 공백 뒤에 문자로 시작(+)되지 않는(^) 것은 제거
train_data["document"] = train_data["document"].str.replace("^ +", "", regex=True)

### ""로 변환된 값들을 다시 nan으로 치환
train_data["document"].replace("", np.nan, inplace=True)

### 기존의 결측치 처리방식으로 nan에 대해서 모든 행 삭제하기
# - how="any" : 행 또는 열 중에 하나라도 NaN이 있으면 해당 행 삭제
train_data = train_data.dropna(how="any")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7896\3775835994.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["document"].replace("", np.nan, inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148740 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        148740 non-null  int64
#  1   document  148740 non-null  object
#  2   label     148740 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.5+ MB

# %%
### 데이터 내에 공백(white space)은 문자로 인식하기 때문에 
# - 공백을 ""로 치환하면 Nan이 됨
# - Nan 처리 후 기존의 결측치 제거 방식을 사용함

### 공백을 ""로 치환하기 : 정규표현식 사용
# - ^ + : 공백 뒤에 문자로 시작(+)되지 않는(^) 것은 제거
test_data["document"] = test_data["document"].str.replace("^ +", "", regex=True)

### ""로 변환된 값들을 다시 nan으로 치환
test_data["document"].replace("", np.nan, inplace=True)

### 기존의 결측치 처리방식으로 nan에 대해서 모든 행 삭제하기
# - how="any" : 행 또는 열 중에 하나라도 NaN이 있으면 해당 행 삭제
test_data = test_data.dropna(how="any")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7896\4167284106.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data["document"].replace("", np.nan, inplace=True)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49575 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        49575 non-null  int64
#  1   document  49575 non-null  object
#  2   label     49575 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 형태소 분석하기

# %%
### 불용어 정의하기
stopwords = ["아", "의", "가", "이", "은", "들", "는", "좀", 
             "잘", "걍", "과", "도", "를", "으로", "자",
             "에", "와", "한", "하다", "흠", "ㅠㅠ", "ㅋ", 
             "ㅋㅋ", "ㅎ", "ㅎㅎ", "전"]

# %%
### 형태소 분석기 생성하기
okt = Okt()
okt

# %%
print(train_data["document"][0])
okt.morphs(train_data["document"][0])
# Out:
# 아 더빙 진짜 짜증나네요 목소리
# ['아', '더빙', '진짜', '짜증나네요', '목소리']

# %%
### 형태소 분할된 후 불용어 처리 후 각 행의 단어들을 리스트 변수에 담기
# - document의 모든 행 내에 단어들을 행단위로 단어 분리 후 리스트 변수에 담기
# - 변수명 : X_train

X_train = []

for sentence in train_data["document"] :
    # 형태소 분석
    tokenized_sentence = okt.morphs(sentence)
    # 불용어 제거
    stopwords_sentence = [word for word in tokenized_sentence 
                                    if word not in stopwords]
    # 리스트에 담기
    X_train.append(stopwords_sentence)

# %%
### 훈련 데이터 : 2차원
X_train
# Out:
# [['더빙', '진짜', '짜증나네요', '목소리'],
#  ['포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍지', '않구나'],
#  ['너', '무재', '밓었', '다그', '래서', '보는것을', '추천', '다'],
#  ['교도소', '이야기', '구먼', '솔직히', '재미', '없다', '평점', '조정'],
#  ['사이',
#   '몬페',
#   '그',
#   '익살스런',
#   '연기',
#   '돋보였던',
#   '영화',
#   '스파이더맨',
#   '에서',
#   '늙어',
#   '보이기만',
#   '했던',
#   '커스틴',
#   '던스트',
#   '너무나도',
#   '이뻐',
#   '보였다'],
#  ['막',
#   '걸음',
#   '마',
#   '뗀',
#   '세',
#   '부터',
#   '초등학교',
#   '학년',
#   '생인',
#   '살용',
#   '영화',
#   'ㅋㅋㅋ',
#   '별',
#   '반개',
#   '아까',
#   '움'],
#  ['원작', '긴장감', '을', '제대로', '살려내지못', '했다'],
#  ['별',
#   '반개',
#   '아깝다',
#   '욕',
#   '나온다',
#   '이응경',
#   '길용우',
#   '연',
#   '기',
#   '생활',
#   '몇',
#   '년',
#   '인지',
#   '정말',
#   '발',
#   '로',
#   '해도',
#   '그것',
#   '보단',
#   '낫겟다',
#   '납치',
#   '감금',
#   '만',
#   '반복',
#   '반복',
#   '드라마',
#   '가족',
#   '없다',
#   '연기',
#   '못',
#   '하는',
#   '사람',
#   '만',
#   '모',
#   '엿',
#   '네'],
#  ['액션', '없는데도', '재미', '있는', '몇', '안되는', '영화'],
#  ['왜케',
#   '평점',
#   '낮은건데',
#   '꽤',
#   '볼',
#   '만',
#   '데',
#   '헐리우드',
#   '식',
#   '화려함에만',
#   '너무',
#   '길들여져',
#   '있나'],
#  ['인피니트', '짱', '이다', '진짜', '짱', '이다'],
#  ['볼때',
#   '마다',
#   '눈물나서',
#   '죽겠다',
#   '년대',
#   '향수',
#   '극',
#   '허진호',
#   '감성',
#   '절제',
#   '멜로',
#   '달인',
#   '이다'],
#  ['울면',
#   '서',
#   '손',
#   '고',
#   '횡단보도',
#   '건널',
#   '때',
#   '뛰',
#   '쳐나',
#   '올',
#   '뻔',
#   '이범수',
#   '연기',
#   '드럽게',
#   '못',
#   '해'],
#  ['담백하고',
#   '깔끔해서',
#   '좋다',
#   '신',
#   '문',
#   '기',
#   '사',
#   '로만',
#   '보다',
#   '보면',
#   '자꾸',
#   '잊어버린다',
#   '그',
#   '사람',
#   '이었다는',
#   '것',
#   '을'],
#  ['취향',
#   '존중',
#   '다지',
#   '만',
#   '진짜',
#   '내생',
#   '극장',
#   '에서',
#   '본',
#   '영화',
#   '중',
#   '가장',
#   '노잼',
#   '노',
#   '감동',
#   '임',
#   '스토리',
#   '어거지',
#   '고',
#   '감동',
#   '어거지'],
#  ['ㄱ', '냥', '매번', '긴장', '되고', '재밋음'],
#  ['참',
#   '사람',
#   '웃긴게',
#   '바스코',
#   '이기',
#   '면',
#   '락스',
#   '코',
#   '라고',
#   '까고',
#   '바비',
#   '이기',
#   '면',
#   '아이돌',
#   '이라고',
#   '깐',
#   '다그',
#   '냥',
#   '까고싶어서',
#   '안달',
#   '난',
#   '것',
#   '처럼',
#   '보인다'],
#  ['굿바이',
#   '레닌',
#   '표절',
#   '인',
#   '것',
#   '이해',
#   '하는데',
#   '왜',
#   '뒤',
#   '로',
#   '갈수록',
#   '재미',
#   '없어지냐'],
#  ['이건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '질퍽',
#   '하',
#   '지',
#   '않은',
#   '산뜻한',
#   '내',
#   '용구성',
#   '버무러진',
#   '깨알',
#   '일드'],
#  ['약탈', '위', '변명', '이라', '저', '놈', '착한', '놈', '절대', '아닌', '걸', '요'],
#  ['나름', '심오한', '뜻', '있는', '듯', '그냥', '학생', '선생', '놀아나는', '영화', '절대', '아님'],
#  ['보면서', '웃지', '않는', '건', '불가능하다'],
#  ['재미없다',
#   '지루하고',
#   '같은',
#   '음식',
#   '영화',
#   '인데',
#   '바베트',
#   '만찬',
#   '하고',
#   '넘',
#   '차이',
#   '남바',
#   '베트',
#   '만찬',
#   '이야기',
#   '있고',
#   '음식',
#   '보는',
#   '재미',
#   '있는데',
#   '이건',
#   '볼',
#   '게',
#   '없다',
#   '음식',
#   '별로',
#   '안',
#   '나오고',
#   '핀란드',
#   '풍경',
#   '이라도',
#   '구',
#   '경',
#   '할랫',
#   '는데',
#   '그것',
#   '별로',
#   '안',
#   '나옴',
#   'ㅡㅡ'],
#  ['절대', '평범한', '영화', '아닌', '수작', '이라', '는걸', '말씀드립니다'],
#  ['주제', '좋은데', '중반', '부터', '지루하다'],
#  ['다', '짤랐을꺼', '야', '그래서', '납득', '할', '수', '없었던거야', '그럴꺼야', '꼭', '그랬던걸', '꺼야'],
#  ['고추', '털어', '버려야', '할텐데'],
#  ['카밀라', '벨', '발연기'],
#  ['재밋는뎅'],
#  ['센스', '있는', '연출', '력', '탁월한', '캐스팅', '년대', '향수', '그래서', '점'],
#  ['엄포스',
#   '위력',
#   '을',
#   '다시',
#   '한번',
#   '깨닫게',
#   '해준',
#   '적남',
#   '꽃',
#   '검사',
#   '님',
#   '연기',
#   '정말',
#   '좋았어요',
#   '완전',
#   '명품',
#   '드라마'],
#  ['졸', '쓰레기', '진부하고말', '도안', '됌', '아시', '간', '아까워'],
#  ['재밌는데', '별', '점', '왜', '이리', '낮은고'],
#  ['라도', '기대했던', '내', '죄인', '입니다', '죄인', '입니다'],
#  ['아직도', '드라마', '내', '인생', '최고'],
#  ['패션', '대한', '열정', '안나', '윈', '투어'],
#  ['키이라', '나이틀리', '연기', '하고자', '했던건', '대체', '정신장애', '일까', '틱장애', '일까'],
#  ['허허', '원', '작가', '정신', '나간', '유령', '이라', '재미있겠네요'],
#  ['포스터', '있어', '보이는데', '관객', '명', '이네'],
#  ['영화', '왜', '이렇게', '저', '평가', '받는지', '모르겠다'],
#  ['단순하면서', '은은한', '매력', '영화'],
#  ['다',
#   '알바생',
#   '인가',
#   '내용',
#   '없고',
#   '무서운거도',
#   '없고',
#   '웃긴거도',
#   '하나',
#   '없음',
#   '완전',
#   '별',
#   '싱거운',
#   '영화',
#   'ㅇㅇ',
#   '내',
#   'ㅇ',
#   '시간',
#   '넘',
#   '아까',
#   '움',
#   '완전',
#   '낚임'],
#  ['오게', '두어라', '서리', '굶주렸다'],
#  ['정말', '맘', '들어요', '그래서', '또', '보고싶은데', '또', '보는', '방법', '없네', 'ㅜㅡ'],
#  ['윤제문',
#   '이라는',
#   '멋진',
#   '배우',
#   '발견',
#   '하게',
#   '됐어요',
#   '소소한',
#   '일',
#   '탈',
#   '잔잔한',
#   '미소',
#   '머금',
#   '게',
#   '합니다',
#   '음악',
#   '조금',
#   '아쉽네요',
#   '점',
#   '주고',
#   '싶은데',
#   '평점',
#   '올리고',
#   '싶어',
#   '점',
#   '줄게요'],
#  ['평점', '속지', '마시길', '시간', '낭비', '돈', '낭비', '임'],
#  ['리얼리티',
#   '뛰어나긴',
#   '한데',
#   '큰',
#   '공감',
#   '안',
#   '간다',
#   '이민기',
#   '캐릭터',
#   '정신의학',
#   '상',
#   '분노조절',
#   '장애',
#   '초기',
#   '증상',
#   '일거다',
#   '툭하면',
#   '사람',
#   '패',
#   '고',
#   '욕',
#   '하고',
#   '물건',
#   '파손',
#   '하고',
#   '조금',
#   '오',
#   '바',
#   '였음',
#   '극',
#   '초반',
#   '엔',
#   '신선했는데',
#   '가면',
#   '갈수록',
#   '이민기',
#   '정신',
#   '상태',
#   '공감',
#   '불가'],
#  ['마이너스',
#   '왜',
#   '없냐',
#   '뮤비',
#   '보고',
#   '영화',
#   '수준',
#   '딱',
#   '알',
#   '만',
#   '하더군',
#   'ㅉㅉ',
#   '북한',
#   '에서',
#   '이런거',
#   '만들라고',
#   '돈',
#   '대주던'],
#  ['난', '우리', '영화', '사랑', '합니다'],
#  ['데',
#   '너',
#   '리스',
#   '타르',
#   '가르',
#   '엔나',
#   '용의',
#   '주인',
#   '되고',
#   '싶다',
#   '누',
#   '이랑',
#   '근친상간',
#   '이나',
#   '하고',
#   '다닐지라도',
#   '소설',
#   '속',
#   '에선',
#   '제일',
#   '멋진',
#   '놈',
#   '메',
#   '라',
#   '니스',
#   '터',
#   '였는데',
#   '드라마',
#   '속',
#   '에선',
#   '드래곤',
#   '용이',
#   '제일',
#   '멋지',
#   '네',
#   '웃음',
#   '감독',
#   '님',
#   '토르',
#   '다크',
#   '월드',
#   '말',
#   '잡수셨을지라도',
#   '기본',
#   '선방',
#   '했음'],
#  ['영화',
#   '사람',
#   '영혼',
#   '을',
#   '어루만져',
#   '줄',
#   '수도',
#   '있군요',
#   '거친',
#   '세',
#   '상사',
#   '잠시',
#   '잊고',
#   '동화',
#   '같은',
#   '영화',
#   '행복했네요'],
#  ['야',
#   '세르게이',
#   '작은',
#   '고추',
#   '매운',
#   '맛',
#   '을',
#   '보여주마',
#   '포퐁',
#   '저그',
#   '콩',
#   '진호',
#   '간다'],
#  ['이렇게', '가슴', '시리', '게', '본', '드라마', '또', '있을까', '감동', '그', '자체'],
#  ['난또',
#   '저',
#   '꼬마',
#   '애가',
#   '무슨',
#   '원한',
#   '깊길래',
#   '했더니',
#   '그냥',
#   '혼자',
#   '나대다',
#   '걸',
#   '어쩌라고'],
#  ['재미있어요'],
#  ['좋아요'],
#  ['최고'],
#  ['너무',
#   '충격',
#   '적이엇다',
#   '기분',
#   '을',
#   '완전히',
#   '푹',
#   '꺼지게',
#   '하는',
#   '느낌',
#   '활',
#   '력',
#   '이라고는',
#   '하나',
#   '없는',
#   '너무나도',
#   '무거운',
#   '지독하고',
#   '차갑고',
#   '무자비하다',
#   '그저',
#   '일본인',
#   '상상력',
#   '정말',
#   '대단한거',
#   '같다는',
#   '생각',
#   '든다'],
#  ['심심한', '영화'],
#  ['백봉기', '언제', '나오나요'],
#  ['보는내내', '그대로', '들어맞는', '예측', '카리스마', '없는', '악역'],
#  ['불알', '나와서', '당황', '아무튼', '영화', '중간', '끝나는', '느낌'],
#  ['평범함', '속', '녹아든', '평범한', '일상', '조금', '밋밋한게'],
#  ['보던거라',
#   '계속',
#   '보고있는데',
#   '전개도',
#   '느리고',
#   '주인공',
#   '인',
#   '은희',
#   '한두',
#   '컷',
#   '나오면서',
#   '소',
#   '극적',
#   '인',
#   '모습',
#   '짜증',
#   'ㅜㅜ',
#   '맨날',
#   '언제',
#   '끝나나',
#   '기',
#   '대만',
#   '하고',
#   '있어요',
#   '전개',
#   '빨리',
#   '빨리',
#   'ㅜㅜ'],
#  ['사랑', '하고', '싶게하는', '가슴속', '온', '감정', '을', '헤집어놓는', '영화', '예요', '정말', '최고'],
#  ['많은',
#   '사람',
#   '다큐',
#   '보고',
#   '우리나라',
#   '슬픈',
#   '현대',
#   '사의',
#   '단면',
#   '대해',
#   '깊이',
#   '생각',
#   '하고',
#   '사죄',
#   '하고',
#   '바로',
#   '잡기',
#   '위해',
#   '노력',
#   '했으면',
#   '합니다',
#   '말로',
#   '만',
#   '듣던',
#   '보도',
#   '연맹',
#   '그',
#   '민간인',
#   '학살',
#   '이정',
#   '일',
#   '줄',
#   '이야',
#   '이건',
#   '명백한',
#   '살인',
#   '입니다',
#   '살인자',
#   '다',
#   '어디',
#   '있나요'],
#  ['예전',
#   '작품',
#   '캐릭터',
#   '에피소드',
#   '재탕',
#   '삼',
#   '탕',
#   '사골',
#   '우려',
#   '먹듯',
#   '우리',
#   '고',
#   '내용',
#   '산',
#   '가고',
#   '시청률',
#   '아예',
#   '안',
#   '나오고',
#   '이제',
#   '회',
#   '중반',
#   '인데',
#   '부작',
#   '이라니'],
#  ['김남길',
#   '백',
#   '점',
#   '짜리',
#   '연기력',
#   '초반',
#   '몰입도',
#   '에도',
#   '불구',
#   '하고',
#   '지루하고',
#   '손예진',
#   'ㅈㅈ'],
#  ['재밌네', '비슷한', '영화', '안', '보신', '분', '한테', '재미있을', '듯'],
#  ['노래실력', '뽑는게', '맞냐', '박시환', '나가면', '진짜', '망신', '이다'],
#  ['일본', '영화', '다', '이런', '건가', '유치하다'],
#  ['이틀',
#   '만에',
#   '다',
#   '봤어요',
#   '재밌어요',
#   '근데',
#   '차',
#   '안',
#   '물건',
#   '넣어',
#   '조작',
#   '하려고',
#   '하면',
#   '차',
#   '안이',
#   '열려있다던지',
#   '집',
#   '안이',
#   '활짝',
#   '열려서',
#   '아무나',
#   '들어간다던가',
#   '문자',
#   '조작',
#   '하려고하면',
#   '비번',
#   '안',
#   '걸려있고',
#   'ㅋㅋㅋ',
#   '그런',
#   '건',
#   '억지스러웠는데',
#   '그래도',
#   '내용',
#   '자체',
#   '좋았어요'],
#  ['졸작'],
#  ['재밋네', '요', '달팽이', '빨', '라서', '더', '재밌었어요'],
#  ['어설픈', '전개', '어이없는', '결말'],
#  ['부패한',
#   '로마노프',
#   '왕조',
#   '기리',
#   '뭣같',
#   '영화',
#   '온몸',
#   '항거',
#   '했던',
#   '러시아',
#   '민중',
#   '그저',
#   '폭도',
#   '냐'],
#  ['내용', '전개', '무난', '편이였구', '보았습니다'],
#  ['매우', '실망'],
#  ['한국영',
#   '화',
#   '흥행',
#   '코드',
#   '갈등',
#   '갈등',
#   '계',
#   '속',
#   '갈등',
#   '화해',
#   '감동',
#   '평점',
#   '점',
#   '남발',
#   '흥행',
#   '뻔하지',
#   '뭐'],
#  ['아햏햏', '아햏햏', '아햏햏'],
#  ['뭐', '냐', '시작', '하고', '분만', '나왔다', '리플릿', '사진', '보며', '불안하더니만'],
#  ['단연', '최고', '라고', '할수있지'],
#  ['감독',
#   '럼',
#   '먹고',
#   '영화',
#   '만들었나보다',
#   '관객',
#   '에게',
#   '뭘',
#   '말',
#   '하는지도',
#   '모르겠고',
#   '엉망',
#   '진창',
#   '개',
#   '진창',
#   '이다'],
#  ['이건', '뭐', '냐', '우뢰매', '냐'],
#  ['정말', '쓰레기', '영화', '입니다'],
#  ['진정', '위대한', '영화', '최고', '임'],
#  ['별루', '였다'],
#  ['내일', '기대', '되는'],
#  ['근데', '조미', '막문위', '좋아한건', '가요'],
#  ['ㅋㅋㅋ', '진짜', '골깜', '눈', '부라릴', '때', '쓰러짐'],
#  ['성룡', '영화', '중', '최악', '인', '듯'],
#  ['골', '때리네', 'ㅋㅋㅋㅋ', '걸스데이', '이혜리', '되라'],
#  ['서기', '이뻐서'],
#  ['완전', '재밌어요', 'ㅋㅋㅋㅋㅋ', '백', '인공', '주귀', '여', '움', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['인상', '적', '인', '영화', '였다'],
#  ['어내스트', '셀레스틴', '완전', '강추', '에요', '정말', '재밌습니다'],
#  ['재미있는', '영화', '입니다'],
#  ['클라라', '볼라', '고', '화신', '본거', '아닌데'],
#  ['진짜', '보면서', '너무', '슬펐던', '영화', '다'],
#  ['설정', '재밌고', '새로운', '에피소드', '내', '에서', '메인', '스토리', '차차', '나오는게', '재밌음'],
#  ['신카이', '마코토', '작화', '미', '유', '하나', '카나', '연기', '해줘서', '더', '대박', '였다'],
#  ['재미없음', '진심', '이훨', '나', '캐스팅', '두', '못', '듯'],
#  ['잔잔한게', '생각', '보다', '볼', '만', '영화', '인거', '같습니다'],
#  ['감독', '님', '고은님', '쓰면', '영화', '안', '봅니다'],
#  ['무섭지도', '않았고', '스토리', 'ㅡㅡ'],
#  ['영화',
#   '속',
#   '억지스럽고',
#   '노골',
#   '적',
#   '인',
#   '술',
#   '광고',
#   '은은하고',
#   '센스',
#   '있게',
#   '했으면',
#   '어땠을까'],
#  ['킬링타임'],
#  ['크리스마스', '하면', '떠오르는', '영화'],
#  ['재미있게', '봤습니다', '매력', '적', '인', '행복', '이네', '요', 'ㅎㅎㅎ'],
#  ['음악', '완전히', '빠져서', '볼', '수', '있었던', '영화', '쫌', '산만하긴', '하던데'],
#  ['태어나서', '처음', '영화', '보다', '중간', '나왔습니다', '불륜', '로맨스', '냐'],
#  ['왕', '짜증', '아주', '전개', '짬뽕', '믹스', '했구나', '음향', '만', '무섭게', '하네하아'],
#  ['솔직히', '난', '별루더', '라', '시간', '낭비', '느낌'],
#  ['대박'],
#  ['시청률',
#   '기준',
#   '되는',
#   '패널',
#   '가구',
#   '머',
#   '하는거지',
#   '명작',
#   '드라마',
#   '다',
#   '망치',
#   '네',
#   'ㅡㅡ',
#   '내',
#   '다',
#   '서운하다'],
#  ['내용', '이상해'],
#  ['몬스터', '주식회사', '재밌게', '봤다'],
#  ['내용', '전개', '너무나', '느리다'],
#  ['소재', '흥미', '끌', '지만', '이야기', '전개', '투', '박해서', '몰입', '안되는군'],
#  ['절대', '보지마라', '쓰레기', '영화'],
#  ['중국인',
#   '특유',
#   '과장',
#   '허풍',
#   '있어',
#   '보이려고',
#   '안간힘',
#   '쓴',
#   '노력',
#   '가상하나',
#   '고증',
#   '현',
#   '실감',
#   '떨어지는',
#   '설정',
#   '거북',
#   '스럽다',
#   '도대체',
#   '그',
#   '왜',
#   '이렇게',
#   '까지',
#   '스스로',
#   '과대',
#   '포장',
#   '하',
#   '것',
#   '인지'],
#  ['그냥',
#   '불법체류자',
#   '때려',
#   '잡는',
#   '영화',
#   '면',
#   '좋았을텐데',
#   '무슨',
#   '우상화',
#   '만든다고',
#   '미국',
#   '따뜻한',
#   '설정',
#   '이건',
#   '뭥미'],
#  ['년', '삶속', '주인공', '생애', '전부', '드러난', '듯'],
#  ['별', '점점', '가자'],
#  ['별로', '다'],
#  ['본지', '꽤', '지난', '후', '남기지만', '재미있었음'],
#  ['아니', '게', '왜', '점', '대', '일까'],
#  ['년',
#   '지나',
#   '다시',
#   '보게',
#   '된',
#   '영화',
#   '다시',
#   '봐도',
#   '그',
#   '순수한',
#   '사랑',
#   '감동',
#   '숀펜',
#   '연기',
#   '또한'],
#  ['올레',
#   '공짜',
#   '로',
#   '있길래',
#   '봤음',
#   '헐',
#   '스토리',
#   '문제',
#   '아니라',
#   '연기자',
#   '전혀',
#   '배역',
#   '이랑',
#   '어울리지',
#   '않음',
#   '그리고',
#   '상대',
#   '배우',
#   '하고',
#   '다',
#   '따로',
#   '노는거',
#   '같음',
#   '이건',
#   '연기자',
#   '문제',
#   '있음',
#   '보아',
#   '진심',
#   '완전',
#   '별로',
#   '임',
#   '라미란',
#   '하고',
#   '아들',
#   '젤',
#   '볼',
#   '만',
#   '했음'],
#  ['너무', '욕심', '많았던', '영화', '어느', '쪽', '만이라도', '제대로', '보여줬다면'],
#  ['빵점'],
#  ['베댓', '말', '을', '아주', '잘써놨네'],
#  ['아주', '모자라진', '않다'],
#  ['영화', '도둑', '이나', '뫼비우스', '하고', '같은', '나라', '에서', '만들어졌다는게', '믿어지냐'],
#  ['온몸', '찌릿짜릿', '나', '두', '용기', '가져야지'],
#  ['정말', '재미있고', '교훈', '적', '인', '영', '화이', '네', '요'],
#  ['당시', '상황', '주제', '주입', '식이', '아닌', '긴장감', '있고', '재밌게', '전하', '작품'],
#  ['케이블', '에서', '그만', '나와', '줬으면'],
#  ['다르', '덴', '이냐', '리투', '차이밍량', '하나', '안', '섞인', '채', '짬뽕', '그릇', '담겨있다'],
#  ['여군',
#   '잼',
#   '없음',
#   '뭐',
#   '하는',
#   '건지',
#   'ㅡㅡ',
#   '잼',
#   '없음',
#   '엠비씨',
#   '다',
#   '잼',
#   '없음',
#   '질린다',
#   '이제'],
#  ['좋구나'],
#  ['한석규', '김혜수', '연기', '만', '돋보인', '영화', '어딘', '지', '모르게', '많이', '어설픈', '영화'],
#  ['솔직히',
#   '에볼라',
#   '바이러스',
#   '떠들',
#   '석',
#   '해',
#   '서',
#   '보게',
#   '된',
#   '영화',
#   '인데',
#   '작품',
#   '성',
#   '이나',
#   '어떤',
#   '면',
#   '에서도',
#   '여',
#   '년전',
#   '영화',
#   '라고',
#   '보기',
#   '엔',
#   '믿기',
#   '힘들',
#   '정도',
#   '로',
#   '정말',
#   '만들었다고',
#   '본다',
#   '마지막',
#   '후반',
#   '부가',
#   '살짝',
#   '아쉽긴',
#   '하지만',
#   '정도',
#   '면',
#   '수작',
#   '이라고',
#   '본다',
#   '시간',
#   '아깝지',
#   '않은',
#   '영화'],
#  ['볼', '만해'],
#  ['재미있다고', '허풍', '떨지', '마세요'],
#  ['용가리', '진짜', '짱짱맨', '이다'],
#  ['영화',
#   '이제',
#   '서야',
#   '보다니',
#   '감히',
#   '내',
#   '인생',
#   '최고',
#   '영화',
#   '중',
#   '하나로',
#   '꼽',
#   '을',
#   '수',
#   '있을만한',
#   '작품',
#   '어떻게',
#   '살',
#   '야할지',
#   '나를',
#   '위',
#   '고민',
#   '을',
#   '한번',
#   '더',
#   '하게',
#   '되는',
#   '시간',
#   '그리고',
#   '모건',
#   '프리',
#   '먼은',
#   '나이',
#   '들어도',
#   '여전히',
#   '섹시하다'],
#  ['작가',
#   '별로',
#   '다',
#   '내',
#   '용이',
#   '진짜',
#   '별로',
#   '임',
#   '맨날',
#   '그냥',
#   '기대',
#   '하고',
#   '재방송',
#   '하면',
#   '혹',
#   '시나',
#   '하고',
#   '봐줘도',
#   '답',
#   '없다',
#   '진짜'],
#  ['명작', '이런', '명작', '있을까', '싶다', '보고', '또', '봐도', '여운', '남는', '영화'],
#  ['진짜',
#   '조금',
#   '만',
#   '더',
#   '손',
#   '보면',
#   '왠만한',
#   '상업',
#   '영화',
#   '못',
#   '지',
#   '않게',
#   '퀄리티',
#   '쩔게',
#   '만들어',
#   '질',
#   '수',
#   '있었는데',
#   '아쉽네요',
#   '그래도',
#   '충분히',
#   '재미있었습니다',
#   '개인',
#   '적',
#   '조금',
#   '만',
#   '더',
#   '잔인하게',
#   '더',
#   '자극',
#   '적',
#   '노출씬',
#   '화끈하게',
#   '했더라면',
#   '어땠을까',
#   '하는',
#   '국산',
#   '영화',
#   '라',
#   '많이',
#   '아낀',
#   '듯',
#   '보임'],
#  ['그만', '끌', '고', '이제', '끝내', '라', '지겹다', '지겨워'],
#  [],
#  ['역시', '드니', '로', '연기', '일품', '나도', '맥스', '샘', '을', '죽이길', '바랬다'],
#  ['나름', '괜찮은', '작품', '입니다'],
#  ['너무', '좋은', '영화'],
#  ['정말', '실망', '스러웟음'],
#  ['배우',
#   '지네',
#   '안',
#   '뜨니까',
#   '이런',
#   '영화',
#   '찍을껀데',
#   '왜',
#   '안',
#   '뜨는지',
#   '진짜',
#   '모르는거야',
#   '면상',
#   '딱',
#   '보면',
#   '알겠구만',
#   '왜',
#   '지네',
#   '자신',
#   '모를까'],
#  ['어린이', '좋아할듯', '내', '어릴', '적', '동심', '멀리', '떠', '낫나보다'],
#  ['무술', '인', '왜', '총을드', '나'],
#  ['점'],
#  ['크리스토퍼', '왈츠', '타란티노', '조합', '이란'],
#  ['한국', '에선', '유명', '한편', '아니지만', '외국', '에선', '상상', '초월', '유명한', '영화', '입니다'],
#  ['오랜', '만', '재밋', '영화', '봤네요'],
#  ['종방',
#   '되어',
#   '아쉬워요',
#   '오늘',
#   '막',
#   '방도',
#   '봤어요',
#   '방송',
#   '대본',
#   '꽤',
#   '완성',
#   '있다는',
#   '느낌',
#   '받았고요',
#   '요즘',
#   '드라마',
#   '막장',
#   '지쳐있었는데',
#   '수백향',
#   '정말',
#   '바른',
#   '드라마',
#   '였던듯',
#   '해',
#   '요',
#   '악역',
#   '그리',
#   '심하게',
#   '어이없지도',
#   '않았고요',
#   '화이팅'],
#  ['평점',
#   '조절',
#   '위원회',
#   '에서',
#   '나왔습니다',
#   '웃음',
#   '김혜선',
#   '내일',
#   '오면의',
#   '김',
#   '순정',
#   '순',
#   '정이',
#   '역할',
#   '제일',
#   '이다',
#   '팜므파탈',
#   '로써',
#   '그',
#   '정도',
#   '까지',
#   '해낼',
#   '줄',
#   '정말',
#   '의외',
#   '였어',
#   '연기',
#   '년',
#   '사람',
#   '에게',
#   '요즘',
#   '사극',
#   '에서',
#   '벌어지고',
#   '있는',
#   '그녀',
#   '대한',
#   '연',
#   '기',
#   '논란',
#   '왠지',
#   '코미디',
#   '장면',
#   '같음',
#   '웃음'],
#  ['영화',
#   '끝',
#   '나갈',
#   '때',
#   '쯤',
#   '멍하다가',
#   '다',
#   '보고나면',
#   '한마디',
#   '나올거',
#   '임',
#   'ㅈ',
#   '같다'],
#  ['공유', '존잘', 'ㅎㅎㅎ'],
#  ['상쾌',
#   '발랄한',
#   '영화',
#   '다',
#   '말',
#   '하기',
#   '껄끄런',
#   '성',
#   '이란',
#   '소재',
#   '유쾌하게',
#   '해설',
#   '했다'],
#  ['소파', '죽', '치고', '앉아', '지켜', '볼', '이유', '없는', '작품'],
#  ['로큰롤'],
#  ['주된',
#   '타겟',
#   '어린이',
#   '니',
#   '일반',
#   '적',
#   '인',
#   '논리',
#   '통',
#   '하지',
#   '않는',
#   '건',
#   '알겠다',
#   '하지만',
#   '게임',
#   '흥미롭지',
#   '않고',
#   '요원',
#   '이라는',
#   '주인공',
#   '너무',
#   '무능력해서',
#   '별로',
#   '재미없다',
#   '배경',
#   '거슬린다'],
#  ['뮤지컬',
#   '영화',
#   '인데',
#   '사운드',
#   '녹음',
#   '엉망',
#   '남주는',
#   '춤',
#   '못',
#   '추고',
#   '내용',
#   '뻔할',
#   '뻔',
#   '주인공',
#   '목소리',
#   '너무',
#   '안',
#   '어울리고',
#   '어제',
#   '에서',
#   '뛰어',
#   '나가려다',
#   '참았습니다',
#   '진심',
#   '말리',
#   '고',
#   '싶습니다',
#   '영국',
#   '저',
#   '예산',
#   '용',
#   '영화',
#   '뮤지컬영화',
#   '아닙니다',
#   '맘마미아',
#   '안됨'],
#  ['어린나이에', '봤음에도', '꽤', '나', '좋아했던', '로맨틱코미디'],
#  ['게이물', '인', '줄', '모르고', '봤네'],
#  ['알바', '꺼', '저', '라'],
#  ['영화',
#   '머',
#   '임내가',
#   '왜',
#   '받아',
#   '봤을까',
#   '그것',
#   '알고싶다',
#   '영화',
#   '배우',
#   '스텝',
#   '감독',
#   '꼭두각시',
#   '였음'],
#  ['대라니', '최악'],
#  ['정말', '아름다운', '영화', '입니다'],
#  ['자극', '적', '인', '것', '익숙해진', '현대인', '봐도', '눈', '을', '떼기', '힘든', '연출', '력'],
#  ['뻑뻑', '읽어', '볼걸', '나도', '당했음'],
#  ['정말',
#   '짜증',
#   '극치',
#   '보여주는',
#   '영화',
#   '굉장히',
#   '언밸러스',
#   '느낌',
#   '뚱뚱하고',
#   '못',
#   '생긴',
#   '남자',
#   '애',
#   '발연기',
#   '시종일관',
#   '봐야하는게',
#   '고역',
#   '인',
#   '듯',
#   '간간히',
#   '흘러나오는',
#   '잔잔한',
#   '클래식',
#   '풍',
#   '음악',
#   '조차도',
#   '듣기',
#   '싫어',
#   '짜증날',
#   '정도',
#   '로',
#   '상당히',
#   '싫은',
#   '영화'],
#  ['감동', '감동', 'ㅜㅜ', '정말', '최고', '네', '요'],
#  ['별',
#   '점',
#   '주기도',
#   '아깝네요',
#   '얼마나',
#   '내용',
#   '진부한지',
#   '욕',
#   '밖에',
#   '안',
#   '나오네요',
#   '보고',
#   '재밌다고',
#   '하는',
#   '사람',
#   '초딩',
#   '인가요',
#   '죄송해요',
#   '너무',
#   '화가',
#   '나서',
#   '아무',
#   '것',
#   '볼',
#   '게',
#   '없습니다',
#   '보지',
#   '마세요',
#   '그냥',
#   '티비',
#   '판',
#   '짜집기',
#   '거',
#   '같네요'],
#  ['나', '왠만해서', '짜증', '안내는데'],
#  ['돼지',
#   '피',
#   '먹고',
#   '닭목',
#   '따는',
#   '장면',
#   '에선',
#   '우웩',
#   '역시',
#   '무당',
#   '아무나',
#   '하는게',
#   '아니다'],
#  ['버려'],
#  ['유치하고', '지루하고', '잠', '왔다'],
#  ['류', '풍', '판타지', '점', '만', '가져가'],
#  ['윤종신',
#   '복귀',
#   '좋았지만',
#   '이하늘',
#   '도대체',
#   '왜',
#   '뽑혔는지',
#   '알수가',
#   '없다',
#   '참가자',
#   '실력',
#   '을',
#   '따지기',
#   '심사',
#   '위원',
#   '인격',
#   '실력',
#   '부터',
#   '쌓고',
#   '오시길',
#   '어',
#   '하',
#   '어허',
#   '그만',
#   '하고요'],
#  ['광장', '작품', '옛날', '것', '보고', '싶다'],
#  ['내', '생', '최고', '영화'],
#  ['어린시절',
#   '너무',
#   '무섭고',
#   '재미있게',
#   '봤던',
#   '추억',
#   '판타지영화',
#   '절대',
#   '나쁜',
#   '짓은',
#   '금물',
#   '지옥',
#   '가요'],
#  ['기존',
#   '멜로영화',
#   '형식',
#   '을',
#   '탈피',
#   '하려고',
#   '하였으나',
#   '감정',
#   '절제',
#   '지나쳐',
#   '너무',
#   '담백한',
#   '영화'],
#  ['난',
#   '사랑비',
#   '서준',
#   '에게',
#   '쏙',
#   '빠져',
#   '버렸네',
#   '초',
#   '만에',
#   '쏙',
#   '난',
#   '절대',
#   '잊지도',
#   '않고',
#   '후회',
#   '도안',
#   '할거야'],
#  ['이영화',
#   '보',
#   '니까',
#   '교훈',
#   '을',
#   '주네',
#   '요',
#   '나도',
#   '남은',
#   '인생',
#   '을',
#   '화려하게',
#   '살아야겟다',
#   '말',
#   '밖에',
#   '안',
#   '나오네요'],
#  ['나름', '추억', '젖어', '들고', '좋았음', '아무', '생각', '없이', '가볍게', '보고오기', '추천', '요'],
#  ['단순한', '싸이코', '물', '을', '벗어난'],
#  ['게',
#   '년도',
#   '만들어진건',
#   '가요',
#   '아니면',
#   '예전',
#   '만든거',
#   '다시',
#   '개봉',
#   '건가',
#   '요',
#   'ㅠ',
#   '너무',
#   '허',
#   '접해',
#   '요',
#   'ㅠ'],
#  ['넘', '사랑스러운', '영화', '다', '보고', '연', '어', '봤다', '넘', '귀여워'],
#  ['청춘',
#   '영화',
#   '만이',
#   '줄',
#   '수',
#   '있는',
#   '감성',
#   '넘쳐',
#   '난다',
#   '순간',
#   '지나가면',
#   '다시',
#   '돌아오지',
#   '않을테지만',
#   '그',
#   '순간',
#   '만큼은',
#   '무한',
#   '할',
#   '젊음',
#   '줄',
#   '수',
#   '있는',
#   '그런',
#   '감성'],
#  ['용', '건담', '시리즈', '중', '에서', '아직', '까지도', '최고봉'],
#  ['개콘', '요즘', '갈수록', '코너', '다', '노잼', '이고', '웃음', '이안', '난', '다'],
#  ['사다코', '서린', '우물', '펀치', 'ㅜㅜ', '감동'],
#  ['후세',
#   '사랑',
#   '하게',
#   '된',
#   '결정',
#   '적',
#   '계기',
#   '그',
#   '시간',
#   '표현',
#   '되지',
#   '않았으며',
#   '시',
#   '람',
#   '생명',
#   '을',
#   '빼앗아야만',
#   '하는',
#   '이유',
#   '등',
#   '을',
#   '시',
#   '노',
#   '출현',
#   '하는',
#   '연극',
#   '으',
#   '로',
#   '더',
#   '알려주었으면',
#   '하는',
#   '생각',
#   '이든',
#   '다',
#   '또한',
#   '시',
#   '노',
#   '얼마나',
#   '본능',
#   '을',
#   '절제',
#   '히',
#   '면서',
#   '시',
#   '랑',
#   '을',
#   '하려고',
#   '노력',
#   '하는지를',
#   '더',
#   '보여줬다면',
#   '좋았을',
#   '뻔했다'],
#  ['새벽',
#   '시간',
#   '하는',
#   '일본',
#   '영화',
#   '전부',
#   '개',
#   '졸작',
#   '이다',
#   '일본',
#   '영화',
#   '원',
#   '래',
#   '다',
#   '이래'],
#  ['강수연', '나가있어', '그리고', '최정원', '신음', '신'],
#  ['정말', '김혜성', '너무', '예쁘네요', '이현진', '웃는', '거', '정말', '하'],
#  ['가발', '쓰고', '싶다'],
#  ['화려한', '여정', '이인상', '깊어요', '재밋어', '요', '배두나', '연', '기', '정말', '해요'],
#  ['대들을', '위', '성적', '호기심', '영화'],
#  ['감동', '적', '인', '영화'],
#  ['이건', '말', '필요', '없다', '그냥', '닥치고', '봐라'],
#  ['각기', '다른', '사람', '재밌고', '멋진', '사랑', '영화'],
#  ['역시', '미국드라마', '파워', '정말', '알수', '없는', '그', '미묘함까지', '사로잡아', '버렸다', '최고'],
#  ['너무', '너무', '훈훈하네요'],
#  ['거', '응답', '하라', '에서', '은지원', '원', '스스로', '욕', '하지', '않앗나', 'ㅋㅋㅋㅋ'],
#  ['너무', '웃기', '고', '배꼽', '빠질', '뻔했네', '내', '컴', '영화', '있는데'],
#  ['구성', '상당히', '부실한', '영화', '역시', '네이버', '평점', '믿을수', '없다'],
#  ['장끌', '로드', '몰락', '을', '가져온', '오우삼', '헐리우드', '작품', '중', '가장', '재미없었던', '졸작'],
#  ['언', '제적', '영웅본색', '연출', '인지', '현실', '성', '제로', '인', '영화'],
#  ['작은거',
#   '하나',
#   '에도',
#   '설레어',
#   '했던',
#   '학창시절',
#   '그때',
#   '그',
#   '느낌',
#   '을',
#   '다시',
#   '느껴',
#   '볼수있는',
#   '시간',
#   '이었다',
#   '장면',
#   '하나',
#   '하나',
#   '대사',
#   '하나',
#   '하나',
#   '배경음악',
#   '하나',
#   '하나',
#   '버릴게',
#   '없는',
#   '드라마'],
#  ['진심', '재미', '없는데', '너무', '평점', '높아서', '화남'],
#  ['더럽게',
#   '재미없다',
#   '어떤',
#   '형태',
#   '로',
#   '닿지',
#   '않는',
#   '허무하고',
#   '완벽히',
#   '지루한',
#   '영화',
#   '고',
#   '영양가',
#   '하나',
#   '없는',
#   '영화',
#   '다'],
#  ['이승기', '정말', '연기', '하는', '조연', '연기', '정말', '하고'],
#  ['현실', '꿈', '꿈', '현실'],
#  ['오늘', '현충일', '특집', '프로', '로', '보게', '되었습니다', '년도', '매우', '훌륭한', '작품', '입니다'],
#  ['판', '미로', '동', '급'],
#  ['제대', '하고', '보', '니까', '더', '재밌네요', 'ㅋㅋㅋㅋ'],
#  ['영화',
#   '보는것만으로도',
#   '마음',
#   '휴가',
#   '다녀온',
#   '느낌',
#   '소박하지고',
#   '잔잔하지만',
#   '지루하지',
#   '않은',
#   '그래서',
#   '다시',
#   '보고싶은',
#   '영화',
#   '햇살',
#   '가득한',
#   '비',
#   '이의',
#   '부엌',
#   '요리',
#   '인상',
#   '적'],
#  ['코믹', '건', '좋았는데', '짜임새', '너무', '허', '술', '하', '다'],
#  ['년',
#   '그때',
#   '당시',
#   '에는',
#   '우리',
#   '나라',
#   '이런',
#   '판타지',
#   '로맨스',
#   '없었다',
#   '아직도',
#   '신현준',
#   '황',
#   '장군',
#   '연기',
#   '음',
#   '괜찮네',
#   '한석규',
#   '성',
#   '시',
#   '대가',
#   '열린',
#   '영화',
#   '때',
#   '한석규',
#   '한테',
#   '뿅',
#   '갔었다'],
#  ['일단', '재생', '하면', '괴물', '같은', '서스펜스', '귀신', '같은', '흡입', '력'],
#  ['하진',
#   '짜',
#   '댓글',
#   '보고',
#   '한번',
#   '쯤',
#   '볼',
#   '만',
#   '영화',
#   '인거',
#   '같아서',
#   '봤지만',
#   '기',
#   '찬다이게',
#   '무슨',
#   '버킷리스트',
#   '인가',
#   '죽기',
#   '직전',
#   '소원',
#   '들어주기',
#   '내',
#   '가보기엔',
#   '죽기',
#   '직전',
#   '막',
#   '살자',
#   '인거',
#   '같다',
#   '감동',
#   '없고',
#   '진짜',
#   '버킷리스트',
#   '란',
#   '영화',
#   '발톱',
#   '때',
#   '만큼도',
#   '못',
#   '따라가는',
#   '쓰레기',
#   '영화',
#   '완존',
#   '실망'],
#  ['시간',
#   '밝고',
#   '긍정',
#   '적',
#   '인',
#   '드라마',
#   '보고',
#   '싶어서',
#   '보긴',
#   '보는데',
#   '오버',
#   '하',
#   '연기',
#   '거슬리네요',
#   '연기',
#   '인게',
#   '너',
#   '무표',
#   '나',
#   '요홍',
#   '혜정',
#   '역',
#   '이그',
#   '나',
#   '마도',
#   '후련',
#   '기도',
#   '하고',
#   '시원하고나',
#   '머',
#   '진다',
#   '답답하네요',
#   '낼',
#   '월요일',
#   '인데',
#   '해피',
#   '것',
#   '만',
#   '보고',
#   '싶네요'],
#  ['정치인', '모순', '인가', '정치범', '모순', '인가'],
#  ['어떻게', '이런', '상상', '을', '대단하다'],
#  ['어렵', '기도', '하고', '전쟁', '대한', '묘사', '모르겠다'],
#  ['일본',
#   '에서',
#   '주년',
#   '극장판',
#   '만드는데',
#   '우리나라',
#   '에선',
#   '주년',
#   '재개',
#   '봉하',
#   '니',
#   '이건',
#   'ㅄ',
#   '아님'],
#  ['대희', '개그콘서트', '본다고', '내', '전화', '끊음', '개그콘서트', '없애주세요', 'ㅡㅡ'],
#  ['물', '간', '동', '서양', '두', '배우', '싸움판'],
#  ['푸하하하', '거', '기대', '안', '했지만', '역시', '나', '구만'],
#  ['세계', '최초', '반공', '애니매이션', '이라는', '역사', '적', '가치', '있다'],
#  ['감각', '적', '인', '시각', '바라보는', '색다른', '느낌', '사랑', '문학', '적'],
#  ['엄마', '무고', '지', '딸', '을', '감옥살이', '시켜', '시켜', '이해', '안', '돼요'],
#  ['이영화',
#   '제발',
#   '책',
#   '을',
#   '보세여',
#   '감독',
#   '미친',
#   '겁니다',
#   '이따위',
#   '로',
#   '만들어놓고',
#   '화가',
#   '날',
#   '정도',
#   'ㅡㅡ'],
#  ['신나는', '흑인음악', '아이스', '큐브', '뿐', '남는게', '없다'],
#  ['드럽게', '재미없네', '시간', '돈', '이다', '내', '시간', '어쩔', '건데'],
#  ['그저', '한마디', '뿐', '알리시아'],
#  ['진짜', '생생하게', '느낄', '수', '있었다'],
#  ['재밌는데', '평점', '이상하다', '싶을', '정도', '로', '낮다'],
#  ['옥소리',
#   '프로필',
#   '사진',
#   '점',
#   '남기고',
#   '갑니다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '완전',
#   '대박',
#   '이다',
#   '진짜',
#   '아우',
#   '짜증나'],
#  ['드라마', '너무', '재밓당'],
#  ['진짜', '너무', '좋아요', 'ㅜㅜ', '짱짱'],
#  ['연기', '굿'],
#  ['이런', '영화', '다시는', '안', '나오겠지', '그때', '시절', '을', '나타내주었던거', '같아요'],
#  ['중간', '정도', '부터', '봤는데도', '꽤', '나', '대단하군요'],
#  ['콩', '까야', '제', '맛', '콩', '까야', '제', '맛'],
#  ['이적', '소설', '재미없다'],
#  ['액션영화',
#   '아니다',
#   '범죄',
#   '느와르',
#   '영화',
#   '다',
#   '허나',
#   '범죄',
#   '느와르',
#   '영화로서도',
#   '실패',
#   '작'],
#  ['뭔가', '알수', '없는', '매력', '빠져드는', '영화'],
#  ['모녀',
#   '토막',
#   '살해',
#   '살인자',
#   '부',
#   '성',
#   '애',
#   '라니',
#   '말',
#   '되나',
#   '감동',
#   '받은',
#   '사람',
#   '본인',
#   '피해자',
#   '되도',
#   '감동',
#   '받았다고',
#   '할수있을까',
#   '진심',
#   '묻고싶습니다'],
#  ['재밌는데', '평점', '왜', '이렇게', '구리지'],
#  ['기', '걸', '본', '내', '눈', '아깝다', 'ㅡㅡ', '진짜', '놔', '진짜', '기', '명작', '이네', '요'],
#  ['필름', '값', '아깝다', '재미', '더럽게', '없다', '점', '부터', '점', '수준', '것', '매미'],
#  ['또', '보고', '싶은데', '어디서', '보죠'],
#  ['영화', '재미있', '드', '만'],
#  ['남',
#   '주인공',
#   '연기력',
#   '안습',
#   '이네',
#   '요',
#   '혀',
#   '짧은',
#   '소리',
#   '듣기',
#   '너무',
#   '힘들었네요',
#   '매니저',
#   '역활',
#   '분',
#   '남',
#   '주인공',
#   '하는게',
#   '훨',
#   '좋았겠다는',
#   '생각',
#   '정도',
#   '영화',
#   '자체',
#   '적당히',
#   '볼',
#   '만',
#   '합니다'],
#  ['점', '딱', '액션', '스릴러', '인데', '액션', '스릴', '없다'],
#  ['완전', '스토리', '엉망', '이구', '완전', '비추', 'ㅜ'],
#  ['영화', '뭘', '전달', '하려는지', '모르겠네', '오글거리고'],
#  ['좋은', '영화'],
#  ['더빙', '이상해요', '할머니', '월', '래', '익숙한', 'ㄷㅔ'],
#  ['게', '편이', '나왔어'],
#  ['모든', '게', '씩', '다', '부족했다아니', '씩'],
#  ['정말', '말', '그대로', '쇼', '하는', '영화'],
#  ['년',
#   '봐서',
#   '기억',
#   '나질',
#   '않지만',
#   '진개',
#   '천카이거',
#   '감독',
#   '이름',
#   '세',
#   '자는',
#   '기억',
#   '해',
#   '두었던'],
#  ['정은지',
#   '언니',
#   '연기',
#   '하구',
#   '노래',
#   '부르시고',
#   '마지막',
#   '회',
#   '웃으면서',
#   '즐겁게',
#   '봤습니다',
#   '트로트',
#   '연인'],
#  ['게', '웃겨'],
#  ['망함'],
#  ['아이', '시선', '보는', '전쟁', '보는', '내내', '가슴', '먹', '먹', '했다는'],
#  ['사람',
#   '재미없다고',
#   '해서',
#   '레알',
#   '기대',
#   '안',
#   '했는데',
#   '생각',
#   '보다',
#   '볼',
#   '만',
#   '함',
#   '근데',
#   '여자애',
#   '랑',
#   '복',
#   '순이',
#   '랑',
#   '다투는',
#   '장면',
#   '그건',
#   '굳이',
#   '없어도',
#   '됐다고',
#   '생각',
#   '함',
#   '몰입도',
#   '겁나',
#   '없애고',
#   '어색',
#   '해보였음'],
#  ['설정', '연속극', '같은', '느낌', '든다', '하지만', '배우', '연기', '뛰어나다'],
#  ['여',
#   '주인공',
#   '인터뷰',
#   '할',
#   '때',
#   '지루해',
#   '죽는줄',
#   '알았음',
#   'ㅡㅡ',
#   '그냥',
#   '저',
#   '냥',
#   '킬링타임',
#   '용',
#   '스릴러'],
#  ['미',
#   '박스',
#   '오피스',
#   '위',
#   '그냥',
#   '몰아주기',
#   '하는',
#   '건가',
#   '어떻게',
#   '이런',
#   '영화',
#   '위',
#   '하지',
#   '옛날',
#   '년대',
#   '우뢰매',
#   '수준',
#   '물폭탄',
#   '싸움',
#   '이네',
#   '손',
#   '에서',
#   '빔나가나',
#   '손',
#   '에서',
#   '물폭탄',
#   '나가나',
#   '다를게',
#   '뭐',
#   '지'],
#  ['감독', '여자', '다', '보니', '기량', '많이', '딸리네'],
#  ['또', '보고', '또', '울었다'],
#  ['이런',
#   '영화',
#   '하나',
#   '개연',
#   '성',
#   '만',
#   '없어도',
#   '허무하게',
#   '만들어',
#   '버린다',
#   '조디',
#   '포스터',
#   '이쁜',
#   '모습',
#   '만',
#   '남',
#   '을',
#   '영화'],
#  ['굳', '굳'],
#  ['스토리',
#   '말',
#   '안되고',
#   '개막',
#   '장',
#   '사랑',
#   '이야기',
#   '아니예요',
#   '걸',
#   '보고',
#   '계신다면',
#   '당신',
#   '시간',
#   '돈',
#   '을',
#   '아낀거예요',
#   '휴',
#   '그래도',
#   '본다면',
#   '호구'],
#  ['네', '놈', '을', '살려', '두기', '엔', '쌀', '아까워', '세기', '명대사'],
#  ['평점',
#   '너무',
#   '높다',
#   '전혀',
#   '재미있지',
#   '않았다',
#   '쓸데없이',
#   '말',
#   '만',
#   '많음',
#   '이런',
#   '류',
#   '영화',
#   '조연',
#   '뒷받침',
#   '중요한데',
#   '조연',
#   '내용',
#   '자체',
#   '전혀',
#   '없음',
#   '또한',
#   '여배우',
#   '별로',
#   '매력',
#   '없었다',
#   '이틀',
#   '저스트',
#   '고',
#   '위드',
#   '잇의',
#   '애니스톤',
#   '을',
#   '보고',
#   '영화',
#   '봐서',
#   '그',
#   '런가',
#   '실망했음'],
#  ['맛깔', '나', '드라마'],
#  ['시베리아', '인가', '거기', '가서', '훈련', '할', '때', '나오는', '개', '작살'],
#  ['이건',
#   '시종일관',
#   '질질',
#   '왜',
#   '제목',
#   '야경',
#   '꾼',
#   '일지냐고',
#   '지금',
#   '회',
#   '넘어가는데',
#   '즉',
#   '달이',
#   '넘어가는데',
#   '앞',
#   '에서',
#   '누군가',
#   '얘기',
#   '하더만',
#   '거',
#   '부',
#   '작이냐고',
#   '그러다',
#   '또',
#   '순간',
#   '모든',
#   '걸',
#   '훅',
#   '진짜',
#   '지루함',
#   '지존'],
#  ['나이', '수록', '이해', '가는', '영화'],
#  ['슬픔'],
#  ['장면',
#   '개연',
#   '성도',
#   '없고',
#   '아역',
#   '연기',
#   '못',
#   '하고',
#   '무슨',
#   '추노',
#   '나오는',
#   '민폐',
#   '언',
#   '년',
#   '외국',
#   '판인줄',
#   '초반',
#   '만',
#   '그럴',
#   '싸한',
#   '저급',
#   '영화'],
#  ['영화', '정말', '별루', '예요', '결말', '이상해요'],
#  ['딱히', '재미', '없네요', '킁'],
#  ['송강호',
#   '정말',
#   '연기',
#   '하기',
#   '위해',
#   '태어났고',
#   '그로',
#   '인해',
#   '우리',
#   '즐거움',
#   '을',
#   '느낀다',
#   '역시',
#   '송강호',
#   '연기',
#   '파다'],
#  ['일본',
#   '영화',
#   '수입',
#   '금지',
#   '시절',
#   '에도',
#   '비디오',
#   '테이프',
#   '로',
#   '돌려',
#   '봤던',
#   '불후',
#   '명작',
#   '그립다'],
#  ['살인',
#   '을',
#   '소재',
#   '로',
#   '영화',
#   '토록',
#   '재밌을',
#   '줄',
#   '이야',
#   '살인',
#   '대한',
#   '감독',
#   '해석',
#   '정말',
#   '재치',
#   '있다',
#   '대',
#   '배우',
#   '님',
#   '들의',
#   '여',
#   '년전',
#   '모습',
#   '새롭웠',
#   '고',
#   '정말',
#   '유쾌하고',
#   '재밌다'],
#  ['누', '미', '라파스', '신봉선', '닮아서', '안', '본다'],
#  ['케이블', '에서', '그만', '재탕해라'],
#  ['멋졌다', '정말', '이지', '멋지다는', '말', '이외', '엔', '할', '말', '없다'],
#  ['년',
#   '어떻게',
#   '이런',
#   '영화',
#   '만들어졌는지',
#   '의문',
#   '당대',
#   '최고',
#   '영화',
#   '지금',
#   '봐도',
#   '퀄',
#   '에서',
#   '결코',
#   '떨어지지',
#   '않아요'],
#  ['지금', '거', '티비', '로', '돈', '내고', '보고있는', '내', '한심하다'],
#  ['쓰레기', '연예인', '재기', '장', '그러나'],
#  ['굿', '좋아'],
#  ['많은', '감동', '을', '준', '드라마', '이다'],
#  ['발',
#   '로만',
#   '든',
#   '영화',
#   '지진나서',
#   '주인공',
#   '넘어지는데',
#   '뒤',
#   '로',
#   '사람',
#   '유유',
#   '히',
#   '걸어다니고',
#   '있음',
#   '발',
#   '발연기',
#   '발',
#   '시나리오',
#   '내용',
#   '정말',
#   '뭐',
#   '같음',
#   'ㅋㅋㅋ'],
#  ['적당히', '해야지', '언제', '끝나는것인가'],
#  ['잊을', '수', '없는', '안개', '낀', '워터', '루', '다리', '마스코트'],
#  ['곤',
#   '사토시',
#   '감독',
#   '년',
#   '안타깝게',
#   '돌아가셔서',
#   '가슴',
#   '먹',
#   '먹',
#   '합니다',
#   '정말',
#   '천재',
#   '적',
#   '인',
#   '감독',
#   '인데',
#   '암',
#   '가시다니',
#   '이제',
#   '서',
#   '다시',
#   '봐도',
#   '모든',
#   '작품',
#   '대작'],
#  ['많은',
#   '생각',
#   '을',
#   '하게',
#   '됐습니다',
#   '예',
#   '뼈',
#   '지고',
#   '싶은',
#   '맘',
#   '있었지만',
#   '하면',
#   '독',
#   '이겠네요'],
#  ['츠무구', '만', '없어지면', '별', '개줄게'],
#  ['어릴',
#   '땐',
#   '조폭',
#   '영화로',
#   '알다',
#   '나이',
#   '들수록',
#   '게',
#   '인생',
#   '이구나',
#   '하고',
#   '뭉클해지는',
#   '영화',
#   '세상',
#   '을',
#   '살아가면',
#   '갈수록',
#   '닿는게',
#   '많아지네요',
#   '세상',
#   '비정하지만',
#   '비정함마',
#   '져도',
#   '따뜻해지는게',
#   '친구',
#   '라고'],
#  ['영상', '너무나도', '멋지다'],
#  ['비디오', '있어서', '봤는데', '년도', '인', '줄', '모를', '정도', '로', '만들었습니다', '긴장감', '있고'],
#  ['처', 'ㅝ', '주'],
#  ['년',
#   '만들어진것치곤',
#   '재밌음',
#   '영화',
#   '길어서',
#   '다듬었으면',
#   '소재',
#   '좋고',
#   '몰입',
#   '감도',
#   '기',
#   '대',
#   '이상',
#   '매끄럽지',
#   '못',
#   '부분',
#   '있지만',
#   '연기',
#   '둘',
#   '다',
#   '한듯'],
#  ['철',
#   '지난',
#   '조폭',
#   '코미디',
#   '뼈대',
#   '있는',
#   '가문',
#   '이야기',
#   '섞었지만',
#   '둘',
#   '다',
#   '지루하다',
#   '박정아',
#   '비롯',
#   '해',
#   '배우',
#   '보기',
#   '민망한',
#   '연기',
#   '펼치고',
#   '기억',
#   '남는',
#   '건',
#   '하나',
#   '없다'],
#  ['군더더기', '없이', '진행', '되는데', '재미', '없는게', '문제'],
#  ['심심해서',
#   '봤는데',
#   '재밌네요',
#   '탑',
#   '연기',
#   '못',
#   '할줄',
#   '알았는데',
#   '배우',
#   '포스',
#   '나고',
#   '잘하군요'],
#  ['고', '다미', '괜찮음'],
#  ['지대', '짜증', '아빠', '랑', '봣는데', '민망해', '죽는줄'],
#  ['점', '못', '주냐'],
#  ['빠순이', '영화', 'ㅋㅋㅋㅋㅋㅋㅋ', '훈훈하', '긔', '재밋쎠'],
#  ['최악', '애니메이션', '지루하고', '재미없고', '스토리', '마저', '진부하다'],
#  ['좋은', '의도', '와는', '다르게', '불쾌한', '표현', '법'],
#  ['줄리아', '로버츠', '귀여운', '연인', '거', '보다', '년전', '꺼', '다'],
#  ['신선하네'],
#  ['예술가',
#   '로써',
#   '사람',
#   '인생',
#   '당시',
#   '시대',
#   '적',
#   '상황',
#   '을',
#   '질',
#   '느낄',
#   '수',
#   '있었던',
#   '명작'],
#  ['관객수',
#   '너무',
#   '아쉬운',
#   '영화',
#   '베테',
#   '랑',
#   '보다도',
#   '더',
#   '류승완',
#   '감독',
#   '역작',
#   '이고',
#   '더',
#   '강한',
#   '악역',
#   '이다'],
#  ['한창', '핵', '펭귄', '남북', '거짓', '평화로', '국민', '을', '속', '이던', '때', '만들어진', '영화'],
#  ['지금', '티비', '에서', '하는데', '못', '보겠다'],
#  ['여자애', '명', '못', '해서', '몇', '명', '죽는거야', '답', '없다'],
#  ['성룡', '헐리웃', '작', '중', '단연', '최고', '지', 'ㅋㅋㅋ'],
#  ['안습'],
#  ['감독', '의도', '전혀', '알아차리지', '못', '했다'],
#  ['하나님',
#   '가정',
#   '을',
#   '온전히',
#   '만든다',
#   '진리',
#   '신분',
#   '이만',
#   '든',
#   '영화',
#   '눈',
#   '으로만',
#   '보지',
#   '말고',
#   '마음',
#   '봐라'],
#  ['편도', '나름', '흥미진진', '데', '핀', '헤드', '죽은게', '아쉬운', '점', '랄', '까'],
#  ['국산',
#   '코미디',
#   '영화',
#   '중',
#   '에서',
#   '난',
#   '신라',
#   '달밤',
#   '제일',
#   '좋았음',
#   '뭔가',
#   '푸근하고',
#   '따뜻함'],
#  ['최악', '이다', '영', '화보', '다가', '잠오긴', '첨', '임', '지루해', '둑', '을', '뻔'],
#  ['탄탄한', '배우', '될고', '머', '하는', '건지'],
#  ['영화',
#   '점점',
#   '끝',
#   '을',
#   '달려갈수록',
#   '몰입도',
#   '더',
#   '높아진',
#   '영화',
#   '이번',
#   '처음',
#   '이네',
#   '요'],
#  ['결국',
#   '감독',
#   '자신',
#   '하고',
#   '싶은',
#   '의견',
#   '을',
#   '지존파',
#   '핑계',
#   '삼아',
#   '하려고',
#   '듯',
#   '지존파',
#   '살인',
#   '정당화',
#   '하고',
#   '정부',
#   '탓',
#   '였다는',
#   '사회',
#   '탓',
#   '이라는'],
#  ['사실',
#   '여부',
#   '떠나',
#   '알',
#   '고',
#   '왔던',
#   '아더',
#   '너무',
#   '매칭',
#   '안',
#   '돼더라',
#   '원탁',
#   '기사',
#   '중',
#   '실제',
#   '검술',
#   '최고',
#   '수',
#   '랜슬롯',
#   '알',
#   '고',
#   '있는데',
#   '트리스탄',
#   '보다',
#   '못',
#   '하고',
#   '싸우는',
#   '검술',
#   '마치',
#   '중국',
#   '검술',
#   '흉내',
#   '낸거',
#   '같은게',
#   '그리고',
#   '란슬롯',
#   '실제',
#   '쌍',
#   '검였나',
#   '너무',
#   '매칭',
#   '안대',
#   '하',
#   '튼',
#   '기네',
#   '비어',
#   '역도',
#   '미스'],
#  ['대한민국', '영화', '수준', '평균', '치를', '하락', '시키기에', '충분한', '급', '영상', '물'],
#  ['점', '없나'],
#  ['재밌는데'],
#  ['재미없다', '기대', '완전', '했는데', '완전', '못', '함', '실망'],
#  ['종착역', '없는', '인생', '대유', '트레비스', '단지', '흘러간다'],
#  ['돈', '시간', '아까운', '영화'],
#  ['네러티브',
#   '하나',
#   '없는',
#   '예쁜',
#   '음악',
#   '동영상',
#   '취미',
#   '로',
#   '영화',
#   '만드는',
#   '것',
#   '걸',
#   '로',
#   '끝나길',
#   '하는',
#   '음악',
#   '올인',
#   '하길'],
#  ['배우', '연기', '좋았는데', '뭘', '말', '하려는', '건지'],
#  ['학위',
#   '위조',
#   '성범죄자',
#   '문',
#   '제자',
#   '만',
#   '모아서',
#   '영화',
#   '찍음',
#   '왜',
#   '그랬으까',
#   '제작비',
#   '아끼려',
#   '구',
#   '패자부활전',
#   '하냐'],
#  ['솔직히'],
#  ['완전', '재미있어요', '애', '보기', '알맞는듯'],
#  ['잔인하기도', '하고', '무서웠어요', 'ㅠ', '탑', '멋있더라구요'],
#  ['무섭지도', '않고', '기분', '만', '나쁘고', '쩝'],
#  ['군더더기', '없는', '깔끔한', '그러나', '강한', '메세지', '전달', '뜻밖', '참', '좋은', '영화'],
#  ['영화', '최고다', '그냥', '최고', '야', '그런', '줄', '알'],
#  ['그랜드', '부다페스트', '호텔', '시리즈', '같네', '캐스팅', '아까워'],
#  ['빨리', '감기', '해서', '봤음', '투자', '비는', '많이', '들었을', '것', '같은데', '영화사', '망했네'],
#  ['도대체',
#   '뭐',
#   '재밌다는',
#   '건지',
#   '모르겠네요',
#   '무슨',
#   '아이언맨',
#   '시리즈',
#   '개그',
#   '뛰어넘는다',
#   '하는데',
#   '어디서',
#   '웃어',
#   '야할지도',
#   '모르겠고',
#   '내용',
#   '뭔',
#   '지',
#   '뜬금',
#   '없는',
#   '히어로',
#   '놀이',
#   '또',
#   '뭔',
#   '지',
#   '왜',
#   '이렇게',
#   '평점',
#   '높은지',
#   '모르겠습니다'],
#  ['왜',
#   '극',
#   '을',
#   '끌어가는',
#   '중심',
#   '있는',
#   '캐릭터',
#   '있어야',
#   '하는지',
#   '알',
#   '게',
#   '된',
#   '영화',
#   '살인마',
#   '대적',
#   '하는',
#   '그리고',
#   '사건',
#   '을',
#   '해결',
#   '하는',
#   '인물',
#   '없고',
#   '그리고',
#   '왜',
#   '마지막',
#   '다',
#   '탈출',
#   '해놓고',
#   '나서',
#   '잡히고',
#   '죽임을',
#   '당하는지',
#   '이해',
#   '할수가',
#   '없다',
#   '대체',
#   '조달환',
#   '정유미',
#   '왜',
#   '나옴'],
#  ['진',
#   '짜',
#   '리얼',
#   '개',
#   '쓰레기',
#   '영화',
#   '다',
#   '보고',
#   '나면',
#   '정말',
#   '찝찝해지는',
#   '영화',
#   '절대',
#   '보지마'],
#  ['비록',
#   '로봇',
#   '이지만',
#   '점차',
#   '인간',
#   '감정',
#   '을',
#   '가지',
#   '고',
#   '자신',
#   '대해',
#   '고민',
#   '하면서',
#   '결국',
#   '인간',
#   '되어',
#   '죽는',
#   '앤드류',
#   '모습',
#   '내',
#   '봤던',
#   '영화',
#   '중',
#   '에서도',
#   '최고',
#   '감동',
#   '을',
#   '선사',
#   '영화'],
#  ['영구', '땡', '칠이', '시리즈', '레전드', '영화', '다'],
#  ['초딩',
#   '때',
#   '친척',
#   '형',
#   '비디오',
#   '로',
#   '빌려와',
#   '서',
#   '봤던',
#   '기억',
#   '난다',
#   '너무',
#   '재미',
#   '없었다',
#   '근데',
#   '나중',
#   '우연히',
#   '다시',
#   '보니',
#   '재밌더라',
#   '그',
#   '땐',
#   '왜',
#   '그렇게',
#   '재미',
#   '없었을까',
#   '년',
#   '면',
#   '내',
#   '초등학교',
#   '학년',
#   '때',
#   '니까',
#   '사촌형',
#   '당시',
#   '나름',
#   '최신',
#   '비디오',
#   '빌려',
#   '온거',
#   '같다'],
#  ['지루할만큼', '고요하고', '서글픈', '시', '선속', '머문', '깊은', '성찰', '사색'],
#  ['영화', '진짜', '보고', '펑펑', '울었습니다', '너무', '슬픈거', '같아요', 'ㅜㅜㅜ'],
#  ['누가', '더', '혀', '짧은가', '내기', '하면', '박빙', '일것', '같다'],
#  ['애', '둘', '딸린', '심은하', '그', '눈부신', '미모', '아름다운', '영상', '메인', '주제가'],
#  ['기',
#   '나오겠죠',
#   '아직',
#   '안',
#   '풀린',
#   '이야기',
#   '많은데',
#   '극장판',
#   '정말',
#   '시간',
#   '가는줄도',
#   '모르고',
#   '봤네요',
#   '역시',
#   '싸',
#   '패'],
#  ['개', '노잼', '뭔가', '스토리', '부족하고', '다', '이상함', '진짜'],
#  ['답', '없네', '뭐', '하는', '건지'],
#  ['절망',
#   '슬픔',
#   '속',
#   '에서도',
#   '자신',
#   '을',
#   '챙겨야만하는',
#   '삶',
#   '잔인함',
#   '을',
#   '거부',
#   '비참함에',
#   '대하',
#   '여'],
#  ['페이스', '허거', '같음', 'ㅋㅋㅋㅋㅋ'],
#  ['시간', '흘러도', '퇴색', '되지', '않는', '맛', '있는', '영화'],
#  ['진짜', '어마어마한', '여운', '을', '주는', '멜로', '영화', '에요'],
#  ['소',
#   '피',
#   '마르',
#   '소',
#   '와의',
#   '말',
#   '같지도',
#   '않은',
#   '불륜',
#   '내용',
#   '다',
#   '망침',
#   '물론',
#   '실제',
#   '역사',
#   '에는',
#   '그런',
#   '똥',
#   '같은',
#   '이야기',
#   '전혀',
#   '없었음',
#   '주인공',
#   '죽',
#   '을',
#   '때',
#   '공주',
#   '살이었음',
#   '한마디',
#   '만약',
#   '미국인',
#   '맞서',
#   '싸우는',
#   '아메리칸',
#   '원주민',
#   '자유',
#   '투쟁',
#   '기였으면',
#   '절대',
#   '아카데미상',
#   '못',
#   '받았음'],
#  ['훈훈하고', '따뜻한', '부정', '을', '느낄수', '잇', '엇음'],
#  ['잼'],
#  ['정말', '재미있게', '봤습니다'],
#  ['어딘가',
#   '에서',
#   '일어나고',
#   '일',
#   '일',
#   '것',
#   '같은',
#   '느낌',
#   '강하다',
#   '우베',
#   '볼',
#   '이런',
#   '영화',
#   '만드는',
#   '이유',
#   '누군가',
#   '실제',
#   '로',
#   '따라',
#   '했으면',
#   '하고',
#   '바라는것',
#   '같은데',
#   '정장',
#   '월',
#   '있는',
#   '애',
#   '보면',
#   '웃겠지'],
#  ['림프비즈킷',
#   '만',
#   '점',
#   '개봉',
#   '당시',
#   '극장',
#   '에서',
#   '봤는데',
#   '영화',
#   '내내',
#   '오우삼',
#   '쥑',
#   '이고',
#   '싶었던'],
#  ['견자단', '대박', '엽문', '시리즈', '계속', '된다'],
#  ['정말',
#   '오월',
#   '멜로',
#   '정말로',
#   '보고',
#   '보고',
#   '또',
#   '봐도',
#   '계속',
#   '보고싶은',
#   '영화',
#   '순위',
#   '순위',
#   '다',
#   '하',
#   '늦은',
#   '밤',
#   '이라',
#   '그런지',
#   '야릇한',
#   '느낌',
#   '들었다'],
#  ['흥미롭게', '봤어요', '여배우', '이쁘네요', '반했음'],
#  ['스토리', '액션', '그래픽', '머', '하나', '건질게', '없는', '망작', '그냥', '게임', '으로나', '즐기셔'],
#  ['그냥', '레전드', '다', '레전드'],
#  ['평론가',
#   '명치',
#   '겁나',
#   '때리고',
#   '싶다',
#   '정말',
#   '영화',
#   '재미없을거라',
#   '생각',
#   '했는데',
#   '재미',
#   '있고',
#   '내',
#   '인생',
#   '도움',
#   '가장',
#   '큰',
#   '영화',
#   '입니다',
#   '본인',
#   '깨달',
#   '고',
#   '싶으면',
#   '꼭',
#   '보세요',
#   '인생',
#   '을',
#   '바꿔줄',
#   '겁니다'],
#  ['키', '아누', '리브', '스', '최고', '액션', '영화'],
#  ['소재',
#   '아름다운',
#   '영화',
#   '다소',
#   '아쉬운',
#   '부분',
#   '있는',
#   '이유',
#   '영화',
#   '영화',
#   '스러운',
#   '극적',
#   '로맨스',
#   '보단',
#   '더',
#   '사실',
#   '적',
#   '남자',
#   '마음',
#   '시선',
#   '을',
#   '말',
#   '하고',
#   '싶었기',
#   '때문',
#   '아닐까'],
#  ['영화평론가', '아니지만', '좋았다', '한번', '보고', '마는', '영화', '아닌', '울림이있는', '영화'],
#  ['역시', '효느', '역시', '재밌다', 'ㅋㅋㅋ', '재탕', '중'],
#  ['대강'],
#  ['간첩', '색휘', '애쓴다', '밥', '먹고', '다니냐'],
#  ['검증', '된', '애', '출현', '시켜라', '이탈리아', '특집', '장난', '하냐'],
#  ['정말', '짜증나네', '절때', '보지말', '껄욕', '나옴'],
#  ['슬프다'],
#  ['최악', '환경', '속', '에서', '이런', '만화', '라도', '만든', '사람', '에게', '경의', '보낸다'],
#  ['여운', '엄청', '길게', '남는', '영화', '이이경', '을', '사랑', '하게하는', '영화'],
#  ['이딴', '게', '한국', '영화', '라니'],
#  ['짜가인가', '게뭐', '여', '뭔'],
#  ['굿', '이상', '가나다라'],
#  ['짱',
#   '이다',
#   '혼자',
#   '자식',
#   '키우며',
#   '살아온',
#   '엄마',
#   '그',
#   '의아',
#   '힘들게',
#   '살아오면서',
#   '서로',
#   '예민해지고',
#   '날카로워질',
#   '때',
#   '잇',
#   '엇',
#   '지만',
#   '결국',
#   '가족',
#   '아빠',
#   '라는',
#   '사람',
#   '생각',
#   '보다',
#   '최악',
#   '아니고',
#   '여자',
#   '확실히',
#   '요구',
#   '하면',
#   '도와준다는',
#   '그',
#   '말',
#   '왠지',
#   '짠하게와',
#   '닿는다',
#   '나',
#   '혼자',
#   '괜히',
#   '끙끙',
#   '거리',
#   '지',
#   '말',
#   'ㅡ',
#   '이런',
#   '단',
#   '순',
#   '생각',
#   '이든',
#   '다'],
#  ['별로', '고', '전개도', '별로', '고', '연기', '별로', '고', '한마디', '로', '재미없다'],
#  ['번', '지수', '잃고', '갈팡질팡'],
#  ['너무', '사랑스럽고', '감동', '적', '인', '영화', '정말', '좋앗어요'],
#  ['최고', '영화'],
#  ['년전',
#   '영활',
#   '다시',
#   '보니',
#   '공효진',
#   '코',
#   '평수',
#   '줄',
#   '이고',
#   '콧대',
#   '높였',
#   '네',
#   '완전',
#   '못',
#   '생겼어',
#   '호',
#   '권상우',
#   '화산고',
#   '때',
#   '왼쪽',
#   '팔자',
#   '심하더니',
#   '지금',
#   '사라지고',
#   '더',
#   '잘생겨졌고',
#   '장혁',
#   '멋지게',
#   '늙었네',
#   'ㅋㅋㅋ',
#   '다시',
#   '보니',
#   '웃겨'],
#  ['말랑말랑'],
#  ['공부', '열심히', '합시다', '공부', '안', '하면', '저런', '인생', '삽니다'],
#  ['그냥', '최고다'],
#  ['전쟁',
#   '이후',
#   '아픔',
#   '을',
#   '그린',
#   '영화',
#   '마지막',
#   '장면',
#   '압',
#   '권',
#   '유대인',
#   '줄',
#   '알',
#   '더럽게',
#   '여기',
#   '나',
#   '도움',
#   '필요하니',
#   '동행',
#   '했던',
#   '토마스',
#   '에게',
#   '더러운',
#   '유태인',
#   '이라고',
#   '말',
#   '장면',
#   '그러나',
#   '유대인',
#   '인척',
#   '사실',
#   '유대인',
#   '가족사진',
#   '을',
#   '보면서',
#   '미묘한',
#   '감정',
#   '을',
#   '사슴',
#   '인형',
#   '을',
#   '밟아까',
#   '며',
#   '대변',
#   '한다',
#   '므',
#   '찐',
#   '영화'],
#  ['오랜', '만', '동화', '다운', '동화', '본', '기분', '이다'],
#  ['감사합니다', '정말로', '감사합니다'],
#  ['둘다', '변태'],
#  ['샤넬', '인생', '성공', '아니라', '샤넬', '그', '남자'],
#  ['영화', '내용', '없다'],
#  ['십',
#   '수년',
#   '세월',
#   '을',
#   '찰나',
#   '순간',
#   '처럼',
#   '찰나',
#   '순간',
#   '을',
#   '영원한',
#   '기억',
#   '남기는',
#   '시간',
#   '상대성',
#   '이론',
#   '관',
#   '하여'],
#  ['니노', '이중인격', '연기', '두근거리네요'],
#  ['보다가', '울컥', '핫', '영화', '재미', '있고', '먼가', '감동', '적임'],
#  ['열정', '만으로', '돌진', '하고', '싶게', '만드는', '영화'],
#  ['연기력', '에서', '유혹', '하지', '못', '한다'],
#  ['난감하다', '재미', '없고', '세상', '을', '깜짝', '놀라게', '하는', '센세이션', '없다'],
#  ['아무리', '노력', '했어도', '차이나타운', '을', '대놓고', '베', '낀', '것', '용서', '안', '됨'],
#  ['신화', '화이팅', '에릭', '화이팅', '모두', '힘내요'],
#  ['엔딩', '넘', '슬퍼요'],
#  ['영화관', '가서', '보면', '더', '좋았을걸', '어린시절', '로', '돌아간', '느낌', '들어', '만', '감'],
#  ['정말', '최고', '였어요', '이민정', '씨', '신하균', '씨', '연기', '너무', '좋았어요'],
#  ['몇', '안되는', '재밌게', '본', '영화'],
#  ['교양',
#   '시간',
#   '보고',
#   '충격',
#   '먹은',
#   '영화',
#   '마지막',
#   '너무',
#   '슬펐다',
#   '빨갱이',
#   '라',
#   '소리',
#   '지르던',
#   '몬초',
#   '갑자기',
#   '다른',
#   '단어',
#   '말',
#   '건',
#   '선생님',
#   '대한',
#   '그리움',
#   '미안함',
#   '슬픔이었을까',
#   '몬',
#   '초가',
#   '마지막',
#   '울먹인거',
#   '같기도',
#   '하고'],
#  ['봤습니다'],
#  ['안',
#   '무서워',
#   '귀신',
#   '애기',
#   '라',
#   '그런',
#   '건',
#   '지',
#   '그냥',
#   '깜놀',
#   '하기만',
#   '할',
#   '뿐',
#   '이야'],
#  ['뭐', '하자는건', '쥐', '모든', '것', '다', '어설프고'],
#  ['배우', '따뜻한', '연기', '일상', '힘겨', '움', '을', '그리는', '현', '실감', '다', '좋았어요'],
#  ['남자배우', '정말', '미스캐스팅', '연기력', '안습', '조은숙', '김유미', '연', '기', '땜', '참고', '봤다'],
#  ['차',
#   '세계대전',
#   '피고',
#   '진',
#   '청춘',
#   '무기',
#   '기술',
#   '력',
#   '세기',
#   '전쟁',
#   '을',
#   '일으킨',
#   '정치인',
#   '전쟁',
#   '을',
#   '지휘',
#   '하는',
#   '고위',
#   '장교',
#   '생각',
#   '세기'],
#  ['책', '과는', '분명히', '다른', '시선', '괜찮네요'],
#  ['내',
#   '거',
#   '왜',
#   '봤지',
#   '싶은데',
#   '한예슬',
#   '이랑',
#   '김태희',
#   '나와서',
#   '본',
#   '듯',
#   '적월',
#   '개',
#   '쌤'],
#  ['솔직히', '점때', '뭐', '냐', '약간', '더러운', '장면', '만', '빼면', '정도', '다'],
#  ['이연서',
#   '님',
#   '신인',
#   '답지',
#   '않은',
#   '연기력',
#   '봤습니다',
#   '다음',
#   '작품',
#   '에서',
#   '또',
#   '뵙길',
#   '바랍니다'],
#  ['반전', '전부', '아닌', '영화', '몇', '번', '을', '봐도', '또', '보고', '싶은', '영화'],
#  ['피해자', '만', '있고', '피의자', '없는'],
#  ['개답답',
#   '먼',
#   '주인공',
#   '지',
#   '혼자',
#   '복수',
#   '못',
#   '함',
#   '주변',
#   '에서',
#   '해주길',
#   '바라는',
#   '민폐',
#   '녀',
#   '아직도',
#   '끌려다니고',
#   'ㅡㅡ'],
#  ['신선한', '소재', '화끈한', '액션', '스피디', '전개'],
#  ['영화',
#   '박자',
#   '디테',
#   '일이었다',
#   '정말',
#   '시가전',
#   '퀄리티',
#   '완벽했고',
#   '남자',
#   '사랑',
#   '대한',
#   '묘사',
#   '작',
#   '중',
#   '한석규',
#   '누군가',
#   '사랑',
#   '하는',
#   '마음',
#   '정말',
#   '디테',
#   '일이',
#   '대단했다',
#   '마지막',
#   '얘기',
#   '완',
#   '급',
#   '조절',
#   '완벽했다',
#   '영화',
#   '정말',
#   '멋졌다'],
#  ['탕웨이', '찡', '그녀', '만으로도', '점', '주기', '충분하다'],
#  ['감동', '적', '인', '영화', '다'],
#  ['당시', '대박', '쳤던', '영화', '괜찮다'],
#  ['억지스러운',
#   '시나리오',
#   '지루한',
#   '전개',
#   '편',
#   '보다',
#   '못',
#   '구성',
#   '등',
#   '편',
#   '안',
#   '나오는게',
#   '나았',
#   '다망',
#   '작',
#   '배우',
#   '영',
#   '화보',
#   '눈',
#   '없어서',
#   '안타깝다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋ', '반도', '안되는', '영화'],
#  ['영화', '평점', '높은', '이유', '모르겠어', 'ㅡㅡ'],
#  ['평생', '기억', '할만', '영화', '정상', '적', '인', '소재', '아니지만'],
#  ['요즘', '상황', '보고', '영화', '생각났다'],
#  ['많을',
#   '것',
#   '을',
#   '생각',
#   '하게',
#   '만드는',
#   '영화',
#   '입니다',
#   '마지막',
#   '사람',
#   '짐승',
#   '보이',
#   '고',
#   '아수라',
#   '사람',
#   '같아',
#   '보였습니다'],
#  ['진짜', '재미', '없는', '영화', '공통점', '스포츠영화', '군대', '영화', '자막', '나오는', '영화'],
#  ['로버트', '드니', '로', '광기', '복수', '연기', '만끽', '할수', '있는', '수작', '서스펜스', '스릴러물'],
#  ['감동', '감동', '감동', '도가니탕'],
#  ['세계',
#   '어디',
#   '서나',
#   '정치',
#   '경제',
#   '문화',
#   '사회',
#   '전반',
#   '걸쳐',
#   '변화',
#   '절실',
#   '상황',
#   '이지만',
#   '변화',
#   '가져올',
#   '방법',
#   '없다는게',
#   '함정',
#   '인',
#   '것',
#   '같다'],
#  ['귀여운', '벤지', '똑똑한', '벤지', '예쁘고', '귀여운', '친구', '압삘럽'],
#  ['당시', '개봉', '날', '보고', '울면', '서', '나왔다', '돈', '아까워서'],
#  ['정말', '최고', '영화'],
#  ['잔잔하게',
#   '숨막히는',
#   '영화',
#   '연출',
#   '대단하다',
#   '곳곳',
#   '숨어있는',
#   '복선',
#   '치밀하다',
#   '싶을',
#   '정도',
#   '로',
#   '섬세한',
#   '감정',
#   '표현',
#   '거기',
#   '김영애',
#   '연기',
#   '까지'],
#  ['시나리오',
#   '연출',
#   '연기',
#   '어느',
#   '것',
#   '하나',
#   '갖추지',
#   '못',
#   '시간',
#   '넘',
#   '아까운',
#   '억지',
#   '싸구려',
#   '중국',
#   '신파',
#   '경극'],
#  ['거부', '하는', '몸짓', '저', '하늘', '을'],
#  ['그만',
#   '빙빙',
#   '돌리고',
#   '밝혀지게',
#   '하면',
#   '안되나요',
#   '보려다',
#   '아직도',
#   '질질',
#   '끌어',
#   '짜증나안',
#   '봄',
#   '여기',
#   '서',
#   '또',
#   '사고',
#   '터져',
#   '또',
#   '질질',
#   '끌',
#   '면',
#   '진짜',
#   '짜증날듯',
#   '빨리',
#   '빨리',
#   '밝혀질건',
#   '밝혀지면서',
#   '반전',
#   '있든지',
#   '작가',
#   '님',
#   '드라마',
#   '사랑',
#   '하고',
#   '잼있는데',
#   '넘',
#   '끌어',
#   '짜증나요'],
#  ['졸면서',
#   '봤다',
#   '왜',
#   '이리',
#   '평정',
#   '높은',
#   '겨',
#   '내용',
#   '별거',
#   '없고',
#   '아오',
#   '감수성',
#   '영화',
#   '냐',
#   '거'],
#  ['기대하지', '않았던', '영화', '아름다', '움', '밀려온다', '꽤', '괜찮다았던', '영화'],
#  ['진짜',
#   '번만',
#   '더',
#   '이런',
#   '영화',
#   '상영',
#   '하면',
#   '용서',
#   '하지',
#   '않는다',
#   '지금',
#   '영화',
#   '보면서',
#   '카톡',
#   '하고',
#   '잇음',
#   '놔',
#   '진짜'],
#  ['살아는', '있지만', '생동감', '을', '잃은', '박물관'],
#  ['노땅', '한심한', '추억', '미화'],
#  ['어릴', '적', '눈물', '흘리며', '웃던', '기억', '간신히', '찾아', '다시', '봤네요'],
#  ['인종차별', '유괴', '라는', '두', '주제', '불협화음'],
#  ['고명환',
#   '연기',
#   '쩌',
#   '냐',
#   '아니면',
#   '돈',
#   '없어',
#   '쓴거냐',
#   '후자',
#   '라면',
#   '볼가치가',
#   '없는',
#   '영화'],
#  ['속편',
#   '에서는',
#   '주인공',
#   '전작',
#   '처럼',
#   '앨빈',
#   '밴드',
#   '였으면',
#   '좋았을것',
#   '같다',
#   '캐릭터',
#   '추가',
#   '로더',
#   '이상해진듯'],
#  ['혼자', '보긴', '너무', '아깝다', '년', '올해', '영화'],
#  ['마지막', '결투', '씬', '최고', '폭풍눈물', '팝핀현준', '할아버지', 'ㅋㅋㅋ'],
#  ['ㄵ', '점', '대'],
#  ['좋아', '상술', '최고', '아니', '선거', '술', '최고'],
#  ['쓰레기', '함부로', '버리지', '맙시', '다'],
#  ['글쎄', '나', '와는', '안', '맞는', '성향', '영화', '중', '하나', '들을', '만', '함'],
#  ['즐'],
#  ['막장',
#   '재미',
#   '있어야',
#   '보지',
#   '재미',
#   '없고',
#   '짜증',
#   '만',
#   '남',
#   '남녀',
#   '주인공',
#   '어울리면',
#   '참고',
#   '보겠는데',
#   '진짜',
#   '안',
#   '어울리고',
#   '웬만하면',
#   '다',
#   '재밌게',
#   '보는데',
#   '진짜',
#   '내',
#   '가본것',
#   '중',
#   '제일',
#   '최악',
#   '였음',
#   '무',
#   '튼',
#   '주인공',
#   '부터',
#   '시작',
#   '해서',
#   '성격',
#   '개',
#   '이상함',
#   '조',
#   '기',
#   '종영',
#   '답',
#   '이다'],
#  ['줄리', '델피', '나이', '들수록', '멋지다'],
#  ['내', '본', '일드', '중', '쵝오'],
#  ['역시', '명작', '명작', '이다'],
#  ['글쎄요', '뭐랄까', '영화', '제목', '을', '잘못', '보고', '착각', '내', '잘못', '랄', '까'],
#  ['그냥',
#   '기독교',
#   '영화',
#   '네',
#   '요',
#   '더',
#   '깊이',
#   '있는',
#   '내용',
#   '을',
#   '기대했는데',
#   '실망',
#   '입니다',
#   '영화',
#   '뭔가',
#   '엉',
#   '성해',
#   '요'],
#  ['그냥',
#   '책',
#   '읽는게',
#   '더',
#   '절절',
#   '하게',
#   '다가온다',
#   '영화',
#   '내용',
#   '을',
#   '너무',
#   '비약',
#   '하고',
#   '삭제',
#   '해서',
#   '행간',
#   '을',
#   '잃어버렸다',
#   '책',
#   '에서',
#   '꽉',
#   '찼었던',
#   '느낌',
#   '반대',
#   '로',
#   '모든',
#   '것',
#   '엉',
#   '성하다'],
#  ['너무나', '감동', '적', '인', '영화'],
#  ['스킨헤드', '성', '님', '들이', '영화', '싫어합니다'],
#  ['자동차', '매니아', '인', '나', '평점', '점', '이하', '속', '았', '다', '아오'],
#  ['나', '거', '보고', '인형', '절', '대안', '삼'],
#  ['정체', '성은', '사치', '인가'],
#  ['나이',
#   '먹은',
#   '아저씨',
#   '일찐',
#   '놀이',
#   '하는',
#   '영화',
#   '개',
#   '역겹다',
#   '알바',
#   '풀었냐',
#   '현',
#   '실감',
#   '개',
#   '진짜',
#   '개제',
#   '로'],
#  ['남극', '왔는데', '그만', '길', '을', '잃었다', '오르지', '못', '할', '곳', '오르는', '것', '아니다'],
#  ['재밌음', '귀엽고', '신남'],
#  ['포스터',
#   '진심',
#   '개',
#   '쩐다',
#   '엑소시스트',
#   '능가',
#   '하는',
#   '공포물',
#   '같지만',
#   '실상',
#   '처키',
#   '보다',
#   '못',
#   '영화'],
#  ['시청률', '개뿔', '존나', '재미없어', '제보', '니', '사극', '너무', '못', '만', '드', '네'],
#  ['요즘', '재방', '보는데', '넘', '재밌는데', '왜', '시청률', '저조했을까', '싶네요', '둘다', '귀요미'],
#  ['연출',
#   '연기',
#   '영상',
#   '아름다운',
#   '영화',
#   '입니다',
#   '저예산영화',
#   '인',
#   '관계',
#   '로',
#   '스펙',
#   '타',
#   '클은',
#   '부족하지만',
#   '한국',
#   '영화계',
#   '새로운',
#   '바람',
#   '희망',
#   '다크호스',
#   '될것',
#   '임',
#   '을',
#   '믿습니다',
#   '많은',
#   '응원',
#   '부탁드리고',
#   '벌써',
#   '부터',
#   '일찍',
#   '관람',
#   '해주',
#   '신분',
#   '진심',
#   '감사합니다'],
#  ['평점',
#   '왜',
#   '이렇게',
#   '낮지난',
#   '거',
#   '또',
#   '다운',
#   '받고있다',
#   '번',
#   '째',
#   '정말',
#   '잼있던데',
#   '끝',
#   '견자단',
#   '하고',
#   '대',
#   '빵',
#   '하고',
#   '싸울',
#   '땐',
#   '정말',
#   '가슴',
#   '뜨거워졌다난',
#   '정말로',
#   '잼있게',
#   '봤다',
#   '최근',
#   '댓글',
#   '이니',
#   '내',
#   '알바',
#   '아닌줄은',
#   '알거다'],
#  ['게', '어떻게', '평점', '낮을수가', '있지'],
#  ['블랙코미디',
#   '조롱',
#   '대상',
#   '우린',
#   '데',
#   '기분',
#   '드러워서',
#   '점수',
#   '주겠냐',
#   '성기',
#   '노출',
#   '등',
#   '어그',
#   '로나',
#   '끌고서는',
#   'ㅉㅉ'],
#  ['촌',
#   '동네',
#   '조폭',
#   '삼류',
#   '영화',
#   '가끔',
#   '씩',
#   '툭툭',
#   '미는',
#   '유머',
#   '영',
#   '쌩뚱',
#   '맞구',
#   '촌스럽기까지'],
#  ['점', '만들기'],
#  ['스타', '뎀', '형님', '얼굴', '먹', '칠', '을', '영화'],
#  ['헐', '남자', '몸매', '보면', '기분', '좋나'],
#  ['안',
#   '봐도',
#   '별',
#   '점',
#   '한개',
#   '주고싶은',
#   '류',
#   '영화',
#   '같다',
#   '심형래',
#   '아저씨',
#   '동',
#   '급',
#   '감독',
#   '인',
#   '듯',
#   'ㅋㅋㅋ'],
#  ['정말', '완벽했다', '최고', '영화', '중', '꼽히는', '영화'],
#  ['조잡하고',
#   '유치한',
#   '저',
#   '예산',
#   '류',
#   '급',
#   '영화',
#   '다',
#   '스토리',
#   '깊이',
#   '감도',
#   '없고',
#   '전체',
#   '적',
#   '루즈'],
#  ['진짜',
#   '뭐',
#   '냐',
#   '민국이',
#   '나',
#   '지아',
#   '더빙',
#   '더',
#   '이상',
#   '시키면',
#   '안되겠네',
#   '더빙',
#   '얼마나',
#   '중요한데',
#   '이런',
#   '애',
#   '을',
#   '시켜',
#   '데뷔',
#   '도안',
#   '애',
#   '을',
#   '연예인',
#   '이해도',
#   '뭐라고하는',
#   '판'],
#  ['그냥', '재미', '없어요'],
#  ['쇼', '해', '라', '쇼'],
#  ['중심', '약하니', '언', '저리', '가지', '고', '무리한', '승부', '수', '띄운다'],
#  ['주', '연', '배우', '이름', '만', '기억', '남'],
#  ['그냥', '안', '보는게', '이득'],
#  ['키', '기키', '기키', '기키', '기키', '기'],
#  ['박얘쁜', '빠수니', '죄다', '없어져', '버려'],
#  ['진짜', '짜증나는', '영화'],
#  ['불',
#   '보이지',
#   '않고',
#   '사람',
#   '죽어',
#   '나갈',
#   '때',
#   '엄청난',
#   '웅장',
#   '음악',
#   '만',
#   '나오고',
#   '전혀',
#   '마음',
#   '닿지',
#   '않는',
#   '설정'],
#  ['망작'],
#  ['상당히', '재밌게', '봤습니다'],
#  ['내', '코끼리', '내놔가', '더', '재밌음'],
#  ['코믹', '코믹', '봐라', '패러디', '하고', '카메오', '들보', '재미', '있다'],
#  ['유치',
#   '짬뽕',
#   '이네',
#   '딱',
#   '초등',
#   '학년',
#   '영화',
#   '다',
#   '초등학교',
#   '자녀',
#   '있는',
#   '가족',
#   '분',
#   '께',
#   '추천',
#   '함'],
#  ['후속', '지금', '이라도', '나와라', '한국', '애니', '살려', '보자'],
#  ['통해', '봤는데', '정말', '재밌게', '봤어요', '요', '근래', '본', '영화', '중', '최고', '인', '듯'],
#  ['기대', '않고', '봤는데', '찰지게', '만든', '토종', '느와르', '네', '흥미진진'],
#  ['성인영화', '가족영화', '로', '만', '드려하는', '멍청한', '자막', '제작자', '마음', '안', '들어서', '점'],
#  ['일본인', '특유', '어색한', '연기', '여', '주인공', '연기', '너무', '못', '해'],
#  ['전반',
#   '적',
#   '무거운',
#   '느낌',
#   '영화',
#   '네',
#   '요',
#   '가비',
#   '의향',
#   '맛',
#   '처럼',
#   '씁쓸함이',
#   '느껴집니다',
#   '장윤현',
#   '감독',
#   '님',
#   '께서',
#   '커피',
#   '부분',
#   '관해',
#   '신경',
#   '을',
#   '쓰시',
#   '다',
#   '보니',
#   '연출',
#   '부분',
#   '있어서',
#   '미흡하지',
#   '않았나싶고',
#   '배우',
#   '연기력',
#   '괜찮았습니다'],
#  ['전작', '보다', '재밌다', '배우', '내용', '모두', '세련됨'],
#  ['진지하고', '무거운', '소재', '경쾌하고', '재미있게', '만들었다'],
#  ['유럽', '작품', '상', '탈', '만', '유럽', '중요한', '얘기', '또한', '픽션'],
#  ['풍', '정정은', '어케된거', '지', 'ㅋㅋㅋ', '과도', '압축', '개연', '성', '없지만', '배우', '호화로워서'],
#  ['이영화',
#   '구성',
#   '좋다는',
#   '분',
#   '아마',
#   '친구',
#   '랑',
#   '같이',
#   '영',
#   '화보',
#   '고',
#   '님들',
#   '영화',
#   '좋다고',
#   '재밌다하면',
#   '같',
#   '이본',
#   '친구',
#   '이해',
#   '하지',
#   '못',
#   '할',
#   '겁니다',
#   '진짜',
#   '최악',
#   '최저',
#   '스토리',
#   '주인공',
#   '행동',
#   '개연',
#   '성',
#   '없음',
#   '캐릭',
#   '간',
#   '이해관계',
#   '최악',
#   'ㅋㅋㅋ',
#   '갘',
#   '이렇게',
#   '허',
#   '접하게',
#   '표현',
#   '된',
#   '영화',
#   '간만',
#   '이라',
#   '능'],
#  ['젠', '그만', '보고', '싶은', '막', '돼', '먹은', '스토리텔링'],
#  ['말',
#   '필요',
#   '없다',
#   '로맨스',
#   '싫어하는',
#   '내',
#   '봤을',
#   '때',
#   '기절',
#   '할',
#   '것',
#   '같았어',
#   'ㅜㅜㅜㅜ'],
#  ['제',
#   '취향',
#   '적',
#   '이고',
#   '우울한',
#   '마음',
#   '을',
#   '완전히',
#   '날려',
#   '버리고',
#   '슬픈',
#   '내용',
#   '을',
#   '본',
#   '뒤',
#   '마음',
#   '을',
#   '정화',
#   '시켜주네요'],
#  ['영상', '미가', '역시', '최고', '네', '요'],
#  ['끙'],
#  ['역시', '한국영', '화', '보지말아야', '돼'],
#  ['괜찮은', '영화'],
#  ['요즘', '재밌음'],
#  ['소재',
#   '참',
#   '좋아서',
#   '삼',
#   '점',
#   '준다',
#   '제작',
#   '된',
#   '영화',
#   '공포',
#   '스릴러',
#   '아닌',
#   '본분',
#   '을',
#   '잊은',
#   '드라마',
#   '아닌',
#   '드라마',
#   '같은',
#   '느낌',
#   '이다',
#   '연기',
#   '연출',
#   '괜찮았다',
#   '다만',
#   '시작',
#   '부터',
#   '끝',
#   '까지',
#   '지루할',
#   '뿐',
#   '이다',
#   '또',
#   '어떤',
#   '장면',
#   '살짝',
#   '유치했다'],
#  ['남자', '인데', '보는내내', '울었다', '딸', '낳으면', '해줘야지'],
#  ['안타까울', '뿐', '안타까울', '뿐'],
#  ['영웅', '사람', '원하기', '때문', '만들어지는', '또다른', '희생', '다'],
#  ['그냥', '평작', '욕', '까진', '안', '나오고'],
#  ['극',
#   '장가',
#   '서',
#   '안',
#   '본',
#   '내',
#   '머리',
#   '깨',
#   '버리고싶네요',
#   '제',
#   '인생',
#   '최고',
#   '영홥니',
#   '다',
#   '키이라',
#   '작품',
#   '중',
#   '에서도',
#   '최고',
#   '일듯',
#   '알럽키',
#   '이라'],
#  ['중고생', '마마', '추어', '포르노'],
#  ['비디오', '물이', '냐', '동시', '상', '영물', '이냐', '넌', '정체', '모', '냐'],
#  ['이건', '말로', '설명', '할', '수', '없는', '유치함이다', '진짜', '필름', '아깝다'],
#  ['이승연', '강렬함이', '묻어나는', '영화', '그러나', '홍경인', '너무', '불쌍하게', '나옴'],
#  ['드릴', '브라', '에서', '뿜었다'],
#  ['부족한',
#   '영화',
#   '아닌',
#   '부족한',
#   '영화',
#   '감동',
#   '있다길래',
#   '참고',
#   '끝',
#   '까지',
#   '다',
#   '봤는데',
#   '진심',
#   '이렇게',
#   '재미없다고',
#   '느끼는건',
#   '처음'],
#  ['계몽영화', '한계', '고스', '란', '답습', '한다'],
#  ['우와', '정말', '오랜', '만', '통쾌하게', '웃었네요', '내일', '기대', '됩니다'],
#  ['청춘', '에는', '마침표', '없다'],
#  ['세얼간이',
#   '아줌마',
#   '나와서',
#   '한번',
#   '본건데',
#   '실망',
#   '신선한',
#   '반전',
#   '을',
#   '주고싶었나',
#   '본데',
#   '개연',
#   '성도',
#   '없구',
#   '뭐',
#   '이런'],
#  ['좋은', '소재', '만족할', '연출'],
#  ['심혜진', '나와서', '겨우', '저', '정도', '라니', '실망', '이다'],
#  ['아들',
#   '놈',
#   '끝',
#   '까지',
#   '아빠',
#   '한테',
#   '미안한',
#   '감정',
#   '없어',
#   'ㅠ',
#   '소재',
#   '신선했는데',
#   '영화',
#   '자체',
#   '메시지',
#   '모호하고',
#   '스토리',
#   '짜임새',
#   '있지',
#   '않은',
#   '것',
#   '같다'],
#  ['창업',
#   '을',
# ...
#   '내',
#   '가본',
#   '영화',
#   '중',
#   '이영화',
#   '내',
#   '생애',
#   '최고',
#   '영화',
#   '였던것',
#   '같다'],
#  ['천녀유혼', '비', '하면', '뭐라', '표현', '하기', '힘든', '퀭', '영화'],
#  ['불륜',
#   '을',
#   '미화',
#   '영화',
#   '남은',
#   '사람',
#   '어쩌라고',
#   '또',
#   '돈',
#   '걱정',
#   '따위',
#   '안',
#   '하는',
#   '사람',
#   '이야기',
#   '공감',
#   '하',
#   '라고',
#   '강요',
#   '하는',
#   '영화',
#   '음악',
#   '이랑',
#   '영상',
#   '미로',
#   '점'],
#  ['최고다', '이란', '노래', '원', '곡', '보다', '영화', '속', '노래', '훠', '얼씬', '좋아요'],
#  ['소재', '굉장히', '신선했다'],
#  ['내사', '랑', '키', '아누', '리브', '스'],
#  ['두',
#   '말',
#   '할',
#   '나위',
#   '없이',
#   '최고',
#   '작품',
#   '인생',
#   '대해',
#   '서',
#   '생각',
#   '해보게',
#   '하는',
#   '깊이',
#   '있는',
#   '영',
#   '화전',
#   '출연',
#   '진과',
#   '제',
#   '작',
#   '진',
#   '에게',
#   '큰',
#   '박수',
#   '보낸다'],
#  ['솔직히', '산만', '하기만', '했다'],
#  ['말', '필요없지', '성룡', '영화', '에선', '무언가', '다른', '것', '을', '느낄수있다'],
#  ['화학',
#   '을',
#   '해서',
#   '그런지',
#   '잼',
#   '잇게',
#   '봣습니닼',
#   '옆',
#   '친구',
#   '중간',
#   '중간',
#   '노',
#   '이해',
#   '나중',
#   '해석',
#   '잼잇엇숩니',
#   '다'],
#  ['아직',
#   '준비',
#   '되지',
#   '않는',
#   '젊은',
#   '영화인',
#   '여',
#   '함부로',
#   '장편',
#   '손대지',
#   '마라천',
#   '천히',
#   '공부',
#   '하고',
#   '나와라'],
#  ['으',
#   '엉',
#   '간만',
#   '추억',
#   '돋아서',
#   '봤는데',
#   '사실',
#   '원작',
#   '자체',
#   '두서',
#   '없이',
#   '전개',
#   '되는데',
#   '영화감독',
#   '내용',
#   '앞뒤',
#   '없이',
#   '막',
#   '잘라서',
#   '정신',
#   '없음',
#   'ㅇ',
#   '배우',
#   '책',
#   '읽고',
#   '특히',
#   '대사',
#   '그대로',
#   '살린거',
#   '오그리오',
#   '그',
#   '링',
#   'ㅋㅋㅋ',
#   '간만',
#   '소설',
#   '로',
#   '읽어야지'],
#  ['개', '쓰레기', '같은', '것', '감히', '파라', '노말', '엑', '티비', '티', '팔', '먹냐'],
#  ['기억', '조작', '되기', '마련', '그', '사람', '아니고서는', '함', '부러', '말', '하지', '말'],
#  ['재밌게',
#   '봤습니다',
#   '그저',
#   '문헌',
#   '적힌',
#   '문란한',
#   '사도세자',
#   '아닌',
#   '정조',
#   '아버지',
#   '로서',
#   '그',
#   '그릇',
#   '어느',
#   '정도',
#   '였는지',
#   '보여준',
#   '작품',
#   '아니었나',
#   '싶네요',
#   '시나리오',
#   '시나리오',
#   '지만',
#   '배우',
#   '연기',
#   '일품',
#   '이었습니다'],
#  ['휴일',
#   '낮',
#   '침대',
#   '누워서',
#   '티비',
#   '보다',
#   '영화',
#   '채널',
#   '에서',
#   '틀어주길래',
#   '어쩔',
#   '수',
#   '없이',
#   '봤는데',
#   '나중',
#   '에는',
#   '벌떡',
#   '앉아서',
#   '봤던',
#   '영화',
#   '완전',
#   '몰입',
#   '되고',
#   '나름',
#   '스토리',
#   '치밀하고',
#   '해리슨',
#   '포드',
#   '다운',
#   '액션',
#   '좋습니다',
#   '저',
#   '영화광',
#   '영화',
#   '평론가',
#   '아니고',
#   '영화',
#   '자주',
#   '보는',
#   '일반',
#   '남자',
#   '사람',
#   '임'],
#  ['절제', '미학', '아니라', '지루함', '극치', '되', '버린', '안타', '갑다'],
#  ['영화관', '에서', '보기', '엔', '돈', '아까웠다', '솔직히', '재미없었다', 'ㅜㅜ'],
#  ['인간',
#   '솔직함을',
#   '보여',
#   '주고',
#   '싶었는가',
#   '이런',
#   '방법',
#   '말고도',
#   '다른',
#   '방법',
#   '충분',
#   '있을텐데'],
#  ['정말', '사랑', '대해', '다시', '생각', '거', '같습니다', '감동', '이에요'],
#  ['내용', '교육', '적', '이나', '정말', '지루해서요', 'ㅜ'],
#  ['꿀잼', '특히', '소유', '랑', '서인영', 'ㅋㅋㅋㅋ', '매력', '터져'],
#  ['태어나서', '본', '영화', '중', '제일', '재미없었음'],
#  ['화면', '을', '흑백', '바꾸기만', '하면', '년대', '작'],
#  ['쇼핑몰', '안', '에서만', '찍어서', '너무', '재미없고', '답답한', '내', '용도', '없다'],
#  ['진짜', '쓰레기', '영화', '돈', '아까워', '죽는줄', '알았다', '여러분', '보지', '마세요'],
#  ['와아', '오', '두근두근', '익스트림', '자체'],
#  ['폭력', '영화', '자극', '적', '이고', '실험', '적', '이라고', '예술', '인가'],
#  ['일',
#   '본',
#   '영화',
#   '랑',
#   '비슷한건',
#   '저만',
#   '느끼는건',
#   '가요',
#   '수트',
#   '입으면',
#   '미남',
#   '으루',
#   '변하구',
#   '마지막',
#   '평생',
#   '입으라',
#   '구',
#   '권유',
#   '받구',
#   '창조',
#   '이렇게',
#   '까지',
#   '중복',
#   '될수',
#   '있',
#   '눈',
#   '건지잘',
#   '모르',
#   '겠네여'],
#  ['진짜',
#   '이렇게',
#   '재미',
#   '없고',
#   '감동',
#   '없는',
#   '영화',
#   '처음',
#   '이네',
#   '특히',
#   '나',
#   '박사',
#   '고',
#   '나발',
#   '이고',
#   '모든',
#   '인물',
#   '컴퓨터',
#   '할',
#   '때',
#   '손',
#   '찍는데',
#   '키',
#   '보드',
#   '누르지도',
#   '않고',
#   'ㅋㅋㅋ',
#   '컴퓨터',
#   '화면',
#   '똑같은',
#   '파트',
#   '만',
#   '무한',
#   '반복',
#   '되고',
#   '허',
#   '접',
#   '해도',
#   '너무',
#   '허',
#   '접하네',
#   '배우',
#   '연기',
#   '개떡',
#   '이고'],
#  ['최고', '농촌', '드라마'],
#  ['독립영화',
#   '실력',
#   '스타',
#   '리그',
#   '옴니버스',
#   '라는',
#   '피로',
#   '감',
#   '극복',
#   '되는',
#   '수준',
#   '이다',
#   '얼음',
#   '강',
#   '단독',
#   '장편',
#   '만들었어도',
#   '좋았을',
#   '듯',
#   '주인공',
#   '혹',
#   '여',
#   '평소',
#   '라면',
#   '공감',
#   '안되는',
#   '여호와',
#   '증인',
#   '이라도',
#   '납득',
#   '될',
#   '정도',
#   '로',
#   '감정',
#   '을',
#   '설득',
#   '하는',
#   '솜씨',
#   '탁월하다'],
#  ['좀비',
#   '좀비',
#   '그러는데',
#   '좀비',
#   '아닙니다',
#   '우주',
#   '아름다',
#   '움',
#   '미쳐',
#   '버린',
#   '인간',
#   '일',
#   '뿐',
#   '충분히',
#   '가능한',
#   '일이',
#   '죠'],
#  ['개', '재미없음', '막장', '스토리', '어거지'],
#  ['뭐', '하나', '흠잡을', '것', '없다', '최고'],
#  ['좋은', '영화'],
#  ['탁재훈',
#   '나오',
#   '믄',
#   '재밌',
#   '는데',
#   '와이',
#   '라지',
#   '스토리',
#   '중반',
#   '부터',
#   '너',
#   '무쳐',
#   '짐',
#   '약해',
#   '약해',
#   '약해',
#   '지겨워',
#   '뒈지는줄',
#   '알'],
#  ['서스펜스', '없고', '스릴', '없다'],
#  ['우리나라', '정서', '하고', '안', '맞다'],
#  ['어디', '선', '많이', '본', '흔한', '스토리'],
#  ['최고', '드라마'],
#  ['우리', '모두', '누군가', '에게', '섬머', '였다'],
#  ['힘알', '하나', '없는', '주인공', '맥', '다', '빠진다'],
#  ['너무', '너무', '귀여운', '영화'],
#  ['전형',
#   '적',
#   '인',
#   '일본',
#   '식',
#   '엽기',
#   '괴짜',
#   '코',
#   '메디',
#   '그',
#   '특이함에',
#   '끌리는건',
#   '왜',
#   '지'],
#  ['걸', '점', '이상', '준', '사람', '뭐', '지', '나루토', '극장판', '중', '가장', '쓰래', '기'],
#  ['정당한',
#   '노력',
#   '이란',
#   '보상',
#   '받게',
#   '마련',
#   '이다',
#   '나름',
#   '일정',
#   '성취',
#   '있고',
#   '좋은',
#   '결실',
#   '을',
#   '거둔',
#   '작품'],
#  ['아씨', '울었다'],
#  ['기적', '이미', '일어났다'],
#  ['아이', '함께', '보기', '좋았지만', '그냥', '그래요'],
#  ['전율', '을', '느꼈다'],
#  ['여기저기',
#   '지저분한',
#   '내용',
#   '기적',
#   '인',
#   '사람',
#   '역겨운',
#   '연애',
#   '사',
#   '마지막',
#   '갈수록',
#   '시청률',
#   '안',
#   '나오니까',
#   '막',
#   '갈겨쓴내용'],
#  ['별로', '완전', '별로', '마지막', '빼고', '넘', '유치하고', '재미없고'],
#  ['세월',
#   '지나서',
#   '다시',
#   '보니',
#   '뭔가',
#   '먹',
#   '먹',
#   '함',
#   '다르더군요',
#   '공감',
#   '하는',
#   '사람',
#   '라면',
#   '가슴속',
#   '명작',
#   '남',
#   '을',
#   '듯'],
#  ['아이', '보기', '엔', '좋을지도'],
#  ['보', '니까', '선정', '성', '세', '같음', '그래도', '액션', '좋음'],
#  ['카타르', '시스', '느끼기에', '충분한', '값진', '영화', '였다'],
#  ['여주',
#   '린',
#   '제이',
#   '로',
#   '닮았다',
#   '전체',
#   '적',
#   '인',
#   '분위기',
#   '나',
#   '배경',
#   '좋았지만',
#   '내용',
#   '지루했다'],
#  ['당신', '솔로', '아니면', '영화', '보지', '마세요'],
#  ['남',
#   '차안',
#   '에서',
#   '전화통화',
#   '하',
#   '는걸',
#   '분',
#   '가까이',
#   '구경',
#   '하고',
#   '있으라고',
#   '폰부스',
#   '명작',
#   '이라',
#   '생각',
#   '하지만',
#   '영화',
#   '진짜',
#   '장난',
#   '하나'],
#  ['전형', '적', '인', '저', '질', '영화'],
#  ['답', '을', '알려고', '하지마라'],
#  ['재미', '잇음', '매우'],
#  ['진짜', '만든', '수작'],
#  ['제발', '찍어주세요', '현기증', '난단', '말', '이에요'],
#  ['너무나도', '따뜻한', '마음', '따뜻해지는', '한번', '쯤', '자신', '을', '되돌아보게', '만드는', '영화'],
#  ['뭔가', '조금씩', '부족한', '영화', '놀래', '킬', '려면', '확', '놀래', '키', '던지', '어정쩡한'],
#  ['거',
#   '참',
#   '소재',
#   '참',
#   '좋은데',
#   '내용',
#   '전개',
#   '개판',
#   '사람',
#   '수도',
#   '많고',
#   '총',
#   '있는데',
#   '그걸',
#   '지',
#   '끼리',
#   '서로',
#   '다',
#   '흩어져서',
#   '일방',
#   '적',
#   '밀리',
#   '네',
#   '거기',
#   '다',
#   '식인종',
#   '이라',
#   '면서',
#   '표현',
#   '을',
#   '좀비',
#   '로',
#   '해놓으면',
#   '어쩌',
#   '잔거야',
#   '식인',
#   '인해',
#   '인성',
#   '말살',
#   '되고',
#   '짐승',
#   '화',
#   '되었다는',
#   '표현',
#   '이라도',
#   '있던가'],
#  ['포스터',
#   '만',
#   '그럴',
#   '싸하다',
#   '구역',
#   '이라는',
#   '이름',
#   '만',
#   '가져다',
#   '쓴',
#   '영화',
#   '완전',
#   '졸작',
#   '이다',
#   '액션',
#   '신도',
#   '개',
#   '허',
#   '술',
#   '하고',
#   '스토리',
#   '이상하다'],
#  ['대체', '왜', '재미없다는', '거지', '난', '존나', '재밌던데'],
#  ['늑대',
#   '여정',
#   '너무',
#   '낭만',
#   '적',
#   '이었던',
#   '애니',
#   '스토리',
#   '좋지만',
#   '음악',
#   '일본',
#   '애니',
#   '중',
#   '탑',
#   '뛰어나다'],
#  ['미국', '흑인', '민권', '운동', '사를', '완벽하게', '요약', '했다'],
#  ['그', '뛰어내리지', '않았다면', '어떻게', '되었을까'],
#  ['점',
#   '대',
#   '나와야지',
#   '그냥',
#   '단순한',
#   '액션',
#   '공포물',
#   '아닌데도',
#   '긴장감',
#   '공포',
#   '감',
#   '연출',
#   '쩔고',
#   '음악',
#   '좋고',
#   '몇',
#   '년',
#   '지나도',
#   '기억나는',
#   '인상',
#   '적',
#   '인',
#   '좀비',
#   '물',
#   '인데',
#   '평점',
#   '너무',
#   '짜서',
#   '줌'],
#  ['아역', '연기', '좋았으나', '내용', '쓰레기'],
#  ['진짜',
#   '재미없다',
#   '극장',
#   '에서',
#   '볼거',
#   '없어서',
#   '스릴러',
#   '라',
#   '길',
#   '래',
#   '봤는데',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '웃음',
#   '밖에',
#   '안',
#   '나온다',
#   '혹시',
#   '나',
#   '해서라도',
#   '절대',
#   '보지마라',
#   '진짜',
#   '제발'],
#  ['평점', '믿지마', '셈', '재밌음'],
#  ['거', '좋다는', '놈', '뭐', '하는', '것', '이야', 'ㅡㅡ'],
#  ['게', '영화', '냐', '년도', '영화', '냐', '쓰래', '기'],
#  ['믿으려는'],
#  ['너무', '구식', '웃길려고', '함', '보는', '내내', '지겨', '움'],
#  ['이런거', '좋아하는', '사람', '정신', '세계', '궁금하다'],
#  ['연예계',
#   '현실',
#   '을',
#   '알리고자',
#   '하는',
#   '마음',
#   '알겠지만',
#   '영화',
#   '재미',
#   '없었다',
#   '지루해',
#   '죽',
#   '을',
#   '뻔',
#   '했음'],
#  ['아주', '재미있고', '책', '봐도', '정말', '재미있다'],
#  ['끝내주게', '재밌다'],
#  ['유투브', '동영상', '을', '돈', '내고', '보는게', '낫다', '생각', '들게', '영화'],
#  ['아쉬운',
#   '점도',
#   '있지만',
#   '스토리',
#   '맞는',
#   '분위기',
#   '나',
#   '배경',
#   '지하철',
#   '기관사',
#   '삶',
#   '등',
#   '을',
#   '묘사'],
#  ['스타워즈',
#   '편',
#   '맞아',
#   '떨어지도록',
#   '만든',
#   '영화',
#   '최고',
#   '에피소드',
#   '다스베이더',
#   '탄생',
#   '루크',
#   '레이어',
#   '운명',
#   '을',
#   '알수있는',
#   '레전드'],
#  ['소희', '귀엽다', '귀엽다', '졸귀'],
#  ['소문난', '잔치', '호화', '캐스팅', '먹을', '건', '없다'],
#  ['주성치', '영화', '최고', '졸작'],
#  ['구', '우우', '웃'],
#  ['딱히', '흠잡을', '것', '두근거릴', '것', '없는', '교과서', '적', '플레이'],
#  ['영화', '중심', '역시', '스토리', '인', '것', '을', '반전', '반전', '너무', '재미있다'],
#  ['아니라', '아닌가'],
#  ['참', '재미있었다', '연기', '발', '로', '하는', '삼류', '배우', '얼굴', '보면서', 'ㅋㅋㅋ'],
#  ['재밌군'],
#  ['것', '재밌는데'],
#  ['점도',
#   '아깝다',
#   '평',
#   '쓰는',
#   '것',
#   '귀찮다',
#   '보는',
#   '내내',
#   '오글거려서',
#   '손발',
#   '사라지는',
#   '줄',
#   '알았다'],
#  ['기대', '안', '하고', '봤는데', '영화', '보는', '내내', '몰입', '해서', '재미있게', '봤어요'],
#  ['유쾌함과',
#   '스릴러',
#   '적',
#   '인',
#   '요소',
#   '어울려진',
#   '명작',
#   '후속작',
#   '보다',
#   '훨씬',
#   '매력',
#   '있음',
#   '두고',
#   '두고',
#   '간직',
#   '해',
#   '두',
#   '면서',
#   '꺼내',
#   '보고',
#   '싶은',
#   '영화'],
#  ['좋네', '괜찮고'],
#  ['명작', '너무', '좋았던', '드라마', '스토리', '캐스팅', '연기', '음악', '연출', '모두', '완벽했던'],
#  ['괜찮은', '영', '화영', '화', '괜찮았지만', '나영', '언니', '완전', '머싯', '고', '예뻤음'],
#  ['일단',
#   '재미있다',
#   '고래',
#   '몇',
#   '마리',
#   '로',
#   '국가',
#   '적',
#   '호들갑',
#   '떠는게',
#   '오버',
#   '스럽겠지만',
#   '그런',
#   '모습',
#   '우리',
#   '모두',
#   '가며',
#   '살아야하는',
#   '지구',
#   '생명',
#   '이란',
#   '메세지',
#   '참으로',
#   '감동',
#   '적',
#   '이다'],
#  ['지금',
#   '첨',
#   '봤는데',
#   '회',
#   '만',
#   '봐',
#   '볼',
#   '까하고',
#   '봤다가',
#   '주말',
#   '밤새',
#   '완주',
#   '하였다',
#   '여운',
#   '많이',
#   '남는',
#   '드라마'],
#  ['애니메이션', '뮬란', '아쉽다', '전쟁씬', '그렇고', '연기', '그렇고', '이야기', '그렇고', '그저', '그래'],
#  ['기대', '않', '하고', '봣는데', '진짜', '내용', '좋고', '재미', '있네요'],
#  ['좋았다'],
#  ['슬픈', '맑음', '파문', '주목', '하', '라'],
#  ['김윤진', '좋아하니깐'],
#  ['재밌', '따'],
#  ['무리수', '되어', '버린', '코미디', '기획', '상품'],
#  ['나', '홀로', '집', '더불어', '나', '최고', '영화'],
#  ['나', '떠올랐다', '그', '옛날', '국산', '애니', '아마겟돈', '악몽'],
#  ['완전', '역겨운', '쓰레기', '영화', '다', '기술', '적', '수준', '을', '떠나', '각본', '무', '개념'],
#  ['고결한', '신사', '께서', '무슨', '짓', '을', '하셧을까'],
#  ['캬', '개안음', 'ㅎㅎㅎㅎ'],
#  ['보는내내', '너무', '너무', '재미있었음'],
#  ['김소현', '팬', '됬습니다', '너무', '재밌음'],
#  ['삐', '에로', '흑인', '남자', '싸웠을', '때', '재미있었다', 'ㅋㅋㅋ', '아웃', '겨'],
#  ['유럽',
#   '영화',
#   '이번',
#   '정부',
#   '많이',
#   '들어와',
#   '즐겁긴',
#   '하다만',
#   '그',
#   '내용',
#   '왜',
#   '이리',
#   '진부한',
#   '걸까',
#   '유럽',
#   '영화',
#   '욕',
#   '되게',
#   '하고있단',
#   '소리',
#   '다'],
#  ['왠만한', '허', '접영', '화', '재미있게', '보는데', '이건', '도를', '넘어섰다'],
#  ['어떤', '누구', '다른', '이의', '삶', '죽음', '대해', '왈가', '왈부', '할', '순', '없다'],
#  ['굿굿굿', '또', '해라', '또해', '라', '제발'],
#  ['주님', '께서', '부르셔서', '제', '여기', '있나이다'],
#  ['미성년',
#   '돈',
#   '많은',
#   '아저씨',
#   '에게',
#   '순결',
#   '을',
#   '바치',
#   '고',
#   '데인',
#   '후',
#   '결국',
#   '정신차리고',
#   '공부',
#   '해거',
#   '명문',
#   '대가',
#   '진부한',
#   '결말'],
#  ['정말', '재밌게', '봤고', '빈센트', '꼬마', '연기', '너무', '하네요'],
#  ['솔직히',
#   '원작',
#   '보다',
#   '훨씬',
#   '낫다',
#   '원작',
#   '무슨',
#   '인간',
#   '말',
#   '못',
#   '하게',
#   '설정',
#   '해놨어'],
#  ['말', '필요없음', '진심', '개', '재밌다'],
#  ['보', '니까', '양반', '다세포', '소녀', '감독', '이네'],
#  ['굿', '잡', '친구', '랑', '또', '보고', '싶네요'],
#  ['재미', '진짜', '흥', '하네', '근데', '새끼', '관', '종인', 'ㅋㅋㅋ'],
#  ['야경', '꾼', '보다', '엉망', '지루함'],
#  ['예원', '찡', '그만', '울', '어'],
#  ['근',
#   '년',
#   '동안',
#   '본',
#   '모든',
#   '영화',
#   '통틀어',
#   '서',
#   '최악',
#   '영화',
#   '시간',
#   '남아돌',
#   '때',
#   '봐도',
#   '시간',
#   '아까운',
#   '역대',
#   '급',
#   '쓰레기',
#   '영화'],
#  ['감동',
#   '이다',
#   '참고',
#   '로',
#   '영화',
#   '보신',
#   '분들',
#   '마지막',
#   '엔딩',
#   '부분',
#   '자막',
#   '으로나',
#   '오는',
#   '부분',
#   '잇죠',
#   '게',
#   '영화상',
#   '에서',
#   '실화',
#   '라는',
#   '거지',
#   '진짜',
#   '레알',
#   '현재',
#   '실제',
#   '로',
#   '실화',
#   '라는',
#   '말이아니에요',
#   '전지현',
#   '피디',
#   '잔아요',
#   '다큐',
#   '찍는거',
#   '그',
#   '다큐',
#   '에서',
#   '엔딩',
#   '장면',
#   '이지',
#   '진짜',
#   '실제',
#   '아니',
#   '에여',
#   '쨋',
#   '든'],
#  ['달기지',
#   '미니어쳐',
#   '티',
#   '팍팍',
#   '나던데우',
#   '뢔매',
#   '보는줄',
#   '알았다',
#   '혹시',
#   '특수',
#   '효과',
#   '감독',
#   '심형래'],
#  ['재미', '드럽게', '없다', 'ㅋㅋㅋ'],
#  ['야', '세르게이', '작은', '고추', '매운', '맛', '을', '보여주마'],
#  ['정여립',
#   '정철',
#   '기축옥사',
#   '까지',
#   '스토리',
#   '탄탄해서',
#   '좋습니다',
#   '배우',
#   '연기',
#   '참',
#   '하고',
#   '남녀',
#   '주인공',
#   '케미',
#   '좋고',
#   '챙겨',
#   '볼',
#   '수',
#   '밖에',
#   '없는',
#   '드라마',
#   'ㅠㅠㅠㅠ'],
#  ['개', '영화', '네', '요', '내', '용도', '없고', '그냥', '심심해서', '만든', '영화'],
#  ['두',
#   '개',
#   '줄려고',
#   '했는데',
#   '알바',
#   '많아서',
#   '후',
#   '볼거',
#   '없어서',
#   '채널',
#   '돌려도',
#   '다시',
#   '다른',
#   '데',
#   '로',
#   '돌리게만',
#   '드는구나'],
#  ['왜', '점', '줄', '수', '없나요'],
#  ['영화사', '남', '을', '작품', '실험영화', '완성', '본'],
#  ['자식', '을', '그렇게', '때리냐'],
#  ['게', '대체', '무슨', '내용', '이야'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '옛',
#   '다',
#   '점',
#   '이나',
#   '처먹어랔',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '게',
#   '점',
#   '급',
#   '이건',
#   '점',
#   '짜리',
#   '내용',
#   '결말',
#   '살다',
#   '살다',
#   '뭐',
#   '이딴'],
#  ['감동', '적이였고', '좋았습니다'],
#  ['초반',
#   '개',
#   '재미없었는데',
#   '볼수록',
#   '점점',
#   '재밌어',
#   '짐',
#   '외계인',
#   '내',
#   '알던',
#   '에일리언',
#   '나오던',
#   '외계인',
#   '아니야'],
#  ['쇼핑', '백', '잊혀지지', '않는다'],
#  ['의도', '좋지만', '너무', '몰입', '안되는걸', '어떡해'],
#  ['유치하지만', '가볍게', '볼', '만', '함'],
#  ['화려한',
#   '색채',
#   '때문',
#   '눈',
#   '아프지만',
#   '그',
#   '나름',
#   '대로',
#   '화려',
#   '연예계',
#   '여자',
#   '욕망',
#   '대해',
#   '표현',
#   '해냈던거',
#   '같다',
#   '보는내내',
#   '진짜',
#   '리리',
#   '코',
#   '심정',
#   '가진',
#   '연',
#   '옌',
#   '있을거',
#   '같고나를',
#   '한번',
#   '도보',
#   '지',
#   '못',
#   '하고',
#   '알지못하는',
#   '사람',
#   '날',
#   '어떻게',
#   '사랑',
#   '하',
#   '냐',
#   '그런',
#   '대사',
#   '나왔을',
#   '때',
#   '소름',
#   '돋더라',
#   '연예인',
#   '많은',
#   '사랑받으면서도',
#   '참',
#   '허전할듯'],
#  ['본지', '수이', '지나도', '아직도', '생생함', '고양이', '귀신', '복수', '진짜', '무서웠지'],
#  ['영상',
#   '대학교',
#   '졸업',
#   '작품',
#   '같아서',
#   '그렇지',
#   '꽤',
#   '나',
#   '많은걸',
#   '담아놓은',
#   '영화',
#   '임',
#   '에는',
#   '분명하다'],
#  ['최강', '전차', '부대'],
#  ['ㅇㅇ'],
#  ['진짜',
#   '어이없는',
#   '소재',
#   '라고',
#   '생각',
#   '하며',
#   '보는데',
#   '개',
#   '웃겨',
#   '남자',
#   '로서',
#   '솔직히',
#   '조금',
#   '부러울수도',
#   '있는'],
#  ['기세', '아까웠다'],
#  ['초등학교',
#   '때',
#   '선생님',
#   '보여주신',
#   '영화',
#   '시간',
#   '흘러서',
#   '기억나는건',
#   '에이즈',
#   '걸렸던',
#   '남자아이와',
#   '운동화',
#   '였고',
#   '그때',
#   '봤던',
#   '영화',
#   '뭐',
#   '였을까',
#   '궁금했었는데',
#   '그',
#   '영화',
#   '바로',
#   '굿바이',
#   '마이',
#   '프렌드',
#   '였다',
#   '년',
#   '이나',
#   '년후',
#   '나',
#   '명작',
#   '시간',
#   '흘러도',
#   '명작',
#   '이다'],
#  ['넘', '재밌었어요', 'ㅅㅎㅎㅎ'],
#  ['설리', '년생', '인데', '년도', '영화', '어떻게', '나오져'],
#  ['샷', '연결', '아닌', '충돌', '만큼이나', '거룩한', '제목', '또한', '인상', '적', '구려'],
#  ['ㅋㅋㅋ', '재미없음'],
#  ['오오',
#   '난',
#   '여태',
#   '까지',
#   '맷',
#   '데이먼',
#   '최고',
#   '영화',
#   '본',
#   '얼티',
#   '메이',
#   '텀',
#   '라이언',
#   '일병',
#   '구',
#   '하기',
#   '뿐인줄',
#   '알았음',
#   'ㅠ',
#   '굿윌헌팅도쩐당'],
#  ['이야기', '자체', '흥미', '끌', '지', '못', '하는군'],
#  ['날', '로그인', '하게', '만들다니', '청춘', '이여', '영원하라'],
#  ['현정', '언니', '짱', '죠', '완전', '잼', '잇어요'],
#  ['영',
#   '상미',
#   '예쁘고',
#   '좋지만',
#   '러닝',
#   '타임',
#   '시간',
#   '넘는데',
#   '초반',
#   '분',
#   '줄거리',
#   '다',
#   '나갔고',
#   '엄청',
#   '지루한',
#   '화보',
#   '집',
#   '보는',
#   '기분',
#   '일본',
#   '영화',
#   '특유',
#   '그',
#   '이해',
#   '못',
#   '할',
#   '희한함이',
#   '있음'],
#  ['스토리', '연결', '전혀', '안되고', '편집', '해서', '끼워', '맞춘', '드라마', '말아먹은', '작품'],
#  ['여자', '주인공', '예뻐서', '끝', '까지', '봤다'],
#  ['지구', '지켜라', '혹', '작품', '을', '보고', '만든', '건', '아닌지'],
#  ['저렇게', '힘들게', '영화', '만드는데', '왜', '한국영', '화', '다', '쓰레기', '냐'],
#  ['케릭',
#   '터',
#   '살아있었으며',
#   '미장센',
#   '훌륭했다',
#   '이야기',
#   '몰입도',
#   '있었고',
#   '불필요한',
#   '샷',
#   '존재',
#   '하지',
#   '않았다',
#   '노인',
#   '을',
#   '위',
#   '한나',
#   '라는',
#   '없다',
#   '먼저',
#   '봤지만',
#   '코',
#   '엔',
#   '감독',
#   '매력',
#   '적',
#   '인',
#   '영화',
#   '만드는',
#   '멋있는',
#   '사람'],
#  ['마지막', '황당했지만', '좋은', '영화'],
#  ['우연히', '돌려보다', '사로잡혔다', '최근', '년', '간', '본', '코미디', '영화', '중', '최고'],
#  ['연', '기', '굿', '화이팅', '해요', '누나'],
#  ['마이클',
#   '베이',
#   '최근',
#   '작',
#   '을',
#   '볼때',
#   '마다',
#   '느낀다',
#   '블록버스터',
#   '액션',
#   '장르',
#   '라도',
#   '탄탄한',
#   '시나리오',
#   '영화',
#   '필수',
#   '라는',
#   '것',
#   '을',
#   '그리고',
#   '당신',
#   '기대하던',
#   '메간폭스',
#   '늙었다'],
#  ['점', '없나', '점', '너무', '후', '하네'],
#  ['미달', '연예계', '바라보는', '태도', '고쳐야', '한다'],
#  ['파괴', '된', '관객'],
#  ['알콜중독자', '덕', '평점', '낮은가'],
#  ['중견',
#   '배우',
#   '만들어놓은',
#   '긴장감',
#   '나름',
#   '긴장감',
#   '있게',
#   '싸워',
#   '보려',
#   '했던',
#   '술사',
#   '의해',
#   '헛',
#   '웃음',
#   '나온다'],
#  ['남자',
#   '주인공',
#   '늑대',
#   '인간',
#   '변하고',
#   '끝나네',
#   '유',
#   '평점',
#   '보고',
#   '안',
#   '볼까',
#   '하다가',
#   '봤는디',
#   '재밌네',
#   '유',
#   '보다',
#   '이런',
#   '실물',
#   '특수',
#   '효과',
#   '더',
#   '보는',
#   '재미',
#   '있',
#   '어유',
#   '웃기기까지',
#   '하네',
#   '유',
#   '근',
#   '디',
#   '제목',
#   '번역',
#   '어느',
#   '바보',
#   '거여',
#   '그냥',
#   '늑대',
#   '인간',
#   '아니잖여'],
#  ['정말',
#   '최고',
#   '명작',
#   '성인',
#   '되고',
#   '본',
#   '이집트',
#   '왕자',
#   '또',
#   '다른',
#   '감동',
#   '그',
#   '자체',
#   '네',
#   '요'],
#  ['이영화', '만', '성공', '했어도', '스퀘어', '닉스', '랑', '합병', '할', '일', '없었을텐데'],
#  ['울컥', '하는', '사회', '현실'],
#  ['기대', '하나', '도안', '하', '면', '할', '일', '없을', '때', '보기', '좋은', '영화'],
#  ['소림사',
#   '관문',
#   '통과',
#   '하기',
#   '진짜',
#   '어렵다는거',
#   '보여준',
#   '영화',
#   '극장',
#   '에서',
#   '개봉',
#   '하는거',
#   '반갑다'],
#  ['시리즈', '안', '나오나', 'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['끝난다는', '사실', '너무', '슬퍼요', '가슴', '뻥', '뚫려', '버린것', '같아'],
#  ...]

# %%
### 형태소 분할된 후 불용어 처리 후 각 행의 단어들을 리스트 변수에 담기
# - document의 모든 행 내에 단어들을 행단위로 단어 분리 후 리스트 변수에 담기
# - 변수명 : X_test

X_test = []

for sentence in test_data["document"] :
    # 형태소 분석
    tokenized_sentence = okt.morphs(sentence)
    # 불용어 제거
    stopwords_sentence = [word for word in tokenized_sentence 
                                    if word not in stopwords]
    # 리스트에 담기
    X_test.append(stopwords_sentence)

# %%
print(len(X_train), len(X_test))
# Out:
# 148740 49575

# %% [markdown]
# ### 각 단어들에 번호 부여하기

# %%
### 각 단어들에 번호 부여하기 : Tokenizer() 사용
tokenizer = Tokenizer()
# - 2차원 리스트 내에 모든 단어들을 추출하여 번호를 부여시킴
#  -> 반환 결과는 딕셔너리 타입
tokenizer.fit_on_texts(X_train)
tokenizer.word_index
# Out:
# {'영화': 1,
#  '을': 2,
#  '너무': 3,
#  '다': 4,
#  '정말': 5,
#  '적': 6,
#  '만': 7,
#  '진짜': 8,
#  '로': 9,
#  '점': 10,
#  '에서': 11,
#  '연기': 12,
#  '평점': 13,
#  '것': 14,
#  '최고': 15,
#  '내': 16,
#  '그': 17,
#  '나': 18,
#  '안': 19,
#  '인': 20,
#  '이런': 21,
#  '스토리': 22,
#  '생각': 23,
#  '못': 24,
#  '왜': 25,
#  '드라마': 26,
#  '게': 27,
#  '이다': 28,
#  '감동': 29,
#  '사람': 30,
#  '보고': 31,
#  '하는': 32,
#  '하고': 33,
#  '말': 34,
#  '고': 35,
#  '더': 36,
#  '배우': 37,
#  '때': 38,
#  '감독': 39,
#  '거': 40,
#  '그냥': 41,
#  '요': 42,
#  '본': 43,
#  '재미': 44,
#  '시간': 45,
#  '내용': 46,
#  '뭐': 47,
#  '까지': 48,
#  '중': 49,
#  '쓰레기': 50,
#  '보다': 51,
#  '없는': 52,
#  '네': 53,
#  '수': 54,
#  '지': 55,
#  '봤는데': 56,
#  '작품': 57,
#  '사랑': 58,
#  '할': 59,
#  '없다': 60,
#  '볼': 61,
#  '하나': 62,
#  '다시': 63,
#  '마지막': 64,
#  '좋은': 65,
#  '이건': 66,
#  '정도': 67,
#  '저': 68,
#  '같은': 69,
#  '완전': 70,
#  '입니다': 71,
#  '있는': 72,
#  'ㅋㅋㅋ': 73,
#  '처음': 74,
#  '장면': 75,
#  '액션': 76,
#  '주인공': 77,
#  '걸': 78,
#  '이렇게': 79,
#  '보는': 80,
#  '최악': 81,
#  '개': 82,
#  '하': 83,
#  '돈': 84,
#  '이야기': 85,
#  '지금': 86,
#  '별로': 87,
#  '봐도': 88,
#  '느낌': 89,
#  '임': 90,
#  '참': 91,
#  'ㅡㅡ': 92,
#  '연출': 93,
#  '라': 94,
#  '인데': 95,
#  '없고': 96,
#  '명작': 97,
#  '듯': 98,
#  '끝': 99,
#  '그리고': 100,
#  '역시': 101,
#  '기': 102,
#  '년': 103,
#  '별': 104,
#  '많이': 105,
#  '서': 106,
#  '재밌게': 107,
#  '이해': 108,
#  '난': 109,
#  '면': 110,
#  '대': 111,
#  '이영화': 112,
#  '분': 113,
#  '라고': 114,
#  '보면': 115,
#  '또': 116,
#  '이나': 117,
#  '때문': 118,
#  '성': 119,
#  '여자': 120,
#  '부터': 121,
#  '일': 122,
#  '해서': 123,
#  '아깝다': 124,
#  '꼭': 125,
#  '된': 126,
#  '보기': 127,
#  '엔': 128,
#  '에게': 129,
#  '두': 130,
#  '이고': 131,
#  '무슨': 132,
#  '여': 133,
#  '짱': 134,
#  '기억': 135,
#  '결말': 136,
#  '편': 137,
#  '같다': 138,
#  '마음': 139,
#  '랑': 140,
#  '야': 141,
#  '인생': 142,
#  '영': 143,
#  '소재': 144,
#  '넘': 145,
#  '애': 146,
#  '님': 147,
#  '없이': 148,
#  '수준': 149,
#  '현실': 150,
#  '속': 151,
#  '한번': 152,
#  '해': 153,
#  '씨': 154,
#  '가장': 155,
#  '급': 156,
#  '매력': 157,
#  '한다': 158,
#  '반전': 159,
#  '전개': 160,
#  '함': 161,
#  '제': 162,
#  '라는': 163,
#  '한국': 164,
#  '남자': 165,
#  '가슴': 166,
#  '되는': 167,
#  '뿐': 168,
#  '아이': 169,
#  '알': 170,
#  '음악': 171,
#  '하게': 172,
#  '니': 173,
#  '다른': 174,
#  '원작': 175,
#  '줄': 176,
#  '만든': 177,
#  '하지만': 178,
#  '화': 179,
#  '인간': 180,
#  '냐': 181,
#  '추천': 182,
#  '우리': 183,
#  '지만': 184,
#  '눈물': 185,
#  '않고': 186,
#  '인지': 187,
#  '합니다': 188,
#  '모든': 189,
#  '봤다': 190,
#  '자체': 191,
#  '번': 192,
#  '눈': 193,
#  '하지': 194,
#  '인가': 195,
#  '캐릭터': 196,
#  '대박': 197,
#  '코미디': 198,
#  '처럼': 199,
#  '솔직히': 200,
#  'ㅋㅋㅋㅋ': 201,
#  '움': 202,
#  '좋다': 203,
#  '대한': 204,
#  '모두': 205,
#  '뭔가': 206,
#  '이상': 207,
#  'ㅠ': 208,
#  '했다': 209,
#  '이네': 210,
#  '전혀': 211,
#  '연기력': 212,
#  '여운': 213,
#  '그래도': 214,
#  '개봉': 215,
#  '공감': 216,
#  '기대': 217,
#  '일본': 218,
#  '시리즈': 219,
#  '있다': 220,
#  '허': 221,
#  '근데': 222,
#  '중간': 223,
#  '표현': 224,
#  '굿': 225,
#  '아주': 226,
#  '영상': 227,
#  '부분': 228,
#  '그런': 229,
#  '모습': 230,
#  '에는': 231,
#  '이라': 232,
#  '작': 233,
#  '계속': 234,
#  '제목': 235,
#  '이랑': 236,
#  'ㅜㅜ': 237,
#  '재밌다': 238,
#  '가족': 239,
#  '내내': 240,
#  '보지': 241,
#  '뭔': 242,
#  '봐': 243,
#  '진심': 244,
#  '재미있게': 245,
#  '실망': 246,
#  '없음': 247,
#  '많은': 248,
#  '하면': 249,
#  '몰입': 250,
#  '밖에': 251,
#  '어떻게': 252,
#  '후': 253,
#  '나오는': 254,
#  '였다': 255,
#  '기분': 256,
#  '했는데': 257,
#  '연': 258,
#  '봤습니다': 259,
#  '작가': 260,
#  '건': 261,
#  '건지': 262,
#  '이제': 263,
#  '않은': 264,
#  '보면서': 265,
#  '위': 266,
#  '아니다': 267,
#  '요즘': 268,
#  '잼': 269,
#  '공포': 270,
#  '아니라': 271,
#  '스릴러': 272,
#  '아니고': 273,
#  '이라는': 274,
#  '감': 275,
#  '시': 276,
#  '용': 277,
#  '긴장감': 278,
#  '개인': 279,
#  '점도': 280,
#  '재미없다': 281,
#  '않는': 282,
#  '조금': 283,
#  '알바': 284,
#  '애니': 285,
#  '대사': 286,
#  '아닌': 287,
#  '이유': 288,
#  '특히': 289,
#  '제대로': 290,
#  '삶': 291,
#  '아까운': 292,
#  '극장': 293,
#  '노래': 294,
#  '노잼': 295,
#  '한테': 296,
#  '딱': 297,
#  '점수': 298,
#  '욕': 299,
#  '시작': 300,
#  '보다가': 301,
#  '막장': 302,
#  '아름다운': 303,
#  '이란': 304,
#  '나름': 305,
#  '오랜': 306,
#  '재밌어요': 307,
#  '극': 308,
#  '이지': 309,
#  '에도': 310,
#  '제일': 311,
#  '차라리': 312,
#  '놈': 313,
#  '친구': 314,
#  '좋고': 315,
#  '영화로': 316,
#  '보게': 317,
#  '당시': 318,
#  '봤어요': 319,
#  '같이': 320,
#  '의미': 321,
#  '절대': 322,
#  '식': 323,
#  '보세요': 324,
#  '만드는': 325,
#  '위해': 326,
#  '있고': 327,
#  '력': 328,
#  '류': 329,
#  '세상': 330,
#  '싶다': 331,
#  '뻔한': 332,
#  '몇': 333,
#  '아직도': 334,
#  '년대': 335,
#  '이라고': 336,
#  '해도': 337,
#  '명': 338,
#  '공포영화': 339,
#  '미국': 340,
#  '웃음': 341,
#  '도대체': 342,
#  '아무': 343,
#  '앞': 344,
#  '설정': 345,
#  '오': 346,
#  '보니': 347,
#  '무엇': 348,
#  '마다': 349,
#  '너': 350,
#  '어': 351,
#  '초반': 352,
#  '물': 353,
#  '데': 354,
#  '뭘': 355,
#  '나도': 356,
#  '수작': 357,
#  '좋아하는': 358,
#  '출연': 359,
#  '우리나라': 360,
#  '봄': 361,
#  '추억': 362,
#  '엄청': 363,
#  '사실': 364,
#  '주고': 365,
#  '좋았다': 366,
#  '안되는': 367,
#  '남는': 368,
#  '한국영': 369,
#  '보는내내': 370,
#  '지루함': 371,
#  '가지': 372,
#  '남': 373,
#  '반': 374,
#  '준다': 375,
#  '시나리오': 376,
#  '주는': 377,
#  '관객': 378,
#  '이야': 379,
#  '분위기': 380,
#  '장난': 381,
#  '팬': 382,
#  '든': 383,
#  '좋아요': 384,
#  '시대': 385,
#  '된다': 386,
#  '지루하고': 387,
#  '졸작': 388,
#  '세': 389,
#  '살': 390,
#  '이딴': 391,
#  '자신': 392,
#  '봤던': 393,
#  '감정': 394,
#  '소리': 395,
#  '최고다': 396,
#  '같아요': 397,
#  '준': 398,
#  '이지만': 399,
#  '엔딩': 400,
#  '접': 401,
#  '영화관': 402,
#  '오늘': 403,
#  '엄마': 404,
#  '구': 405,
#  '결국': 406,
#  '제발': 407,
#  '정신': 408,
#  '주': 409,
#  '인상': 410,
#  '라면': 411,
#  '더빙': 412,
#  '원': 413,
#  '포스터': 414,
#  '캐스팅': 415,
#  '문제': 416,
#  '평가': 417,
#  '어떤': 418,
#  '코믹': 419,
#  '니까': 420,
#  '얼마나': 421,
#  '아무리': 422,
#  '될': 423,
#  '엉': 424,
#  '멋진': 425,
#  '애니메이션': 426,
#  '그저': 427,
#  '함께': 428,
#  '음': 429,
#  '몰입도': 430,
#  '신': 431,
#  '괜찮은': 432,
#  '킬링타임': 433,
#  '어릴': 434,
#  '티비': 435,
#  '했던': 436,
#  '봐서': 437,
#  '기도': 438,
#  '재밌음': 439,
#  '배경': 440,
#  '첨': 441,
#  '대해': 442,
#  '뒤': 443,
#  '맘': 444,
#  '충격': 445,
#  '스릴': 446,
#  '전쟁': 447,
#  '만화': 448,
#  '등': 449,
#  '얘기': 450,
#  '그렇게': 451,
#  '존나': 452,
#  '책': 453,
#  '개연': 454,
#  '건가': 455,
#  '같은데': 456,
#  '예술': 457,
#  '간': 458,
#  '싶은': 459,
#  '머리': 460,
#  '매우': 461,
#  '머': 462,
#  '갈수록': 463,
#  '질': 464,
#  '조': 465,
#  '보단': 466,
#  '웃기': 467,
#  '얼굴': 468,
#  '큰': 469,
#  '아니': 470,
#  '후회': 471,
#  '이름': 472,
#  '재밌는': 473,
#  '옛날': 474,
#  '영화인': 475,
#  '너무나': 476,
#  '구성': 477,
#  '어디': 478,
#  '나온': 479,
#  '하면서': 480,
#  '집중': 481,
#  '이후': 482,
#  '울': 483,
#  '까': 484,
#  '총': 485,
#  '않는다': 486,
#  '꽤': 487,
#  '장르': 488,
#  '지루한': 489,
#  '집': 490,
#  '만들어': 491,
#  '날': 492,
#  '봐라': 493,
#  '주연': 494,
#  '하는데': 495,
#  '다큐': 496,
#  '시즌': 497,
#  '상황': 498,
#  '누구': 499,
#  '지루하다': 500,
#  '그래서': 501,
#  '모르겠다': 502,
#  '재미없음': 503,
#  '상': 504,
#  '이리': 505,
#  '씬': 506,
#  '짜증': 507,
#  '억지': 508,
#  '언제': 509,
#  '예전': 510,
#  '강추': 511,
#  '글': 512,
#  '아직': 513,
#  '비': 514,
#  '후반': 515,
#  '역사': 516,
#  '다운': 517,
#  '보는데': 518,
#  '어느': 519,
#  '먹': 520,
#  '걸작': 521,
#  '아님': 522,
#  '진': 523,
#  '여기': 524,
#  '마세요': 525,
#  '누가': 526,
#  '약간': 527,
#  '훨씬': 528,
#  '했지만': 529,
#  '자기': 530,
#  '소름': 531,
#  '그것': 532,
#  '만점': 533,
#  '인물': 534,
#  '실화': 535,
#  '발연기': 536,
#  '본다': 537,
#  '그나마': 538,
#  '그대로': 539,
#  '방송': 540,
#  '분들': 541,
#  '시절': 542,
#  '봤음': 543,
#  '아까': 544,
#  '회': 545,
#  '비디오': 546,
#  '대체': 547,
#  '할수': 548,
#  '없어': 549,
#  '않다': 550,
#  '한마디': 551,
#  '소설': 552,
#  '재밌고': 553,
#  '부': 554,
#  '로맨스': 555,
#  '봤지만': 556,
#  '휴': 557,
#  '사회': 558,
#  '초딩': 559,
#  '아들': 560,
#  '하기': 561,
#  '비교': 562,
#  '보': 563,
#  '됨': 564,
#  '감성': 565,
#  '판': 566,
#  '네이버': 567,
#  '다음': 568,
#  '여주': 569,
#  '여배우': 570,
#  '전체': 571,
#  '나와서': 572,
#  '이었다': 573,
#  '간만': 574,
#  '해야': 575,
#  '죠': 576,
#  '꿈': 577,
#  '좋은데': 578,
#  '장': 579,
#  '라도': 580,
#  '편이': 581,
#  '없네': 582,
#  '같음': 583,
#  '나이': 584,
#  '만큼': 585,
#  '이라도': 586,
#  '성룡': 587,
#  '코': 588,
#  '나라': 589,
#  '재': 590,
#  '였습니다': 591,
#  '재밋': 592,
#  '동안': 593,
#  '혼자': 594,
#  '어렸을': 595,
#  '열': 596,
#  '삼류': 597,
#  '없어서': 598,
#  '순간': 599,
#  '교훈': 600,
#  '쯤': 601,
#  '보다는': 602,
#  '아쉽다': 603,
#  '재미있어요': 604,
#  'ㅉㅉ': 605,
#  '없었다': 606,
#  '빨리': 607,
#  '그만': 608,
#  '가는': 609,
#  '존재': 610,
#  '힘': 611,
#  '바로': 612,
#  '미친': 613,
#  '하네요': 614,
#  '주제': 615,
#  '어설픈': 616,
#  '낸': 617,
#  '목소리': 618,
#  '낭비': 619,
#  '에요': 620,
#  '년도': 621,
#  '억': 622,
#  '진정한': 623,
#  '죽': 624,
#  '짜리': 625,
#  '당신': 626,
#  '는데': 627,
#  '거의': 628,
#  '안보': 629,
#  '몇번': 630,
#  '질질': 631,
#  '년전': 632,
#  '굳': 633,
#  '라니': 634,
#  '잔잔한': 635,
#  '말고': 636,
#  '줄거리': 637,
#  '상당히': 638,
#  '재미있다': 639,
#  '판타지': 640,
#  'ㅜ': 641,
#  '의도': 642,
#  '에선': 643,
#  '딸': 644,
#  '이번': 645,
#  '갑자기': 646,
#  '아버지': 647,
#  '좀비': 648,
#  '좋아': 649,
#  '있지만': 650,
#  '보여주는': 651,
#  '되어': 652,
#  '그러나': 653,
#  '어른': 654,
#  '되고': 655,
#  '전부': 656,
#  '피': 657,
#  '재밌네요': 658,
#  '점주': 659,
#  '당': 660,
#  '상영': 661,
#  '모': 662,
#  '시청률': 663,
#  'ㅎㅎㅎ': 664,
#  '실제': 665,
#  '소': 666,
#  '믿고': 667,
#  '있을까': 668,
#  '만하': 669,
#  'ㅡ': 670,
#  '하며': 671,
#  '으로도': 672,
#  '봤네요': 673,
#  '평론가': 674,
#  '곳': 675,
#  '맛': 676,
#  '점점': 677,
#  '필요': 678,
#  '땜': 679,
#  '비해': 680,
#  '단': 681,
#  '재미있는': 682,
#  '난다': 683,
#  '버린': 684,
#  '쳐': 685,
#  '막': 686,
#  '한편': 687,
#  '그녀': 688,
#  '히': 689,
#  '제작': 690,
#  '화면': 691,
#  '사': 692,
#  '바': 693,
#  '같네요': 694,
#  '대로': 695,
#  '극장판': 696,
#  '초': 697,
#  '평': 698,
#  '간다': 699,
#  '답': 700,
#  '중국': 701,
#  '형': 702,
#  '하네': 703,
#  '있는데': 704,
#  '있어': 705,
#  '온': 706,
#  '되지': 707,
#  '각본': 708,
#  '에서도': 709,
#  '래': 710,
#  '밑': 711,
#  '나온다': 712,
#  '볼때': 713,
#  '굉장히': 714,
#  '이하': 715,
#  '훌륭한': 716,
#  '있어서': 717,
#  '관람': 718,
#  '란': 719,
#  '저런': 720,
#  '선': 721,
#  '스타일': 722,
#  '올': 723,
#  '일단': 724,
#  '세계': 725,
#  '가치': 726,
#  '참고': 727,
#  '선택': 728,
#  '좋네요': 729,
#  '성우': 730,
#  '똥': 731,
#  '요소': 732,
#  '항상': 733,
#  '터': 734,
#  '둘': 735,
#  '그런지': 736,
#  '복수': 737,
#  '봐야': 738,
#  '어디서': 739,
#  '햇': 740,
#  '에서는': 741,
#  '뻔': 742,
#  '첫': 743,
#  '흥행': 744,
#  '해주는': 745,
#  '어린': 746,
#  '모르고': 747,
#  '그때': 748,
#  '드': 749,
#  '여러': 750,
#  '더욱': 751,
#  '치고': 752,
#  '없네요': 753,
#  '진행': 754,
#  '였음': 755,
#  '슬픈': 756,
#  '라서': 757,
#  '이냐': 758,
#  '좋음': 759,
#  '인거': 760,
#  '또한': 761,
#  '거기': 762,
#  '아빠': 763,
#  '씩': 764,
#  '물론': 765,
#  '수가': 766,
#  '역대': 767,
#  '발': 768,
#  '보는게': 769,
#  'ㅋㅋㅋㅋㅋ': 770,
#  '완성': 771,
#  '전형': 772,
#  '편집': 773,
#  '멜로': 774,
#  '했음': 775,
#  '재미없는': 776,
#  '상미': 777,
#  '화이팅': 778,
#  '새끼': 779,
#  '충분히': 780,
#  '더럽게': 781,
#  '짓': 782,
#  '이에요': 783,
#  '해준': 784,
#  '어이': 785,
#  'ㅠㅠㅠ': 786,
#  '새로운': 787,
#  '술': 788,
#  '역': 789,
#  '불륜': 790,
#  '군': 791,
#  '귀': 792,
#  '알았는데': 793,
#  '병맛': 794,
#  '개그': 795,
#  '일이': 796,
#  '에겐': 797,
#  '엉망': 798,
#  '사건': 799,
#  '거지': 800,
#  '예상': 801,
#  '잠': 802,
#  '미화': 803,
#  '낫다': 804,
#  '중반': 805,
#  '설명': 806,
#  '꿀잼': 807,
#  '그게': 808,
#  '어쩔': 809,
#  '과거': 810,
#  '있음': 811,
#  '프랑스': 812,
#  '화보': 813,
#  '키': 814,
#  '좋겠다': 815,
#  '따': 816,
#  '나옴': 817,
#  '흥미진진': 818,
#  '도저히': 819,
#  '손': 820,
#  '재밌는데': 821,
#  '노력': 822,
#  '댓글': 823,
#  '깊은': 824,
#  '그래픽': 825,
#  '여서': 826,
#  '죽음': 827,
#  '흥미': 828,
#  '거리': 829,
#  '같아': 830,
#  '척': 831,
#  '나올': 832,
#  '무조건': 833,
#  '취향': 834,
#  '였어요': 835,
#  '티': 836,
#  '원래': 837,
#  '몸': 838,
#  '나오고': 839,
#  '있게': 840,
#  '않음': 841,
#  '리': 842,
#  '화가': 843,
#  '한다는': 844,
#  '새': 845,
#  '따뜻한': 846,
#  '하는게': 847,
#  '알았다': 848,
#  '배': 849,
#  '현': 850,
#  '자극': 851,
#  '대단한': 852,
#  '감상': 853,
#  '암': 854,
#  '며': 855,
#  '만으로도': 856,
#  '만이': 857,
#  '예': 858,
#  '학교': 859,
#  '아까워': 860,
#  '괜히': 861,
#  '안된다': 862,
#  '자꾸': 863,
#  '같습니다': 864,
#  '액션영화': 865,
#  '무': 866,
#  '관': 867,
#  '예고편': 868,
#  '오히려': 869,
#  '좋았어요': 870,
#  '바보': 871,
#  '결혼': 872,
#  '이라니': 873,
#  '다가': 874,
#  '아저씨': 875,
#  '엄청난': 876,
#  '아닌가': 877,
#  '심리': 878,
#  '게임': 879,
#  '이래': 880,
#  '속편': 881,
#  '재밌었다': 882,
#  '꺼': 883,
#  '용도': 884,
#  '기대하고': 885,
#  '미': 886,
#  '연기자': 887,
#  '안됨': 888,
#  '보이': 889,
#  '잘만': 890,
#  '마무리': 891,
#  '있을': 892,
#  '관계': 893,
#  '맨': 894,
#  '되': 895,
#  '양': 896,
#  '천재': 897,
#  '법': 898,
#  '땐': 899,
#  '야할': 900,
#  'ㄷㄷ': 901,
#  '억지로': 902,
#  '표정': 903,
#  '귀신': 904,
#  '봤을': 905,
#  '전설': 906,
#  '영환': 907,
#  '순': 908,
#  '가서': 909,
#  '최근': 910,
#  '유치': 911,
#  '느끼게': 912,
#  '높은': 913,
#  '현재': 914,
#  '헐': 915,
#  '상상': 916,
#  '나쁜': 917,
#  '동': 918,
#  '하하': 919,
#  '드는': 920,
#  '타임': 921,
#  '지루': 922,
#  '젠': 923,
#  '촬영': 924,
#  '아쉬움': 925,
#  '봣': 926,
#  '오빠': 927,
#  '대한민국': 928,
#  '하는지': 929,
#  '따라': 930,
#  '오래': 931,
#  '완벽한': 932,
#  '산': 933,
#  '대작': 934,
#  '짐': 935,
#  '조차': 936,
#  '재미있고': 937,
#  '길': 938,
#  '우연히': 939,
#  '엇': 940,
#  '전편': 941,
#  '짜': 942,
#  '스타': 943,
#  '묘사': 944,
#  '재미없고': 945,
#  '메세지': 946,
#  '만의': 947,
#  '철학': 948,
#  '하는거': 949,
#  '일까': 950,
#  '타': 951,
#  '프로그램': 952,
#  '마': 953,
#  '동화': 954,
#  '살다': 955,
#  '프로': 956,
#  '그림': 957,
#  '만에': 958,
#  '있었다': 959,
#  '그렇고': 960,
#  '예요': 961,
#  '전달': 962,
#  '서로': 963,
#  '유머': 964,
#  '유치한': 965,
#  '공': 966,
#  '졸라': 967,
#  '역할': 968,
#  '지루하지': 969,
#  '무비': 970,
#  '등장': 971,
#  '쓴': 972,
#  '조연': 973,
#  '전작': 974,
#  '경찰': 975,
#  '스러운': 976,
#  '다행': 977,
#  '소녀': 978,
#  '이미': 979,
#  '먼저': 980,
#  '나중': 981,
#  '볼수': 982,
#  '그런데': 983,
#  '했으면': 984,
#  '살인': 985,
#  '먹고': 986,
#  '마치': 987,
#  '모르는': 988,
#  '받아': 989,
#  '아쉬운': 990,
#  '특유': 991,
#  '힘든': 992,
#  '유치하고': 993,
#  '재미없어': 994,
#  '관심': 995,
#  '되었다': 996,
#  '비슷한': 997,
#  '이며': 998,
#  '보이는': 999,
#  '사이': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 99996

# %%
### 단어와 빈도(번호)를 key, value로 조회시켜줌(items())
tokenizer.word_index.items()
# Out:
# dict_items([('영화', 1), ('을', 2), ('너무', 3), ('다', 4), ('정말', 5), ('적', 6), ('만', 7), ('진짜', 8), ('로', 9), ('점', 10), ('에서', 11), ('연기', 12), ('평점', 13), ('것', 14), ('최고', 15), ('내', 16), ('그', 17), ('나', 18), ('안', 19), ('인', 20), ('이런', 21), ('스토리', 22), ('생각', 23), ('못', 24), ('왜', 25), ('드라마', 26), ('게', 27), ('이다', 28), ('감동', 29), ('사람', 30), ('보고', 31), ('하는', 32), ('하고', 33), ('말', 34), ('고', 35), ('더', 36), ('배우', 37), ('때', 38), ('감독', 39), ('거', 40), ('그냥', 41), ('요', 42), ('본', 43), ('재미', 44), ('시간', 45), ('내용', 46), ('뭐', 47), ('까지', 48), ('중', 49), ('쓰레기', 50), ('보다', 51), ('없는', 52), ('네', 53), ('수', 54), ('지', 55), ('봤는데', 56), ('작품', 57), ('사랑', 58), ('할', 59), ('없다', 60), ('볼', 61), ('하나', 62), ('다시', 63), ('마지막', 64), ('좋은', 65), ('이건', 66), ('정도', 67), ('저', 68), ('같은', 69), ('완전', 70), ('입니다', 71), ('있는', 72), ('ㅋㅋㅋ', 73), ('처음', 74), ('장면', 75), ('액션', 76), ('주인공', 77), ('걸', 78), ('이렇게', 79), ('보는', 80), ('최악', 81), ('개', 82), ('하', 83), ('돈', 84), ('이야기', 85), ('지금', 86), ('별로', 87), ('봐도', 88), ('느낌', 89), ('임', 90), ('참', 91), ('ㅡㅡ', 92), ('연출', 93), ('라', 94), ('인데', 95), ('없고', 96), ('명작', 97), ('듯', 98), ('끝', 99), ('그리고', 100), ('역시', 101), ('기', 102), ('년', 103), ('별', 104), ('많이', 105), ('서', 106), ('재밌게', 107), ('이해', 108), ('난', 109), ('면', 110), ('대', 111), ('이영화', 112), ('분', 113), ('라고', 114), ('보면', 115), ('또', 116), ('이나', 117), ('때문', 118), ('성', 119), ('여자', 120), ('부터', 121), ('일', 122), ('해서', 123), ('아깝다', 124), ('꼭', 125), ('된', 126), ('보기', 127), ('엔', 128), ('에게', 129), ('두', 130), ('이고', 131), ('무슨', 132), ('여', 133), ('짱', 134), ('기억', 135), ('결말', 136), ('편', 137), ('같다', 138), ('마음', 139), ('랑', 140), ('야', 141), ('인생', 142), ('영', 143), ('소재', 144), ('넘', 145), ('애', 146), ('님', 147), ('없이', 148), ('수준', 149), ('현실', 150), ('속', 151), ('한번', 152), ('해', 153), ('씨', 154), ('가장', 155), ('급', 156), ('매력', 157), ('한다', 158), ('반전', 159), ('전개', 160), ('함', 161), ('제', 162), ('라는', 163), ('한국', 164), ('남자', 165), ('가슴', 166), ('되는', 167), ('뿐', 168), ('아이', 169), ('알', 170), ('음악', 171), ('하게', 172), ('니', 173), ('다른', 174), ('원작', 175), ('줄', 176), ('만든', 177), ('하지만', 178), ('화', 179), ('인간', 180), ('냐', 181), ('추천', 182), ('우리', 183), ('지만', 184), ('눈물', 185), ('않고', 186), ('인지', 187), ('합니다', 188), ('모든', 189), ('봤다', 190), ('자체', 191), ('번', 192), ('눈', 193), ('하지', 194), ('인가', 195), ('캐릭터', 196), ('대박', 197), ('코미디', 198), ('처럼', 199), ('솔직히', 200), ('ㅋㅋㅋㅋ', 201), ('움', 202), ('좋다', 203), ('대한', 204), ('모두', 205), ('뭔가', 206), ('이상', 207), ('ㅠ', 208), ('했다', 209), ('이네', 210), ('전혀', 211), ('연기력', 212), ('여운', 213), ('그래도', 214), ('개봉', 215), ('공감', 216), ('기대', 217), ('일본', 218), ('시리즈', 219), ('있다', 220), ('허', 221), ('근데', 222), ('중간', 223), ('표현', 224), ('굿', 225), ('아주', 226), ('영상', 227), ('부분', 228), ('그런', 229), ('모습', 230), ('에는', 231), ('이라', 232), ('작', 233), ('계속', 234), ('제목', 235), ('이랑', 236), ('ㅜㅜ', 237), ('재밌다', 238), ('가족', 239), ('내내', 240), ('보지', 241), ('뭔', 242), ('봐', 243), ('진심', 244), ('재미있게', 245), ('실망', 246), ('없음', 247), ('많은', 248), ('하면', 249), ('몰입', 250), ('밖에', 251), ('어떻게', 252), ('후', 253), ('나오는', 254), ('였다', 255), ('기분', 256), ('했는데', 257), ('연', 258), ('봤습니다', 259), ('작가', 260), ('건', 261), ('건지', 262), ('이제', 263), ('않은', 264), ('보면서', 265), ('위', 266), ('아니다', 267), ('요즘', 268), ('잼', 269), ('공포', 270), ('아니라', 271), ('스릴러', 272), ('아니고', 273), ('이라는', 274), ('감', 275), ('시', 276), ('용', 277), ('긴장감', 278), ('개인', 279), ('점도', 280), ('재미없다', 281), ('않는', 282), ('조금', 283), ('알바', 284), ('애니', 285), ('대사', 286), ('아닌', 287), ('이유', 288), ('특히', 289), ('제대로', 290), ('삶', 291), ('아까운', 292), ('극장', 293), ('노래', 294), ('노잼', 295), ('한테', 296), ('딱', 297), ('점수', 298), ('욕', 299), ('시작', 300), ('보다가', 301), ('막장', 302), ('아름다운', 303), ('이란', 304), ('나름', 305), ('오랜', 306), ('재밌어요', 307), ('극', 308), ('이지', 309), ('에도', 310), ('제일', 311), ('차라리', 312), ('놈', 313), ('친구', 314), ('좋고', 315), ('영화로', 316), ('보게', 317), ('당시', 318), ('봤어요', 3 ...

# %%
### 말뭉치 갯수 정의하기
# - 빈도가 작은 단어의 갯수는 제외시키기

### 사용빈도가 작은 단어의 수 확인하기

### 임시로 기준 단어의 갯수 정의하기(비교 기준으로 사용)
# - 기준 갯수보다 작은 단어 빈도 확인을 위해
threshold = 3

# 총 단어의 수 
total_cnt = len(tokenizer.word_index)
print(total_cnt)
# 기준 단어의 갯수보다 작은 단어의 갯수 count(실제 확인할 값)
rare_cnt = 0

# 훈련 데이터에 사용할 전체 단어 빈도수 총합
total_freq = 0
# 기준 단어의 갯수보다 작은 단어의 등장 빈도수 총합
rare_freq = 0

### tokenizer의 word_counts를 items()를 사용하여 반복하기
for key, value in tokenizer.word_counts.items() :
    # 훈련 데이터의 전체 단어 빈도수 총합 누적하기
    total_freq = total_freq + value
    
    # 기준 단어의 갯수보다 작은 단어의 갯수 카운트 하기
    if value < threshold :
        # 작은 단어의 갯수 카운트
        rare_cnt = rare_cnt + 1
        
        # 작은 단어의 빈도수 총합 누적하기
        rare_freq = rare_freq + value
# Out:
# 99996

# %%
### 출력하기
print(f"단어 집합의 전체 크기 : {total_cnt}")
print(f"등장 빈도가 {threshold - 1}개 이하인 단어의 수 : {rare_cnt}")
print(f"기준 갯수보다 작은 단어의 비율 : {(rare_cnt/total_cnt) * 100}%")
print(f"전체 단어 대비 기준보다 작은 단어 비율 : {(rare_freq/total_freq)/100}%")
# Out:
# 단어 집합의 전체 크기 : 99996
# 등장 빈도가 2개 이하인 단어의 수 : 67672
# 기준 갯수보다 작은 단어의 비율 : 67.67470698827952%
# 전체 단어 대비 기준보다 작은 단어 비율 : 0.000498340736297111%

# %%
### 사용할 말뭉치 갯수 정의하기
# - 1을 더하는 이유 : 말뭉치에 없는 단어 처리를 위한 공간으로 사용(0번 인덱스 처리)
#                   : 패팅시에 빈 공간의 0번 인덱스에 대한 처리를 위함
vocab_size = total_cnt - rare_cnt + 1
print(vocab_size)
# Out:
# 32325

# %% [markdown]
# ### 텍스트를 숫자로 변환하기

# %%
### 말뭉치 사전을 기준으로 텍스트를 숫자로 변환하기
# 말뭉치 사전 생성하기 : vocab_size로 정의된 갯수에 대한 말뭉치 생성하기 위해
#  - Tokenizer 정의시 생성할 말뭉치 갯수 정의
tokenizer = Tokenizer(vocab_size)

### 단어를 정수로 변환하기 위한 패턴 찾기
#   (말뭉치 생성됨)
tokenizer.fit_on_texts(X_train)

# %%
### 찾은 패턴으로 훈련 및 테스트 데이터 변환하기
# - 말뭉치의 인덱스 번호로 텍스트를 매핑하여 변환
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
len(X_train), len(X_test)
# Out:
# (148740, 49575)

# %% [markdown]
# ### 종속변수 numpy의 배열로 처리하기

# %%
### 종속변수 컬럼명 : label
y_train = np.array(train_data["label"])
y_test  = np.array(test_data["label"])

# %%
len(X_train), y_train.shape, len(X_test), y_test.shape
# Out:
# (148740, (148740,), 49575, (49575,))

# %% [markdown]
# ### 말뭉치에 존재하지 않는 단어들의 번호는 비어 있기에 해단 부분 제거하기

# %%
### 비어 있는 부분에 대한 시퀀스의 위치 확인하기
# - enumerate : 데이터의 인덱스 번호와 해당 값을 동시에 추출
drop_train = [index for index, sentence in enumerate(X_train)
                        if len(sentence) < 1]
len(drop_train)
# Out:
# 583

# %%
### X_train 데이터에서 drop_train의 인덱스 위치를 제외하고 추출하기
# - 변수명 : X_train에 제외한 결과 담기
X_train = [sentence for index, sentence in enumerate(X_train)
                      if index not in drop_train]
len(X_train)
# Out:
# 148157

# %%
# X_train

# %%
### y_train 종속변수에서도 제거할 인덱스 위치의 행 제거하기
# - 변수명 : y_train
# - np.delete : 넘파이 배열 내에 특정 인덱스 영역을 행단위(axis=0)로 삭제하는 함수
y_train = np.delete(y_train, drop_train, axis=0)
len(X_train), y_train.shape
# Out:
# (148157, (148157,))

# %%
y_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %% [markdown]
# ### 단어의 최대길이 및 평균길이 확인하기

# %%
### 단어의 최대길이
max_len = max(len(review) for review in X_train)

### 단어의 평균길이
mean_len = sum(map(len, X_train)) / len(X_train)

max_len, mean_len
# Out:
# (68, 10.391348366935075)

# %%
### max_len 정의하기
# - 평균 이상값을 사용하면 보편적 데이터들을 대부분 포함할 것으로 여겨짐
max_len = 11

# %%
### max_len 이내에 포함될 단어들의 비율 확인하기
# - max_len 이내에 비율이 너무 낮은 경우 max_len 수정이 필요하기 때문에
# - X_train 각 행의 단어의 갯수가 max_len 이내인 비율이 어느정도 인지 확인하기
max_len = 11
count = 0

for sentence in X_train :
    if len(sentence) <= max_len :
        count = count + 1
        
rate = count / len(X_train) * 100
print(f"max_len이하인 비율은 {rate}%")

### max_len 조정 방법
# - 100% 시점의 max_len 값을 찾으면 됨
# Out:
# max_len이하인 비율은 70.53531051519671%

# %% [markdown]
# ### 데이터 스케일링 처리하기

# %%
### 데이터 스케일링 : max_len을 기준으로 모든 행의 데이터 갯수 맞추기
# X_train과 X_test 모두 padding 처리하기 : 변수명 동일하게 사용
X_train = pad_sequences(X_train, maxlen=max_len, padding="post", truncating="post")
X_test = pad_sequences(X_test, maxlen=max_len, padding="post", truncating="post")

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((148157, 11), (148157,), (49575, 11), (49575,))
