# %% [markdown]
# - 사용 데이터셋 : 구글 드라이브 files 폴더 내 파일
# - 데이터셋 확인 후 지금까지 배운 내용을 기반
#     - 1개 이상의 주제 만들어서 수행
#     - 주제별로 별도의 파일 각각 사용
# - 개별 제출

# %% [markdown]
# ### 라이브러리 정의

# %%
### 기본 라이브러리
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

### 형태소 분석
from konlpy.tag import Okt

### 정규표현식(Regular Expression; regex) 
import re

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
tf.keras.utils.set_random_seed(42)

### 텍스트 길이 정규화 라이브러리
# - 텍스트의 길이가 긴경우 자르고, 길이가 작은 경우에는 채움
from tensorflow.keras.preprocessing.sequence import pad_sequences

### 말뭉치 사전 처리를 위한 라이브러리
# - 텍스트 데이터를 숫자(인덱스번호)로 변환하는 라이브러리
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# ### 데이터 불러오기

# %%
data = pd.read_csv("./files/04_Exe_QnA_Data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11823 entries, 0 to 11822
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Q                              11823 non-null  object
#  1   A                              11823 non-null  object
#  2   label(일상다반사0/이별(부정)1/사랑(긍정)2)  11823 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 277.2+ KB

# %%
data["Q"]
# Out:
# 0                         12시 땡!
# 1                    1지망 학교 떨어졌어
# 2                   3박4일 놀러가고 싶다
# 3                3박4일 정도 놀러가고 싶다
# 4                        PPL 심하네
#                   ...
# 11818             훔쳐보는 것도 눈치 보임.
# 11819             훔쳐보는 것도 눈치 보임.
# 11820                흑기사 해주는 짝남.
# 11821    힘든 연애 좋은 연애라는게 무슨 차이일까?
# 11822                 힘들어서 결혼할까봐
# Name: Q, Length: 11823, dtype: object

# %% [markdown]
# ### 단어사전(말뭉치) 만들기

# %%
### 텍스트 문장 데이터를 토큰화(단어로 분리하여 숫자 인덱스화)를 위한 클래스 생성
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data["Q"] + data["A"])

# %%
### 전체 분리된 단어들의 갯수 확인하기
len(tokenizer.word_index)
# Out:
# 24277

# %%
### 단어들의 순서 확인하기
# - 딕셔너리 타입으로 정의되어 있음(사전의 의미임)
tokenizer.word_index
# Out:
# {'거예요': 1,
#  '수': 2,
#  '너무': 3,
#  '좋아하는': 4,
#  '더': 5,
#  '거': 6,
#  '것': 7,
#  '안': 8,
#  '잘': 9,
#  '게': 10,
#  '같아요': 11,
#  '있어요': 12,
#  '좀': 13,
#  '많이': 14,
#  '있을': 15,
#  '사람': 16,
#  '사람이': 17,
#  '마세요': 18,
#  '나': 19,
#  '건': 20,
#  '해보세요': 21,
#  '좋은': 22,
#  '내가': 23,
#  '내': 24,
#  '썸': 25,
#  '어떻게': 26,
#  '왜': 27,
#  '있는': 28,
#  '다': 29,
#  '이제': 30,
#  '수도': 31,
#  '좋을': 32,
#  '다시': 33,
#  '마음이': 34,
#  '것도': 35,
#  '하는': 36,
#  '하고': 37,
#  '또': 38,
#  '시간이': 39,
#  '오늘': 40,
#  '정말': 41,
#  '자꾸': 42,
#  '될': 43,
#  '다른': 44,
#  '그': 45,
#  '없어요': 46,
#  '할': 47,
#  '이별': 48,
#  '바랄게요': 49,
#  '돼요': 50,
#  '같이': 51,
#  '걸': 52,
#  '헤어진지': 53,
#  '좋아요': 54,
#  '한': 55,
#  '보세요': 56,
#  '여자친구가': 57,
#  '남자친구가': 58,
#  '하세요': 59,
#  '때': 60,
#  '않아요': 61,
#  '진짜': 62,
#  '드세요': 63,
#  '나를': 64,
#  '없는': 65,
#  '마음을': 66,
#  '좋죠': 67,
#  '먹고': 68,
#  '못': 69,
#  '먼저': 70,
#  '바랍니다': 71,
#  '일이': 72,
#  '계속': 73,
#  '해요': 74,
#  '생각해요': 75,
#  '말해보세요': 76,
#  '혼자': 77,
#  '뭐': 78,
#  '좋겠어요': 79,
#  '연락': 80,
#  '있을까': 81,
#  '있으면': 82,
#  '몰라요': 83,
#  '이렇게': 84,
#  '이': 85,
#  '사람은': 86,
#  '그냥': 87,
#  '힘든': 88,
#  '사랑이': 89,
#  '연애': 90,
#  '보고': 91,
#  '하면': 92,
#  '어떨까요': 93,
#  '마음': 94,
#  '나만': 95,
#  '생각해보세요': 96,
#  '될까': 97,
#  '사람을': 98,
#  '시간': 99,
#  '사랑': 100,
#  '참': 101,
#  '주세요': 102,
#  '타는': 103,
#  '하지': 104,
#  '말고': 105,
#  '해': 106,
#  '무슨': 107,
#  '있어': 108,
#  '친구가': 109,
#  '있는데': 110,
#  '줄': 111,
#  '짝사랑': 112,
#  '그럴': 113,
#  '해도': 114,
#  '날': 115,
#  '좋겠네요': 116,
#  '가고': 117,
#  '같아': 118,
#  '어떤': 119,
#  '나한테': 120,
#  '아니에요': 121,
#  '만큼': 122,
#  '짝남이': 123,
#  '바라요': 124,
#  '싶다': 125,
#  '선물': 126,
#  '술': 127,
#  '연락이': 128,
#  '많은': 129,
#  '때가': 130,
#  '생각을': 131,
#  '않는': 132,
#  '사랑하는': 133,
#  '헤어진': 134,
#  '찾아보세요': 135,
#  '아직': 136,
#  '생각이': 137,
#  '만날': 138,
#  '가보세요': 139,
#  '싶은': 140,
#  '그런': 141,
#  '살': 142,
#  '말': 143,
#  '나는': 144,
#  '자신을': 145,
#  '따라': 146,
#  '제가': 147,
#  '항상': 148,
#  '말을': 149,
#  '싶어': 150,
#  '짝남': 151,
#  '물어보세요': 152,
#  '않을': 153,
#  '해야': 154,
#  '있죠': 155,
#  '도움이': 156,
#  '새로운': 157,
#  '전': 158,
#  '사랑은': 159,
#  '후': 160,
#  '같은': 161,
#  '사랑을': 162,
#  '이별을': 163,
#  '말아요': 164,
#  '할까': 165,
#  '올': 166,
#  '연락해보세요': 167,
#  '때문에': 168,
#  '돈': 169,
#  '가는': 170,
#  '그렇게': 171,
#  '데이트': 172,
#  '짝녀가': 173,
#  '괜찮아요': 174,
#  '있나봐요': 175,
#  '친구': 176,
#  '아직도': 177,
#  '싶은데': 178,
#  '제일': 179,
#  '결국': 180,
#  '쉽지': 181,
#  '연락을': 182,
#  '오세요': 183,
#  '꼭': 184,
#  '내일': 185,
#  '않은': 186,
#  '대한': 187,
#  '마음에': 188,
#  '남자': 189,
#  '남자가': 190,
#  '집에': 191,
#  '중요해요': 192,
#  '사람이랑': 193,
#  '함께': 194,
#  '생각': 195,
#  '대화를': 196,
#  '지금': 197,
#  '이젠': 198,
#  '갑자기': 199,
#  '방법': 200,
#  '어때': 201,
#  '오래': 202,
#  '큰': 203,
#  '살고': 204,
#  '난': 205,
#  '거라': 206,
#  '이별은': 207,
#  '여자가': 208,
#  '결혼': 209,
#  '같은데': 210,
#  '힘들': 211,
#  '열심히': 212,
#  '짝남한테': 213,
#  '헤어지고': 214,
#  '조금': 215,
#  '직접': 216,
#  '볼': 217,
#  '시간을': 218,
#  '엄청': 219,
#  '모르겠어요': 220,
#  '어제': 221,
#  '오늘도': 222,
#  '중요한': 223,
#  '싶어요': 224,
#  '기분': 225,
#  '뭐가': 226,
#  '저도': 227,
#  '친구랑': 228,
#  '카톡': 229,
#  '사는': 230,
#  '서로': 231,
#  '요즘': 232,
#  '되는': 233,
#  '사람한테': 234,
#  '있다면': 235,
#  '사람도': 236,
#  '사세요': 237,
#  '가장': 238,
#  '여행': 239,
#  '하죠': 240,
#  '조금씩': 241,
#  '생각해': 242,
#  '만나고': 243,
#  '모르는': 244,
#  '없을': 245,
#  '보는': 246,
#  '돼': 247,
#  '정리가': 248,
#  '머리': 249,
#  '저는': 250,
#  '남자친구': 251,
#  '자주': 252,
#  '여자친구': 253,
#  '봐요': 254,
#  '그게': 255,
#  '매일': 256,
#  '된': 257,
#  '했는데': 258,
#  '어떡해': 259,
#  '되길': 260,
#  '일': 261,
#  '많았어요': 262,
#  '뿐이에요': 263,
#  '없어': 264,
#  '우리': 265,
#  '여자': 266,
#  '믿어요': 267,
#  '나도': 268,
#  '조심하세요': 269,
#  '않죠': 270,
#  '충분히': 271,
#  '집': 272,
#  '합니다': 273,
#  '핸드폰': 274,
#  '가서': 275,
#  '빨리': 276,
#  '점점': 277,
#  '기분이': 278,
#  '좋아할': 279,
#  '벌써': 280,
#  '만나는': 281,
#  '나서': 282,
#  '사귀고': 283,
#  '여친': 284,
#  '있었나봐요': 285,
#  '스트레스': 286,
#  '아는': 287,
#  '이런': 288,
#  '공부': 289,
#  '맞는': 290,
#  '거죠': 291,
#  '위해': 292,
#  '좋을까': 293,
#  '이야기': 294,
#  '알': 295,
#  '덜': 296,
#  '이별한지': 297,
#  '사랑의': 298,
#  '곳으로': 299,
#  '당신의': 300,
#  '사람들이': 301,
#  '잘하고': 302,
#  '관심': 303,
#  '그만': 304,
#  '받고': 305,
#  '딱': 306,
#  '주무세요': 307,
#  '걸까': 308,
#  '남친': 309,
#  '잔': 310,
#  '제': 311,
#  '전에': 312,
#  '오늘은': 313,
#  '밥': 314,
#  '여친이': 315,
#  '자신이': 316,
#  '연락하고': 317,
#  '마지막': 318,
#  '짝녀': 319,
#  '싶네요': 320,
#  '없죠': 321,
#  '해볼까': 322,
#  '필요해요': 323,
#  '이유가': 324,
#  '가져보세요': 325,
#  '번': 326,
#  '않아도': 327,
#  '사귀는': 328,
#  '많아요': 329,
#  '힘이': 330,
#  '되지': 331,
#  '듯': 332,
#  '보면': 333,
#  '날이': 334,
#  '주는': 335,
#  '애가': 336,
#  '없이': 337,
#  '아닌': 338,
#  '때까지': 339,
#  '잘할': 340,
#  '해주세요': 341,
#  '좋아하게': 342,
#  '힘들게': 343,
#  '사진': 344,
#  '남편이': 345,
#  '확인해보세요': 346,
#  '살펴보세요': 347,
#  '얼른': 348,
#  '대로': 349,
#  '아픈': 350,
#  '없네요': 351,
#  '중에': 352,
#  '예의가': 353,
#  '그녀를': 354,
#  '모두': 355,
#  '사랑해주세요': 356,
#  '힘들죠': 357,
#  '좋아': 358,
#  '늦지': 359,
#  '준비': 360,
#  '중요하지': 361,
#  '괜찮은': 362,
#  '감정을': 363,
#  '아니라': 364,
#  '몇': 365,
#  '뭘': 366,
#  '필요한': 367,
#  '말이': 368,
#  '눈을': 369,
#  '일찍': 370,
#  '하나': 371,
#  '마음의': 372,
#  '것이': 373,
#  '조금만': 374,
#  '인연이': 375,
#  '사랑에': 376,
#  '좋아하면': 377,
#  '남자애가': 378,
#  '짝녀한테': 379,
#  '언제나': 380,
#  '뭘까': 381,
#  '가세요': 382,
#  '알게': 383,
#  '해봐요': 384,
#  '잘하는': 385,
#  '애': 386,
#  '알았는데': 387,
#  '자기': 388,
#  '받을': 389,
#  '힘들어요': 390,
#  '그래요': 391,
#  '보통': 392,
#  '힘내세요': 393,
#  '너': 394,
#  '쉬운': 395,
#  '눈이': 396,
#  '서로에게': 397,
#  '확신이': 398,
#  '생각보다': 399,
#  '이별후': 400,
#  '없다면': 401,
#  '짝남이랑': 402,
#  '변화가': 403,
#  '아닌데': 404,
#  '언제': 405,
#  '쉬고': 406,
#  '신경쓰지': 407,
#  '타고': 408,
#  '좋겠죠': 409,
#  '당신을': 410,
#  '자신의': 411,
#  '생길': 412,
#  '않고': 413,
#  '편이': 414,
#  '모르겠어': 415,
#  '하루': 416,
#  '먹으면': 417,
#  '중인데': 418,
#  '있는지': 419,
#  '아무래도': 420,
#  '일을': 421,
#  '아': 422,
#  '관심이': 423,
#  '여자애가': 424,
#  '가끔': 425,
#  '드는': 426,
#  '고민': 427,
#  '나쁜': 428,
#  '반': 429,
#  '연락해도': 430,
#  '시험': 431,
#  '때도': 432,
#  '다를': 433,
#  '맨날': 434,
#  '완전': 435,
#  '상관': 436,
#  '좋겠다': 437,
#  '아닐까요': 438,
#  '마요': 439,
#  '않길': 440,
#  '같습니다': 441,
#  '가능': 442,
#  '사랑하고': 443,
#  '일은': 444,
#  '한달': 445,
#  '이별이': 446,
#  '힘드네': 447,
#  '썸남': 448,
#  '못하는': 449,
#  '그리고': 450,
#  '봅니다': 451,
#  '문제가': 452,
#  '있나': 453,
#  '차': 454,
#  '당신이': 455,
#  '아닌지': 456,
#  '뭔지': 457,
#  '하는데': 458,
#  '돈이': 459,
#  '드디어': 460,
#  '맘': 461,
#  '뭐야': 462,
#  '사람에': 463,
#  '영화': 464,
#  '것을': 465,
#  '탈': 466,
#  '천천히': 467,
#  '가슴이': 468,
#  '물어보는': 469,
#  '받아들이는': 470,
#  '좋아하는게': 471,
#  '확실한': 472,
#  '갈': 473,
#  '예쁘게': 474,
#  '만나지': 475,
#  '가기': 476,
#  '힘들어': 477,
#  '않는다면': 478,
#  '뭔가': 479,
#  '한번': 480,
#  '해서': 481,
#  '앞에': 482,
#  '건지': 483,
#  '말하세요': 484,
#  '아무것도': 485,
#  '사람이네요': 486,
#  '가면': 487,
#  '알고': 488,
#  '가지고': 489,
#  '얼굴': 490,
#  '물': 491,
#  '기다리고': 492,
#  '같네요': 493,
#  '커피': 494,
#  '꿈에': 495,
#  '좋아하는데': 496,
#  '친구를': 497,
#  '되고': 498,
#  '죽을': 499,
#  '만나보세요': 500,
#  '것보다': 501,
#  '받는': 502,
#  '갖고': 503,
#  '좋은데': 504,
#  '있겠어요': 505,
#  '있잖아요': 506,
#  '남친이': 507,
#  '좋아하는지': 508,
#  '노래': 509,
#  '잠이': 510,
#  '곳이': 511,
#  '않을까요': 512,
#  '뭐라고': 513,
#  '하는게': 514,
#  '생각할': 515,
#  '않았으면': 516,
#  '친구한테': 517,
#  '작은': 518,
#  '준비가': 519,
#  '있네요': 520,
#  '썸남이': 521,
#  '있나요': 522,
#  '언젠간': 523,
#  '안돼': 524,
#  '있어도': 525,
#  '부모님': 526,
#  '되겠네요': 527,
#  '어디': 528,
#  '누구나': 529,
#  '보러': 530,
#  '자연스러운': 531,
#  '되어': 532,
#  '그런가봐요': 533,
#  '어려운': 534,
#  '사람과': 535,
#  '나을': 536,
#  '괜찮을까': 537,
#  '머리가': 538,
#  '하나도': 539,
#  '하나씩': 540,
#  '만나자고': 541,
#  '알바': 542,
#  '사람의': 543,
#  '일이에요': 544,
#  '보지': 545,
#  '오는': 546,
#  '마음도': 547,
#  '모든': 548,
#  '소개팅': 549,
#  '꿈을': 550,
#  '애랑': 551,
#  '사랑했던': 552,
#  '재회': 553,
#  '고민이야': 554,
#  '사랑하면': 555,
#  '잊고': 556,
#  '저를': 557,
#  '만들어': 558,
#  '되나': 559,
#  '일도': 560,
#  '위한': 561,
#  '사람마다': 562,
#  '좋지': 563,
#  '미리': 564,
#  '하기': 565,
#  '생각하세요': 566,
#  '긴': 567,
#  '놀아요': 568,
#  '나랑': 569,
#  '눈물이': 570,
#  '날씨': 571,
#  '연습을': 572,
#  '만나세요': 573,
#  '싶지': 574,
#  '몸이': 575,
#  '바로': 576,
#  '안되는': 577,
#  '아무': 578,
#  '이상': 579,
#  '시작해보세요': 580,
#  '사람에게': 581,
#  '잊지': 582,
#  '관심을': 583,
#  '이별의': 584,
#  '상황을': 585,
#  '이제는': 586,
#  '학교': 587,
#  '저랑': 588,
#  '두': 589,
#  '들': 590,
#  '못하고': 591,
#  '가자고': 592,
#  '현상이에요': 593,
#  '다행이에요': 594,
#  '괜히': 595,
#  '그래도': 596,
#  '알아': 597,
#  '이야기해보세요': 598,
#  '주면': 599,
#  '새': 600,
#  '꿈': 601,
#  '사랑할': 602,
#  '먹을': 603,
#  '안하고': 604,
#  '못한': 605,
#  '정리': 606,
#  '걸로': 607,
#  '기억': 608,
#  '힘들겠어요': 609,
#  '방법이': 610,
#  '있고': 611,
#  '아무리': 612,
#  '안경': 613,
#  '연락해': 614,
#  '끝이': 615,
#  '만난': 616,
#  '마음은': 617,
#  '그녀가': 618,
#  '모르겠네요': 619,
#  '자연스럽게': 620,
#  '남자를': 621,
#  '호감이': 622,
#  '시간은': 623,
#  '생각하고': 624,
#  '쉬는': 625,
#  '신경': 626,
#  '않았어요': 627,
#  '꾸준히': 628,
#  '생각하는': 629,
#  '예쁜': 630,
#  '괜찮아': 631,
#  '네': 632,
#  '사람이에요': 633,
#  '절대': 634,
#  '나이가': 635,
#  '먹는': 636,
#  '주지': 637,
#  '나중에': 638,
#  '원하는': 639,
#  '제대로': 640,
#  '쉬세요': 641,
#  '넘': 642,
#  '잠을': 643,
#  '주고': 644,
#  '1년': 645,
#  '원래': 646,
#  '얼마': 647,
#  '될까요': 648,
#  '해보는': 649,
#  '회사': 650,
#  '와': 651,
#  '짝사랑하는': 652,
#  '힘들지': 653,
#  '끝은': 654,
#  '있습니다': 655,
#  '슬픈': 656,
#  '생각나는': 657,
#  '곧': 658,
#  '놓아주세요': 659,
#  '했던': 660,
#  '따로': 661,
#  '잊을': 662,
#  '들어': 663,
#  '어느덧': 664,
#  '완전히': 665,
#  '앞에서': 666,
#  '지켜보세요': 667,
#  '필요하죠': 668,
#  '붙잡고': 669,
#  '노력해보세요': 670,
#  '게임': 671,
#  '되죠': 672,
#  '않으면': 673,
#  '되면': 674,
#  '말씀해주세요': 675,
#  '이야기네요': 676,
#  '바뀔': 677,
#  '궁금하네요': 678,
#  '축하해요': 679,
#  '좋아하고': 680,
#  '말하는': 681,
#  '행복한': 682,
#  '말도': 683,
#  '이해해주세요': 684,
#  '운동': 685,
#  '어때요': 686,
#  '약속': 687,
#  '고생': 688,
#  '괜찮을': 689,
#  '많죠': 690,
#  '사람들': 691,
#  '없는데': 692,
#  '둘': 693,
#  '잡고': 694,
#  '만나서': 695,
#  '아침': 696,
#  '그러면': 697,
#  '때는': 698,
#  '전해보세요': 699,
#  '내는': 700,
#  '있으니까요': 701,
#  '알아보세요': 702,
#  '스스로': 703,
#  '때네요': 704,
#  '여자친구와': 705,
#  '들어드릴게요': 706,
#  '남자친구의': 707,
#  '가슴': 708,
#  '그녀의': 709,
#  '흘렀네요': 710,
#  '사랑하는데': 711,
#  '눈에': 712,
#  '확실히': 713,
#  '어느': 714,
#  '헷갈리게': 715,
#  '썸남한테': 716,
#  '즐기세요': 717,
#  '후회할': 718,
#  '결정을': 719,
#  '감정이': 720,
#  '챙겨': 721,
#  '얼마나': 722,
#  '속이': 723,
#  '필요': 724,
#  '바람': 725,
#  '있는게': 726,
#  '있지': 727,
#  '좋아할까': 728,
#  '줘도': 729,
#  '만들어보세요': 730,
#  '꿈이': 731,
#  '예뻐요': 732,
#  '폰': 733,
#  '왔는데': 734,
#  '변화를': 735,
#  '버리세요': 736,
#  '말씀해보세요': 737,
#  '이상한': 738,
#  '없다고': 739,
#  '필요는': 740,
#  '못할': 741,
#  '쉽게': 742,
#  '이유를': 743,
#  '건가': 744,
#  '척': 745,
#  '고민이': 746,
#  '누가': 747,
#  '시작': 748,
#  '사람으로': 749,
#  '책': 750,
#  '전화': 751,
#  '만나는게': 752,
#  '만나면': 753,
#  '아니라고': 754,
#  '달라고': 755,
#  '받지': 756,
#  '자고': 757,
#  '자신감을': 758,
#  '않아': 759,
#  '어쩔': 760,
#  '분위기': 761,
#  '비': 762,
#  '사랑한다고': 763,
#  '문자': 764,
#  '여자친구랑': 765,
#  '연락하는': 766,
#  '첫': 767,
#  '가지세요': 768,
#  '대해': 769,
#  '지나갈': 770,
#  '2년': 771,
#  '연애를': 772,
#  '저에게': 773,
#  '않으니까요': 774,
#  '그녀': 775,
#  '상처를': 776,
#  '사랑하지': 777,
#  '나의': 778,
#  '당신은': 779,
#  '지내고': 780,
#  '그건': 781,
#  '여자친구의': 782,
#  '좋아해도': 783,
#  '썸타는': 784,
#  '짝녀랑': 785,
#  '썸이': 786,
#  '썸인지': 787,
#  '정도': 788,
#  '모르고': 789,
#  '옆에': 790,
#  '가요': 791,
#  '있을거예요': 792,
#  '수록': 793,
#  '선택을': 794,
#  '약': 795,
#  '앞으로': 796,
#  '필요할': 797,
#  '지쳤나봐요': 798,
#  '기다릴': 799,
#  '쐬고': 800,
#  '사람들에게': 801,
#  '편하게': 802,
#  '길이': 803,
#  '사고': 804,
#  '않게': 805,
#  '만든': 806,
#  '나이': 807,
#  '어쩌지': 808,
#  '봐도': 809,
#  '재미': 810,
#  '능력이': 811,
#  '여러': 812,
#  '말이에요': 813,
#  '자책하지': 814,
#  '발표': 815,
#  '최고죠': 816,
#  '놀고': 817,
#  '전남친': 818,
#  '이건': 819,
#  '처음': 820,
#  '대학': 821,
#  '나은': 822,
#  '없으면': 823,
#  '충분해요': 824,
#  '맛있는': 825,
#  '좋겠어': 826,
#  '면접': 827,
#  '많아': 828,
#  '선물이': 829,
#  '아무도': 830,
#  '즐거운': 831,
#  '중': 832,
#  '티': 833,
#  '용기를': 834,
#  '추천': 835,
#  '안돼요': 836,
#  '한잔': 837,
#  '아니면': 838,
#  '좋아해': 839,
#  '엄마가': 840,
#  '애한테': 841,
#  '연애는': 842,
#  '되기도': 843,
#  '쓰는': 844,
#  '추억이': 845,
#  '가능성이': 846,
#  '자존감이': 847,
#  '진심으로': 848,
#  '당신': 849,
#  '힘들겠지만': 850,
#  '친한': 851,
#  '말할': 852,
#  '헤어졌습니다': 853,
#  '있길': 854,
#  '남자들은': 855,
#  '거겠죠': 856,
#  '그녀는': 857,
#  '수가': 858,
#  '후폭풍이': 859,
#  '아니라면': 860,
#  '조언': 861,
#  '방법이에요': 862,
#  '잊는': 863,
#  '미련이': 864,
#  '만난지': 865,
#  '연락하지': 866,
#  '안됐는데': 867,
#  '충분한': 868,
#  '있지만': 869,
#  '사랑해서': 870,
#  '첫사랑': 871,
#  '짝사랑이': 872,
#  '고백': 873,
#  '여자애한테': 874,
#  '됨': 875,
#  '정리하는게': 876,
#  '좋아하던': 877,
#  '생겼는데': 878,
#  '부담스럽지': 879,
#  '놓고': 880,
#  '준': 881,
#  '친구로': 882,
#  '생각이에요': 883,
#  '습관이에요': 884,
#  '갈까': 885,
#  '맛있게': 886,
#  '듣고': 887,
#  '사이가': 888,
#  '역시': 889,
#  '없나봐요': 890,
#  '내세요': 891,
#  '곳에서': 892,
#  '피하세요': 893,
#  '중요하죠': 894,
#  '느낌이': 895,
#  '여행을': 896,
#  '적어보세요': 897,
#  '말해': 898,
#  '주변': 899,
#  '하셨네요': 900,
#  '번호': 901,
#  '옷': 902,
#  '자신에': 903,
#  '좋아해요': 904,
#  '사귈': 905,
#  '많은데': 906,
#  '뭐하고': 907,
#  '나면': 908,
#  '사용해보세요': 909,
#  '소리': 910,
#  '생각은': 911,
#  '날씨가': 912,
#  '어디서': 913,
#  '일이네요': 914,
#  '늦게': 915,
#  '때를': 916,
#  '아닐': 917,
#  '밖에': 918,
#  '소중한': 919,
#  '넌': 920,
#  '알려주세요': 921,
#  '눈': 922,
#  '용기가': 923,
#  '한달이': 924,
#  '편한': 925,
#  '좋겠지만': 926,
#  '모습이': 927,
#  '기다려보세요': 928,
#  '관계를': 929,
#  '잠': 930,
#  '우산': 931,
#  '잊어버리세요': 932,
#  '곳에': 933,
#  '인형': 934,
#  '카페': 935,
#  '서로의': 936,
#  '의미': 937,
#  '오랜만에': 938,
#  '아침에': 939,
#  '고백해보세요': 940,
#  '지금은': 941,
#  '언제쯤': 942,
#  '화장': 943,
#  '만났는데': 944,
#  '있다고': 945,
#  '정리할': 946,
#  '전여친': 947,
#  '필요하겠네요': 948,
#  '썸남이랑': 949,
#  '프사': 950,
#  '것은': 951,
#  '헤어졌는데': 952,
#  '헤어지자고': 953,
#  '혼자가': 954,
#  '이겨낼': 955,
#  '아프네요': 956,
#  '됩니다': 957,
#  '끝을': 958,
#  '사랑한': 959,
#  '괜찮아질': 960,
#  '여자를': 961,
#  '있겠죠': 962,
#  '힘들어서': 963,
#  '선물을': 964,
#  '연락하면': 965,
#  '이거': 966,
#  '사랑으로': 967,
#  '남자친구와': 968,
#  '그렇지만': 969,
#  '호감을': 970,
#  '스킨십': 971,
#  '썸인데': 972,
#  '아는데': 973,
#  '가지': 974,
#  '온': 975,
#  '막': 976,
#  '생각만': 977,
#  '보내고': 978,
#  '됐으면': 979,
#  '믿어보세요': 980,
#  '내보세요': 981,
#  '무시하세요': 982,
#  '행복할': 983,
#  '다르겠지만': 984,
#  '걱정하지': 985,
#  '싫은': 986,
#  '관계가': 987,
#  '돌려보세요': 988,
#  '군대': 989,
#  '낫죠': 990,
#  '마음으로': 991,
#  '자신': 992,
#  '곳': 993,
#  '있다는': 994,
#  '담배': 995,
#  '선물은': 996,
#  '회사에서': 997,
#  '뭐든': 998,
#  '거니': 999,
#  '축하드려요': 1000,
#  ...}

# %%
### 말뭉치에 포함되지 않은 단어의 경우를 처리하기 위해
#   - 토큰화한 결과의 갯수에 1을 더하여 사용

### 훈련시 사용할 말뭉치 갯수
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 24278

# %%
### 텍스트를 말뭉치의 인덱스번호로 숫자화하는 함수 
#  - texts_to_sequences(텍스트데이터) 사용

### 질문 데이터를 인덱스화 하기
questions_sequences = tokenizer.texts_to_sequences(data["Q"])

print(len(questions_sequences))
# Out:
# 11823

# %%
questions_sequences
# Out:
# [[8626, 8627],
#  [8628, 587, 5806],
#  [4375, 1399, 125],
#  [4375, 788, 1399, 125],
#  [8629],
#  [4379],
#  [4379, 524],
#  [1223, 8632, 27],
#  [1223, 8634, 6, 973, 256, 36, 832],
#  [1223, 8636, 42],
#  [8638, 95, 1638, 29],
#  [425, 1419],
#  [425, 3175, 1419],
#  [2373, 4384, 5249],
#  [8640, 8641],
#  [8643, 525],
#  [8644, 8645, 10718],
#  [4388, 8647],
#  [4388, 8649, 4391, 118],
#  [3178, 3, 14, 8651],
#  [3178, 4394, 1090],
#  [3178, 1091, 8505],
#  [238, 472, 20, 381],
#  [1966, 239, 2378, 1848],
#  [1966, 239, 10096],
#  [1966, 239, 1639, 974],
#  [1966, 108],
#  [4395, 3179],
#  [4396, 8657],
#  [8658, 91, 150],
#  [2379],
#  [2379],
#  [2379, 528, 974],
#  [2379, 239],
#  [8662],
#  [1400, 3183],
#  [8664, 239, 4863],
#  [4398, 286],
#  [8667],
#  [8668, 473, 2381, 264],
#  [2382, 8669],
#  [2382, 2383, 832],
#  [2382, 4403, 832],
#  [3185, 78, 1777],
#  [3185, 835],
#  [8674],
#  [8675, 1385],
#  [885, 1967, 427, 247],
#  [885, 1967],
#  [4408, 4409, 68, 125],
#  [4408, 4409, 4464],
#  [1090, 1220],
#  [1090, 2386, 7, 118],
#  [1090, 3186, 108],
#  [1090, 590, 6, 1220],
#  [8680],
#  [8682, 264],
#  [8683, 1220],
#  [8684, 2387, 358],
#  [720, 8685],
#  [8687, 1407],
#  [8689, 524],
#  [1968, 64, 1403, 336, 108],
#  [199, 428, 137, 976],
#  [199, 1093, 19],
#  [199, 8693],
#  [199, 2388, 888, 257, 6, 118],
#  [1969, 4416, 8695, 458],
#  [1225, 1404, 150],
#  [1225, 1404, 178, 889],
#  [1225, 2390, 2, 81],
#  [1225],
#  [8701, 275, 1226],
#  [51, 8702, 114, 559],
#  [51, 8703, 109, 264],
#  [51, 1973, 95, 1974, 6, 118],
#  [51, 4420, 2378, 1848],
#  [51, 82, 1975, 669, 150],
#  [51, 4422, 592, 322],
#  [51, 47, 2, 28, 1645, 8706, 78, 81],
#  [8708],
#  [8710, 474, 3189, 1422],
#  [],
#  [],
#  [8712, 7612],
#  [8713, 8714],
#  [4428, 23354],
#  [8716, 880, 8365],
#  [4430, 264],
#  [],
#  [8720, 199, 1976, 1908],
#  [4432, 8722, 29, 6677],
#  [4432, 560, 29, 6677],
#  [],
#  [],
#  [8725, 5249],
#  [3190, 3, 2794],
#  [2397, 2398, 4436, 8728],
#  [4437, 161, 429, 979, 437],
#  [3191, 51, 8730, 880],
#  [],
#  [1647, 1848],
#  [2399, 268, 1228, 42, 106],
#  [2399, 1230, 247],
#  [8736, 2399],
#  [1231, 337],
#  [1231, 13, 337, 204, 125],
#  [1979, 1247],
#  [1979, 276],
#  [8740, 1372],
#  [8742, 8365],
#  [1980, 6260],
#  [1980, 8745, 7, 118],
#  [4444, 1097, 36, 200],
#  [8747],
#  [8749, 287, 1981, 430, 97],
#  [8750],
#  [8752],
#  [],
#  [4449],
#  [],
#  [8755, 154, 247],
#  [1982, 117, 110, 8757, 16307],
#  [],
#  [8759, 1406, 108],
#  [671, 51, 1233, 165],
#  [671, 168, 99, 12282],
#  [671, 168, 4456, 277],
#  [671, 4458],
#  [671],
#  [8763, 30],
#  [8764, 150],
#  [8766, 99, 12282],
#  [2403, 8767],
#  [8769, 8770],
#  [8771, 117, 1098],
#  [8773, 13, 7978],
#  [8775, 4463],
#  [8777, 721, 4464],
#  [180, 288, 8778],
#  [1650, 1407],
#  [3193, 2405, 4469, 793, 1408],
#  [3193, 1409, 1408],
#  [719, 69, 8779],
#  [4471, 4472, 264],
#  [209, 258],
#  [209, 1848],
#  [4474, 29, 8783],
#  [1099, 476, 8328],
#  [1099, 38],
#  [8786, 4477, 245, 4478, 8366],
#  [8787, 3, 828],
#  [3196, 104, 27, 42, 120, 1410, 4481],
#  [8788, 169, 14],
#  [8790, 169, 722],
#  [1985, 169, 14, 3895],
#  [1985, 169, 722, 13608],
#  [1236, 358],
#  [1236, 293],
#  [1236, 2408],
#  [1236, 1411],
#  [1236, 8795],
#  [],
#  [1237, 559],
#  [1237, 97],
#  [3197, 371],
#  [4487, 3],
#  [73, 8800, 97],
#  [73, 1987, 6, 8328],
#  [73, 8802, 2265],
#  [73, 91, 150],
#  [73, 91, 3199, 259],
#  [73, 723, 62, 8, 358],
#  [73, 4490, 1134],
#  [73, 8806, 150],
#  [73, 2409, 5704],
#  [8809, 8810, 2412],
#  [8812],
#  [8814, 1097, 6492],
#  [8815, 68, 1097, 6492],
#  [4496, 3202, 68, 125],
#  [4496, 68, 150],
#  [4498],
#  [4498, 258],
#  [3203, 2656],
#  [8819, 301, 828],
#  [8821, 4501, 8822, 808],
#  [427, 108],
#  [427, 13],
#  [1413, 3204, 1328],
#  [4503, 3, 2973],
#  [4503, 2973],
#  [4506, 4507, 150],
#  [4506, 4509, 150],
#  [2414, 2415, 246, 832],
#  [2414, 1404, 150],
#  [2414, 1404, 150],
#  [8828, 404, 1414, 55, 6, 118],
#  [8829, 4514, 16],
#  [],
#  [3208, 69],
#  [3208, 8832, 247],
#  [3208, 3543],
#  [8835],
#  [4515, 68, 150],
#  [4515, 8247],
#  [1415, 3348],
#  [1415, 498, 125],
#  [1415, 674, 437],
#  [1415, 431, 289, 2054],
#  [1415, 431, 499, 6, 118],
#  [1415, 431],
#  [1415],
#  [4521, 563],
#  [4522, 1657, 15776],
#  [4522],
#  [8848, 4523],
#  [289, 4524, 97],
#  [289, 184, 154, 165],
#  [289, 8851, 371],
#  [289, 1659, 97],
#  [289, 27, 154, 247],
#  [289, 9, 524],
#  [289, 302, 150],
#  [289, 13, 5, 47, 52],
#  [289, 565, 2794],
#  [1661, 24, 4532, 338, 7, 118],
#  [8856, 68, 142, 2, 81],
#  [8857, 8858],
#  [1662, 1385],
#  [1662, 986, 115],
#  [3211, 8861, 264],
#  [3211, 1991],
#  [3211, 324, 264],
#  [1663, 360, 477],
#  [1663, 360, 477],
#  [1663, 7116],
#  [1663, 3212, 2054],
#  [],
#  [4537, 91, 150],
#  [4537, 530, 117, 150],
#  [8867, 8868, 95, 477],
#  [4539, 1666],
#  [4539, 108],
#  [4541, 1238, 6260],
#  [4541],
#  [4542, 556, 796, 3214],
#  [4542, 361, 759],
#  [8875, 4543, 524],
#  [8876, 1522],
#  [],
#  [4546, 8879],
#  [4546, 8880],
#  [1239, 68],
#  [1239, 4464],
#  [1239, 8, 4549, 247],
#  [1239, 9, 8, 4549, 247],
#  [1239, 721, 4464],
#  [987, 73, 8883],
#  [303, 8884, 37, 125],
#  [303, 13, 8],
#  [8887, 1220],
#  [],
#  [4552, 8],
#  [3216, 108],
#  [362, 1981, 3217, 1385],
#  [595, 3218, 2020],
#  [595],
#  [595, 8894, 11159],
#  [595, 4558, 99],
#  [595],
#  [4562, 532, 170, 895, 663],
#  [8896, 1372],
#  [2418, 3220, 5338],
#  [4564, 1667, 188, 426, 386, 108],
#  [4564, 1416],
#  [8899, 188, 426, 386, 108],
#  [8900, 4458],
#  [8902, 8903, 4458],
#  [8905, 2812],
#  [4567, 8907],
#  [4567, 13979],
#  [1668, 476, 1385],
#  [1668, 1993, 1553],
#  [8910, 1553],
#  [8911, 219, 261, 6677],
#  [989, 1993, 166, 339, 799, 2, 81],
#  [989, 1418],
#  [989, 2420, 97],
#  [989, 1104, 7973],
#  [989, 799, 2, 81],
#  [989, 405],
#  [989, 8916, 1418],
#  [],
#  [3225],
#  [8919],
#  [1419],
#  [1419, 1864],
#  [1242, 2217],
#  [1232],
#  [1232],
#  [1232],
#  [8925, 201],
#  [45, 17, 19, 8, 4, 6, 118],
#  [45, 17, 19, 3227, 437],
#  [45, 17, 3229, 437],
#  [45, 8926, 29],
#  [87],
#  [87, 4521, 32, 332],
#  [87, 3230, 8928],
#  [87, 1421, 1422],
#  [87, 406, 125],
#  [87, 8930],
#  [87, 84, 204, 150],
#  [87, 1669, 6, 2424],
#  [87, 8932, 92, 8933, 210, 42],
#  [87, 2426, 8935],
#  [87, 165],
#  [87, 77, 4589, 4464],
#  [87, 77, 726, 358],
#  [1670, 9, 8937],
#  [4592],
#  [1243],
#  [1243, 30],
#  [596, 13],
#  [141, 149, 27, 104],
#  [141, 8940],
#  [141, 8942, 6492],
#  [141, 176, 8944, 3, 4595, 14160],
#  [171, 473],
#  [171, 202, 8947, 2430, 1407],
#  [171, 10101],
#  [3233, 9, 450, 125],
#  [3233, 13, 9, 8950, 437],
#  [304, 1106, 3234, 150],
#  [304, 2431, 458],
#  [304],
#  [1671, 141, 416],
#  [8954, 993, 597],
#  [8955, 82],
#  [4605, 597],
#  [4605, 201],
#  [],
#  [8959, 8960, 8961, 1408],
#  [2432, 8963],
#  [2432, 8963, 7267],
#  [8965, 181, 759],
#  [3236],
#  [1672, 29, 8968, 8328],
#  [1672, 38, 22655],
#  [1672],
#  [1672, 8971, 8328],
#  [8972, 13],
#  [1425, 35],
#  [4617, 143, 1407],
#  [8976, 1998],
#  [3237, 16904],
#  [3237, 8979, 4619, 2, 28, 200, 81],
#  [8980, 3865],
#  [2434],
#  [],
#  [1999, 2, 28, 16],
#  [8984, 264],
#  [8985, 3240],
#  [2435, 8986, 244, 7, 118],
#  [2435, 8, 532, 108],
#  [8989, 13, 1751],
#  [],
#  [225],
#  [225, 428, 8992, 8993, 108],
#  [225, 4627, 13, 2436, 108],
#  [225, 1678, 37, 150],
#  [225, 8996, 4463],
#  [278, 8998, 118],
#  [278],
#  [278],
#  [278, 2018],
#  [1244, 537],
#  [1244, 5806],
#  [1244, 9005, 1426],
#  [1244, 1679, 9006],
#  [1244],
#  [9008, 11057],
#  [9010, 408, 239, 117, 150],
#  [9011, 117, 150],
#  [4633, 1407],
#  [4633, 802, 1113],
#  [2439, 3243],
#  [2439, 126, 537],
#  [2439, 4634],
#  [2439, 599, 728],
#  [4635, 126, 3243],
#  [4635, 126, 3670],
#  [1245],
#  [1245, 69],
#  [9018, 2002, 630, 1246, 20035],
#  [9019, 630, 1246, 20035],
#  [567, 249, 1247, 4640],
#  [567, 249, 2441, 6, 2054],
#  [567, 39, 9021, 631],
#  [9022, 1681, 1248, 1864],
#  [],
#  [9025],
#  [9026, 2003, 2004, 729, 559],
#  [1682, 995, 4647, 16, 1385],
#  [1682, 901],
#  [1682, 9028, 2004, 729, 559],
#  [1682, 9029, 13979],
#  [4648, 9031, 9032],
#  [803, 9034],
#  [803],
#  [803, 9036],
#  [803],
#  [9037, 68, 150],
#  [4654, 1593],
#  [9038, 4464],
#  [9039, 558, 4464],
#  [9040, 68, 150],
#  [9042, 4659],
#  [9043, 3245],
#  [9045, 2442, 6, 118],
#  [9046, 9047, 7, 210],
#  [1250, 305, 125],
#  [1250, 804, 150],
#  [1250, 1226],
#  [1250, 126, 728],
#  [1250, 4665, 1422],
#  [1250, 474],
#  [4666, 4667],
#  [4666, 62],
#  [4669, 1427, 832],
#  [4669, 9054, 5249],
#  [9056, 117, 150],
#  [1110],
#  [1110, 9059, 9060],
#  [1110, 3243],
#  [1110, 10011],
#  [1110, 126, 3250],
#  [1110, 126, 3243],
#  [1110, 126, 201],
#  [1110],
#  [9063, 9064, 1239, 9065, 126, 226, 358],
#  [9066, 293, 9067, 293],
#  [9069, 305],
#  [],
#  [3252, 906],
#  [731, 3, 828],
#  [731, 3],
#  [731],
#  [731, 589],
#  [731, 264],
#  [731, 9075],
#  [731, 42, 23473],
#  [731],
#  [9078],
#  [3254, 32, 111, 387],
#  [4683, 9080, 306],
#  [4683, 9081, 306],
#  [19],
#  [19, 503],
#  [19, 161, 86, 2009, 9084, 1784],
#  [19, 51, 630, 1429, 27],
#  [19, 1647, 1407],
#  [19, 1650, 9, 9087],
#  [19],
#  [19, 3250],
#  [19, 9089, 2, 81],
#  [19, 1670],
#  [19],
#  [19, 185, 1244],
#  [19],
#  [19, 3, 69, 1666],
#  [19, 3, 23238],
#  [19, 2011],
#  [19, 9095, 9096],
#  [19, 9097],
#  [19],
#  [19, 44, 6, 165],
#  [19, 4694, 6, 404],
#  [19, 4698, 386, 26, 165],
#  [19, 4698, 386, 9100, 26, 104],
#  [19, 14],
#  [19, 143, 4701, 6, 118],
#  [19, 434, 4702, 6, 118],
#  [19, 249, 428, 332],
#  [19, 538, 9104, 7, 118],
#  [19, 70, 10158],
#  [19, 1430, 27, 84, 2008],
#  [19, 1112, 328, 6, 1220],
#  [19, 4707, 2450, 6, 118],
#  [19, 1403, 6, 118],
#  [19, 1403, 16, 26, 106],
#  [19, 1403, 16, 4223],
#  [19, 452, 9108, 118],
#  [19, 2451, 3191],
#  [19, 4713],
#  [19, 9110, 150],
#  [19, 9112, 1633],
#  [19],
#  [19, 3257, 1689, 6, 118],
#  [19, 2014, 2450, 6, 210, 259],
#  [19],
#  [19, 9118],
#  [19, 1254, 9119],
#  [19, 600, 902],
#  [19, 2454],
#  [19, 4722],
#  [19, 2455, 6, 118],
#  [19],
#  [19, 9123, 2121],
#  [19, 9125],
#  [19],
#  [19],
#  [19],
#  [19],
#  [19, 136, 9129, 338, 6, 118],
#  [19, 177, 386, 118],
#  [19, 201],
#  [19, 3261, 2451, 3191],
#  [19, 9131, 3, 1113, 1647, 1407],
#  [19, 212],
#  [19, 40],
#  [19, 40, 146, 4731],
#  [19, 40, 1254],
#  [19, 435, 9136],
#  [19],
#  [19, 9138, 118],
#  [19, 27],
#  [19, 27, 4734],
#  [19, 3263, 69],
#  [19, 232, 1257, 880, 204, 28, 6, 118],
#  [19, 2017, 636, 6, 118],
#  [19, 4736, 1522],
#  [19, 1416, 1403, 386, 108],
#  [19, 9440],
#  [19, 2018],
#  [19, 30],
#  [19, 1692, 150],
#  [19, 9, 142, 2, 1115],
#  [19, 4740],
#  [19, 302, 28, 483, 415],
#  [19, 302, 28, 308],
#  [19, 385, 10, 264],
#  [19, 2019],
#  [19, 340, 2, 81],
#  [19, 277, 4562, 498, 108],
#  [19, 9150],
#  [19, 13, 3218],
#  [19, 13, 3218, 2020, 106],
#  [19, 13, 3230, 9154, 826],
#  [19, 13, 3230],
#  [19, 13, 8, 9156, 826],
#  [19, 13, 3227],
#  [19, 13, 4748, 332],
#  [19, 13],
#  [19, 342, 1255, 125],
#  [19, 4, 7, 118],
#  [19, 1114, 16, 1115],
#  [19, 3265, 453],
#  [19, 499],
#  [19, 4750, 6, 118],
#  [19, 2021, 9161, 6, 118],
#  [19, 9163, 17, 4463],
#  [19, 4752, 118],
#  [19],
#  [19, 9165, 62],
#  [19, 2465, 1692, 150],
#  [19],
#  [19, 733, 4759, 6, 1220],
#  [19, 9168, 3],
#  [19, 9170, 365, 99],
#  [19, 47, 2, 108],
#  [19, 2022, 681, 6, 4762, 150],
#  [19, 77],
#  [19, 77, 239, 734],
#  [19, 2466, 1433],
#  [19, 4768, 3, 1113],
#  [19, 2467, 9, 524],
#  [19, 997, 1692, 150],
#  [9178, 8328],
#  [144, 9179, 230, 6, 118],
#  [144, 225, 4771, 9181],
#  [144, 3271, 8031],
#  [144],
#  [144, 9185, 3272, 6, 118],
#  [144, 998, 47, 2, 2468],
#  [144, 366],
#  [144, 27, 85],
#  [144, 27, 84, 4772],
#  [144, 27, 4772],
#  [144, 9, 2474, 287, 10, 65, 7, 118],
#  [144, 4, 10, 381],
#  [144, 504, 4776],
#  [144, 109, 264],
#  [144, 2028],
#  [268, 362, 1981],
#  [268, 4778, 305, 1586],
#  [268, 4779, 1435, 125],
#  [268, 1254, 305, 125],
#  [268, 4781, 4782],
#  [268, 1698, 4463],
#  [268, 1699, 305, 125],
#  [268, 9197, 9198],
#  [268, 30],
#  [268, 3274, 4785],
#  [268, 272, 804, 150],
#  [268, 9199, 1435, 125],
#  [9201],
#  [9203, 12523],
#  [3276, 7192],
#  [569, 9594],
#  [569],
#  [569, 436, 65],
#  [569, 726],
#  [],
#  [64, 9209, 437],
#  [64, 3, 202],
#  [64, 3, 2022, 769],
#  [64, 3280, 806, 394],
#  [64, 2031, 2, 28, 20, 226, 81],
#  [64, 882, 195],
#  [64, 9213, 287, 16, 259],
#  [64, 343, 36, 1981, 669, 150],
#  [95, 10818],
#  [95],
#  [95, 601, 337, 230, 6, 118],
#  [95, 309, 264],
#  [95, 4793, 4261],
#  [95, 9218, 264],
#  [95, 1638],
#  [95],
#  [95, 2482, 1048],
#  [95, 22185],
#  [95],
#  [95],
#  [95, 9223, 118],
#  [95, 738],
#  [95],
#  [95, 9227],
#  [95],
#  [95],
#  [95, 4806],
#  [95, 2028],
#  [95, 882],
#  [95, 88, 6, 2424],
#  [1701, 39, 367, 7, 118],
#  [1701, 39, 4463],
#  [9235, 29, 682, 6, 118],
#  [428, 601, 2362],
#  [807, 168, 4707, 3243],
#  [807, 9238],
#  [635, 906, 4813, 97],
#  [9241, 1003, 2484, 13],
#  [9243, 570],
#  [9244, 3265, 20583],
#  [638, 907, 68, 20301],
#  [638, 2033, 554],
#  [638, 9248],
#  [120, 9249, 10, 539],
#  [120, 1647, 13, 8, 1032],
#  [120, 1702, 908, 808],
#  [120, 1702, 9252],
#  [120, 3, 129, 52, 1675, 332],
#  [120, 452, 828],
#  [120, 9255, 13, 104],
#  [120, 9257, 2265],
#  [120, 738, 1702, 2486],
#  [120, 47, 143, 2487, 381],
#  [120, 9259, 13, 1264, 826],
#  [2488, 3286, 11707],
#  [2488, 27, 288, 72],
#  [9262, 435, 18962],
#  [9264, 9265, 910, 5249],
#  [9267, 910],
#  [2489, 8, 4832],
#  [2489, 8, 4832, 4458, 11715],
#  [2489],
#  [2489, 4, 189, 201],
#  [9273, 107, 810],
#  [205, 2009, 9274, 118],
#  [205, 14, 9275, 6, 210],
#  [205],
#  [205, 27, 474, 149, 8021],
#  [205, 27],
#  [205, 41],
#  [205, 62],
#  [205],
#  [9280, 4394, 12951],
#  [4836, 524],
#  [4836, 4839, 12951],
#  [115, 9284],
#  [571, 4840, 6, 1220],
#  [571, 27, 84],
#  [571, 13, 9285, 118],
#  [571, 504],
#  [571],
#  [571, 2492, 358],
#  [571],
#  [912, 3],
#  [912, 3, 12951],
#  [912],
#  [912, 62],
#  [9291, 117, 150],
#  [4853, 42, 4854, 3936],
#  [9292, 4856, 26, 154, 247],
#  [3291, 115, 4858, 6, 118],
#  [3291, 29, 9293, 36, 6, 118],
#  [3292, 4859, 264],
#  [1265, 369, 3, 6823],
#  [1265, 261, 3293, 165],
#  [1265, 454, 9295, 24, 169],
#  [9297, 9298, 132, 3295, 4863, 106],
#  [189, 392, 913, 1607],
#  [189, 913, 1607],
#  [189, 109, 9300],
#  [189, 1705, 6, 201],
#  [190, 9303, 3, 839],
#  [190, 1705, 6, 26, 242],
#  [9306, 1266, 7, 118],
#  [9308, 826],
#  [4869, 4870, 1864],
#  [251, 1668, 9310, 150],
#  [251, 38, 685],
#  [251, 4873, 366, 2196],
#  [251, 4874, 1439, 226, 293],
#  [251, 40, 146, 9314, 11715],
#  [251, 40, 13, 9316],
#  [58, 19, 8],
#  [58, 3],
#  [58, 3, 9320, 106],
#  [58, 3],
#  [58],
#  [58, 4879, 3, 14],
#  [58, 1706],
#  [58],
#  [58, 344, 4880],
#  [58, 1121, 3, 69, 22474],
#  [58, 9329],
#  [58, 3298, 828],
#  [58],
#  [58],
#  [58, 3299, 106, 599, 437],
#  [58, 4884, 9],
#  [58, 1707],
#  [58, 42],
#  [58, 9334, 3128],
#  [58, 1006, 9, 1087],
#  [58, 1710, 52, 8, 839],
#  [58, 4889],
#  [9336, 913, 1607],
#  [1007, 2503],
#  [1007, 1440, 1711],
#  [1007, 1269, 2762],
#  [1712, 4895, 6, 118],
#  [309, 2037, 24, 344, 264],
#  [309, 168, 1974, 332],
#  [309],
#  [309, 9340, 366, 599, 293],
#  [309, 4874, 126, 835],
#  [309, 913, 1607],
#  [309, 9343, 24, 344, 27],
#  [309, 4897, 24, 344, 264],
#  [507, 2037, 24, 4898, 8, 3720],
#  [507, 1707],
#  [9347, 1668, 592, 37, 150],
#  [345, 19, 8, 4904],
#  [345, 1270, 1271, 5],
#  [345, 434, 915, 20678],
#  [345, 20351],
#  [345, 9349, 8, 9350],
#  [345, 27, 9352, 8],
#  [345, 9354, 1087],
#  [345, 9356],
#  [345, 1271, 8, 4904],
#  [345, 1271, 8, 106],
#  [345, 1713, 3],
#  [345],
#  [345, 539, 8, 4904],
#  [345, 9360, 2885],
#  [345, 9362, 915, 20678],
#  [4905, 3305, 7, 118],
#  [4905, 264],
#  [4906],
#  [24, 251, 91, 150],
#  [24, 251, 9366, 437],
#  [24, 811, 3],
#  [24, 66],
#  [24, 66, 13, 597, 755],
#  [24, 575, 812, 2384, 9370, 437],
#  [24, 2508, 381],
#  [24, 9371, 381],
#  [24, 9372, 528, 81],
#  [24, 9374, 528, 81],
#  [24, 4912, 3],
#  [24, 9376],
#  [24, 9378, 44, 16, 137, 62, 9379, 52, 22354],
#  [24, 2511, 3, 23238],
#  [24, 1441],
#  [24, 1441, 2189],
#  [24, 4880, 13, 4748, 332],
#  [24, 3307],
#  [24, 253],
#  [24, 9384, 1009, 4236],
#  [24, 4918, 8],
#  [24, 2512, 13, 9387, 6620],
#  [24, 9389],
#  [24, 9391],
#  [24, 9393, 577],
#  [24, 2040, 264],
#  [24, 1010, 2041, 264],
#  [24, 1442, 4922, 118],
#  [24, 2515, 4924, 3644],
#  [24, 261, 404, 154, 247],
#  [24, 3719],
#  [24, 2043, 457, 415],
#  [24, 1443, 6, 210, 149, 1407],
#  [24, 1443, 6, 210, 26],
#  [24, 3311, 789],
#  [24, 9401, 24],
#  [24, 1238, 1666],
#  [24, 9404, 9734],
#  [24, 3313, 24, 9406, 6735],
#  [24, 1272, 4928, 1522],
#  [24, 1715, 9409],
#  [24, 414, 65, 6, 118],
#  [24, 9410, 539, 65, 6, 118],
#  [23, 171],
#  [23, 9412, 6, 118],
#  [23, 9413, 62, 1237, 97],
#  [23, 9414, 3, 14, 23728],
#  [23],
#  [23, 3],
#  [23, 3, 3314, 19449],
#  [23, 3, 742, 9418],
#  [23, 3],
#  [23, 44, 107, 149],
#  [23, 4937, 1113],
#  [23, 14],
#  [23, 3316, 27, 4940, 165],
#  [23],
#  [23, 9423, 23925],
#  [23, 366],
#  [23, 366, 508, 4943, 415],
#  [23],
#  [23, 9427, 84, 918, 9428],
#  [23],
#  [23],
#  [23, 602, 1011, 453],
#  [23, 4946],
#  [23, 9431, 1992, 118],
#  [23, 485, 338, 16, 118],
#  [23, 27, 9434, 415],
#  [23, 639, 17, 2044, 3543],
#  [23, 9437, 362, 1981],
#  [23, 84, 38, 9438, 1717],
#  [23, 738, 744],
#  [23, 738],
#  [23, 9440],
#  [23, 4951, 308],
#  [23, 9442, 457, 8, 1864],
#  [23, 179, 9444, 332],
#  [23, 3319],
#  [23, 4, 9447],
#  [23, 4, 6],
#  [23, 4, 6, 244, 6, 1220],
#  [23, 4, 535, 64, 1114, 16],
#  [23, 4, 17, 19, 8, 4, 6, 118],
#  [23, 4, 17, 19, 3227, 437],
#  [23, 4, 17, 3229, 437],
#  [23, 279, 1011, 453],
#  [23, 3311],
#  [23, 3311, 4953, 3191],
#  [23, 3320, 2046, 6, 118],
#  [23, 62, 9452, 2, 9453, 381],
#  [23],
#  [23, 101, 4956, 118],
#  [23],
#  [23, 3322, 1213],
#  [23, 88, 10, 5089],
#  [9458, 9459, 4959, 5125],
#  [9461, 5, 4961, 84, 1278],
#  [9463, 415],
#  [9464, 528, 453],
#  [9466, 503, 150],
#  [185, 4964, 3936],
#  [185, 1244, 7598],
#  [185, 571, 201],
#  [185, 571, 293],
#  [185, 21340],
#  [185, 541, 9469],
#  [185, 541, 322],
#  [185, 9470],
#  [185],
#  [185, 815, 3323, 2322],
#  [185, 815, 360],
#  [185, 815, 1445, 108],
#  [185, 9475, 2322],
#  [185, 9484],
#  [185],
#  [185, 9478],
#  [185],
#  [185, 687, 110, 571],
#  [185, 370, 3326, 247],
#  [185, 228, 3327],
#  [185, 9480, 4975],
#  [185, 416, 1446],
#  [1721, 4977, 9482, 2121],
#  [1721, 9484, 437],
#  [1721, 9486, 3327],
#  [2524],
#  [4978, 1273, 4975],
#  [9488, 10688],
#  [2050, 9490, 571],
#  [2050],
#  [1702, 908, 808],
#  [9492, 808],
#  [9494, 7, 118],
#  [4980, 9712],
#  [4981, 3, 14, 5704],
#  [4981, 1091, 8505],
#  [9499, 9500, 4983, 1593],
#  [9501],
#  [3329, 4654, 1593],
#  [3329, 603, 10, 1593],
#  [3329, 603, 10, 539, 1593],
#  [394, 1724],
#  [394, 5022],
#  [394, 9505],
#  [394],
#  [394, 38, 9507, 111, 597],
#  [394, 806, 16, 4986, 4752],
#  [394, 806, 86, 3183],
#  [394, 143],
#  [394, 143, 640, 1113],
#  [394, 368, 13],
#  [394, 16307],
#  [394, 2451, 20745],
#  [394, 20351],
#  [394, 3331],
#  [394, 62],
#  [1448],
#  [1448, 78, 9515],
#  [1448, 4993, 9516],
#  [1448, 9517],
#  [9518, 4261],
#  [1274, 427],
#  [1274, 427, 108],
#  [1274],
#  [1274, 107, 427],
#  [1274, 4998, 108],
#  [3],
#  [3],
#  [3, 44, 9524, 332],
#  [3, 5000, 2052, 3334, 3335],
#  [3, 5168],
#  [3, 2536, 20303],
#  [3, 2442, 6, 118],
#  [3, 129, 52],
#  [3, 14, 5004, 5005, 458, 5006, 1385],
#  [3, 14],
#  [3, 14, 10448],
#  [3],
#  [3],
#  [3, 3336, 2601],
#  [3, 9533, 1220],
#  [3, 276],
#  [3, 276, 3337, 3338, 6, 1451, 34, 2217],
#  [3, 276, 3337, 24092],
#  [3, 9537],
#  [3, 3543],
#  [3, 202, 9539, 1717],
#  [3, 5024],
#  [3, 385, 3341],
#  [3],
#  [3, 9543, 4261],
#  [3, 5013, 1728, 8328],
#  [3, 5013, 5015, 118],
#  [3, 5018, 8, 358],
#  [3, 9547, 6, 118],
#  [3],
#  [3, 2054],
#  [3, 2054, 9550],
#  [5020, 62],
#  [920, 746, 462],
#  [920, 5022],
#  [642, 14, 5023],
#  [3346, 5024],
#  [9553, 1729, 5025, 6, 1220],
#  [9554],
#  [],
#  [9556, 165],
#  [5030, 126, 3348],
#  [5030, 1452, 1439, 729, 3348],
#  [9557, 179, 358],
#  [509, 2055, 1124, 8, 1161],
#  [509, 9, 9560, 16],
#  [509, 302, 150],
#  [509, 385, 16],
#  [1124, 117, 150],
#  [1124, 487],
#  ...]

# %%
### 질문에 대한 최대값, 최소값, 중앙값 확인하기
# 52개 각각의 문장 내에 단어 갯수 확인하기
lengths = np.array([len(x) for x in questions_sequences])

np.max(lengths), np.min(lengths), np.median(lengths)
# Out:
# (15, 0, 3.0)

# %%
### 질문 데이터 데이터스케일링하기(최대 길이로 스케일링)
# - 최대 단어 길이로 스케일링하기에, 자르는값 없음. 채우는 값만 존재함
# - maxlen 속성은 15, maxlen을 생략하면 -> 전체 데이터의 단어 길이중 최대값을 사용하게됨
questions_padded = pad_sequences(questions_sequences, padding="post")
questions_padded
# Out:
# array([[ 8626,  8627,     0, ...,     0,     0,     0],
#        [ 8628,   587,  5806, ...,     0,     0,     0],
#        [ 4375,  1399,   125, ...,     0,     0,     0],
#        ...,
#        [24272,  1096,   151, ...,     0,     0,     0],
#        [   88,    90,    22, ...,     0,     0,     0],
#        [  963,     0,     0, ...,     0,     0,     0]])

# %%
# 답변데이터를 말뭉치사전의 인덱스로 인덱스화 하기
answers_sequences = tokenizer.texts_to_sequences(data["A"])

### 답변에 대한 최대값, 최소값, 중앙값 확인하기
# 52개 각각의 문장 내에 단어 갯수 확인하기
lengths = np.array([len(x) for x in answers_sequences])
np.max(lengths), np.min(lengths), np.median(lengths)
# Out:
# (21, 0, 3.0)

# %%
### 답변 데이터 데이터스케일링하기(최대 길이로 스케일링)
answers_padded = pad_sequences(answers_sequences, padding="post")
answers_padded
# Out:
# array([[ 1963,    38,  2371, ...,     0,     0,     0],
#        [ 1033,  2372,     0, ...,     0,     0,     0],
#        [ 3508,   380,    67, ...,     0,     0,     0],
#        ...,
#        [24273,     0,     0, ...,     0,     0,     0],
#        [    9,  1585,     2, ...,     0,     0,     0],
#        [20196,  1887,   104, ...,     0,     0,     0]])

# %%
### 독립변수 = 질문 데이터
#   종속변수 = 답변 데이터
# 변수명 : questions_train, answers_train, questions_val, answers_val
questions_train, questions_val, answers_train, answers_val = train_test_split(
    questions_padded, answers_padded, test_size=0.2, random_state=42
)
print(questions_train.shape, answers_train.shape)
print(questions_val.shape, answers_val.shape)
# Out:
# (9458, 15) (9458, 21)
# (2365, 15) (2365, 21)

# %%
### 모델 생성하기
model = keras.Sequential()
model

### 입력계층 추가하기(임베딩 계층 추가하기)
#    - input_dim : 말뭉치갯수
#    - 출력갯수 : 64개
#    - input_length : 질문의 특성 갯수
model.add(
    keras.layers.Embedding(input_dim=vocab_size,
                           output_dim=64,
                           input_length=questions_train.shape[1])
)

### 은닉계층 추가 : GRU, 출력:128, 활성화함수:relu
# - 질문을 담당하는 계층
model.add(
    keras.layers.GRU(units=128, activation="relu")
)

### 드롭아웃 추가
model.add(keras.layers.Dropout(0.3))

### 질문을 담당하는 계층에서 넘어오는 결과는 6개의 질문 특성을 사용함
# - 답변차원의 특성 7개로 변경한 후 답변을 담당하는 계층으로 넘겨주기
model.add(
    keras.layers.RepeatVector(answers_train.shape[1])
)

### 은닉계층 : GRU 계층(질문 결과를 받아서 답변과의 일치성 훈련 시키기)
# - return_sequences=True : 훈련결과(단어)를 다음 계층으로 넘겨주기
#                         : 다음계층에서 처리결과 단어들을 받아서 연속에서 훈련 진행
model.add(
    keras.layers.GRU(units=128, activation="relu", return_sequences=True)
)

### 단어조합 계층과 출력계층 정의하기
# TimeDistributed 
#  - 전체 문장을 기준으로 위 계층에서 전달받은 단어들의 이전/다음 인덱스의 연결(문맥 연결)을 관리하는 계층
#  - 다음에 올 단어들이 있는지 체크
#  - 분류의 개념보다, 예측(회귀-시간적 흐름-단어의 문맥)의 개념을 담고있는 계층임
#  - 출력계층을 감싸서 사용
# ** 처리 순서 : 출력계층의 말뭉치 결과를 TimeDistributed 계층에서 확률이 높은 단어들을 조합하여 반환
model.add(
    keras.layers.TimeDistributed(
        keras.layers.Dense(units=vocab_size, activation="softmax")
    )
)

model.summary()

### 모델 설정하기
# - rmsprop 사용, 학습율 기존값사용, 정확도 출력
model.compile(
    optimizer="RMSprop",
    loss="sparse_categorical_crossentropy",
    metrics="accuracy"
)

### 콜백함수 정의하기
# - 파일명 : best_RNN_chatbot.h5
save_file = "./model/best_RNN_chatbot.h5"
cp_cb = keras.callbacks.ModelCheckpoint(save_file, save_best_only=True)
es_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)

### 훈련시키기
# - 훈련횟수:100회, 배치사이즈:64
history = model.fit(
    questions_padded, answers_padded, epochs=500, batch_size=64 
    # , validation_data=(questions_val, answers_val)
    # , callbacks=[cp_cb, es_cb]
)
# Out:
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 15, 64)            1553792
#
#  gru_4 (GRU)                 (None, 128)               74496
#
#  dropout (Dropout)           (None, 128)               0
#
#  repeat_vector_5 (RepeatVect  (None, 21, 128)          0
#  or)
#
#  gru_5 (GRU)                 (None, 21, 128)           99072
#
#  time_distributed_4 (TimeDis  (None, 21, 24278)        3131862
#  tributed)
#
# =================================================================
# Total params: 4,859,222
# Trainable params: 4,859,222
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 185/185 [==============================] - 17s 84ms/step - loss: 1.9384 - accuracy: 0.8264
# Epoch 2/500
# 185/185 [==============================] - 15s 83ms/step - loss: 1.5236 - accuracy: 0.8309
# Epoch 3/500
# 185/185 [==============================] - 16s 85ms/step - loss: 1.4779 - accuracy: 0.8309
# Epoch 4/500
# 185/185 [==============================] - 20s 109ms/step - loss: 1.4419 - accuracy: 0.8309
# Epoch 5/500
# 185/185 [==============================] - 34s 183ms/step - loss: 1.4154 - accuracy: 0.8309
# Epoch 6/500
# 185/185 [==============================] - 35s 191ms/step - loss: 1.3944 - accuracy: 0.8309
# Epoch 7/500
# 185/185 [==============================] - 33s 177ms/step - loss: 1.3753 - accuracy: 0.8310
# Epoch 8/500
# 185/185 [==============================] - 37s 201ms/step - loss: 1.3588 - accuracy: 0.8311
# Epoch 9/500
# 185/185 [==============================] - 21s 115ms/step - loss: 1.3451 - accuracy: 0.8313
# Epoch 10/500
# 185/185 [==============================] - 15s 82ms/step - loss: 1.3333 - accuracy: 0.8314
# Epoch 11/500
# 185/185 [==============================] - 15s 82ms/step - loss: 1.3245 - accuracy: 0.8314
# Epoch 12/500
# 185/185 [==============================] - 15s 82ms/step - loss: 1.3158 - accuracy: 0.8315
# Epoch 13/500
# 185/185 [==============================] - 15s 82ms/step - loss: 1.3084 - accuracy: 0.8315
# Epoch 14/500
# 161/185 [=========================>....] - ETA: 1s - loss: 1.2981 - accuracy: 0.8316
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 68
#      64 es_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
#      66 ### 훈련시키기
#      67 # - 훈련횟수:100회, 배치사이즈:64
# ---> 68 history = model.fit(
#      69     questions_padded, answers_padded, epochs=500, batch_size=64
#      70     # , validation_data=(questions_val, answers_val)
#      71     # , callbacks=[cp_cb, es_cb]
#      72 )
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\Administrator\anaconda3\envs\pk_dl_gpu\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
